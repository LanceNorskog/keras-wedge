# %% [markdown]
# # Pneumonia Classification on TPU
#
# **Author:** Amy MiHyun Jang<br>
# **Date created:** 2020/07/28<br>
# **Last modified:** 2020/08/24<br>
# **Description:** Medical image classification on TPU.

# %% [markdown]
# Works, but test set is nowhere near large enough. Validation is good but holdout test sucks.

# %%
# !pip uninstall -y tensorflow
# !pip install -q tensorflow==2.5.0
# Advance 2.6.0 release breaks TPU !
# Out:
# Found existing installation: tensorflow 2.5.0
# Uninstalling tensorflow-2.5.0:
#   Successfully uninstalled tensorflow-2.5.0
#      |████████████████████████████████| 454.3 MB 16 kB/s

# %% [markdown]
# ## Introduction + Set-up
#
# This tutorial will explain how to build an X-ray image classification model
# to predict whether an X-ray scan shows presence of pneumonia.

# %%
import re
import os
import random
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print("Device:", tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print("Number of replicas:", strategy.num_replicas_in_sync)
# Out:
# Number of replicas: 1

# %% [markdown]
# We need a Google Cloud link to our data to load the data using a TPU.
# Below, we define key configuration parameters we'll use in this example.
# To run on TPU, this example must be on Colab with the TPU runtime selected.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
BATCH_SIZE = 25 * strategy.num_replicas_in_sync
BATCH_SIZE = 256
IMAGE_SIZE = [180, 180]
CLASS_NAMES = ["NORMAL", "PNEUMONIA"]

# %% [markdown]
# ## Load the data
#
# The Chest X-ray data we are using from
# [*Cell*](https://www.cell.com/cell/fulltext/S0092-8674(18)30154-5) divides the data into
# training and test files. Let's first load in the training TFRecords.

# %%
train_images = tf.data.TFRecordDataset(
    "gs://download.tensorflow.org/data/ChestXRay2017/train/images.tfrec"
)
train_paths = tf.data.TFRecordDataset(
    "gs://download.tensorflow.org/data/ChestXRay2017/train/paths.tfrec"
)

ds = tf.data.Dataset.zip((train_images, train_paths))

# %% [markdown]
# Let's count how many healthy/normal chest X-rays we have and how many
# pneumonia chest X-rays we have:

# %%
COUNT_NORMAL = len(
    [
        filename
        for filename in train_paths
        if "NORMAL" in filename.numpy().decode("utf-8")
    ]
)
print("Normal images count in training set: " + str(COUNT_NORMAL))

COUNT_PNEUMONIA = len(
    [
        filename
        for filename in train_paths
        if "PNEUMONIA" in filename.numpy().decode("utf-8")
    ]
)
print("Pneumonia images count in training set: " + str(COUNT_PNEUMONIA))
# Out:
# Normal images count in training set: 1349
# Pneumonia images count in training set: 3883

# %% [markdown]
# Notice that there are way more images that are classified as pneumonia than normal. This
# shows that we have an imbalance in our data. We will correct for this imbalance later on
# in our notebook.

# %% [markdown]
# We want to map each filename to the corresponding (image, label) pair. The following
# methods will help us do that.
#
# As we only have two labels, we will encode the label so that `1` or `True` indicates
# pneumonia and `0` or `False` indicates normal.

# %%
def get_label(file_path):
    # convert the path to a list of path components
    parts = tf.strings.split(file_path, "/")
    # The second to last is the class-directory
    return parts[-2] == "PNEUMONIA"


def decode_img(img):
    # convert the compressed string to a 3D uint8 tensor
    img = tf.image.decode_jpeg(img, channels=3)
    # resize the image to the desired size.
    return tf.image.resize(img, IMAGE_SIZE)


def process_path(image, path):
    label = get_label(path)
    # load the raw data from the file as a string
    img = decode_img(image)
    return img, label


ds = ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# Let's split the data into a training and validation datasets.

# %%
ds = ds.shuffle(10000)
train_ds = ds.take(4200)
val_ds = ds.skip(4200)

# %% [markdown]
# Let's visualize the shape of an (image, label) pair.

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  True

# %% [markdown]
# Load and format the test data as well.

# %%
test_images = tf.data.TFRecordDataset(
    "gs://download.tensorflow.org/data/ChestXRay2017/test/images.tfrec"
)
test_paths = tf.data.TFRecordDataset(
    "gs://download.tensorflow.org/data/ChestXRay2017/test/paths.tfrec"
)
test_ds = tf.data.Dataset.zip((test_images, test_paths))

test_ds = test_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

# %% [markdown]
# ## Visualize the dataset
#
# First, let's use buffered prefetching so we can yield data from disk without having I/O
# become blocking.
#
# Please note that large image datasets should not be cached in memory. We do it here
# because the dataset is not very large and we want to train on TPU.

# %%
def prepare_for_training(ds, cache=True):
    # This is a small dataset, only load it once, and keep it in memory.
    # use `.cache(filename)` to cache preprocessing work for datasets that don't
    # fit in memory.
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()

    ds = ds.batch(BATCH_SIZE)

    # `prefetch` lets the dataset fetch batches in the background while the model
    # is training.
    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

# %% [markdown]
# Call the next batch iteration of the training data.

# %%
train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

image_batch, label_batch = next(iter(train_ds))

# %% [markdown]
# Define the method to show the images in the batch.

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10, 10))
    for n in range(25):
        ax = plt.subplot(5, 5, n + 1)
        plt.imshow(image_batch[n] / 255)
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

# %% [markdown]
# As the method takes in NumPy arrays as its parameters, call the numpy function on the
# batches to return the tensor in NumPy array form.

# %%
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# ## Build the CNN
#
# To make our model more modular and easier to understand, let's define some blocks. As
# we're building a convolution neural network, we'll create a convolution block and a dense
# layer block.
#
# The architecture for this CNN has been inspired by this
# [article](https://towardsdatascience.com/deep-learning-for-detecting-pneumonia-from-x-ray-images-fc9a3d9fdba8).

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing


def conv_block(filters, inputs):
    x = layers.SeparableConv2D(filters, 3, activation="relu", padding="same")(inputs)
    x = layers.SeparableConv2D(filters, 3, activation="relu", padding="same")(x)
    x = layers.BatchNormalization()(x)
    outputs = layers.MaxPool2D()(x)

    return outputs


def dense_block(units, dropout_rate, inputs):
    x = layers.Dense(units, activation="relu")(inputs)
    x = layers.BatchNormalization()(x)
    outputs = layers.Dropout(dropout_rate)(x)

    return outputs

# %% [markdown]
# The following method will define the function to build our model for us.
#
# The images originally have values that range from [0, 255]. CNNs work better with smaller
# numbers so we will scale this down for our input.
#
# The Dropout layers are important, as they
# reduce the likelikhood of the model overfitting. We want to end the model with a `Dense`
# layer with one node, as this will be the binary output that determines if an X-ray shows
# presence of pneumonia.

# %%
def build_model():
    inputs = keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
    x = preprocessing.Rescaling(1.0 / 255)(inputs)
    x = layers.Conv2D(16, 3, activation="relu", padding="same")(x)
    x = layers.Conv2D(16, 3, activation="relu", padding="same")(x)
    x = layers.MaxPool2D()(x)

    x = conv_block(32, x)
    x = conv_block(64, x)

    x = conv_block(128, x)
    x = layers.Dropout(0.2)(x)

    x = conv_block(256, x)
    x = layers.Dropout(0.2)(x)

    x = layers.Flatten()(x)
    x = dense_block(512, 0.7, x)
    x = dense_block(128, 0.5, x)
    x = dense_block(64, 0.3, x)

    outputs = layers.Dense(1, activation="sigmoid")(x)

    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# ## Correct for data imbalance
#
# We saw earlier in this example that the data was imbalanced, with more images classified
# as pneumonia than normal. We will correct for that by using class weighting:

# %%
initial_bias = np.log([COUNT_PNEUMONIA / COUNT_NORMAL])
print("Initial bias: {:.5f}".format(initial_bias[0]))

TRAIN_IMG_COUNT = COUNT_NORMAL + COUNT_PNEUMONIA
weight_for_0 = (1 / COUNT_NORMAL) * (TRAIN_IMG_COUNT) / 2.0
weight_for_1 = (1 / COUNT_PNEUMONIA) * (TRAIN_IMG_COUNT) / 2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print("Weight for class 0: {:.2f}".format(weight_for_0))
print("Weight for class 1: {:.2f}".format(weight_for_1))
# Out:
# Initial bias: 1.05724
# Weight for class 0: 1.94
# Weight for class 1: 0.67

# %% [markdown]
# The weight for class `0` (Normal) is a lot higher than the weight for class `1`
# (Pneumonia). Because there are less normal images, each normal image will be weighted
# more to balance the data as the CNN works best when the training data is balanced.

# %% [markdown]
# ## Train the model

# %% [markdown]
# ### Defining callbacks
#
# The checkpoint callback saves the best weights of the model, so next time we want to use
# the model, we do not have to spend time training it. The early stopping callback stops
# the training process when the model starts becoming stagnant, or even worse, when the
# model starts overfitting.

# %%
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("xray_model.h5", save_best_only=True)

early_stopping_cb = tf.keras.callbacks.EarlyStopping(
    patience=10, restore_best_weights=True
)

# %% [markdown]
# We also want to tune our learning rate. Too high of a learning rate will cause the model
# to diverge. Too small of a learning rate will cause the model to be too slow. We
# implement the exponential learning rate scheduling method below.

# %%
initial_learning_rate = 0.015
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=100000, decay_rate=0.96, staircase=True
)

# %% [markdown]
# ### Fit the model
#
# For our metrics, we want to include precision and recall as they will provide use with a
# more informed picture of how good our model is. Accuracy tells us what fraction of the
# labels is correct. Since our data is not balanced, accuracy might give a skewed sense of
# a good model (i.e. a model that always predicts PNEUMONIA will be 74% accurate but is not
# a good model).
#
# Precision is the number of true positives (TP) over the sum of TP and false positives
# (FP). It shows what fraction of labeled positives are actually correct.
#
# Recall is the number of TP over the sum of TP and false negatves (FN). It shows what
# fraction of actual positives are correct.
#
# Since there are only two possible labels for the image, we will be using the
# binary crossentropy loss. When we fit the model, remember to specify the class weights,
# which we defined earlier. Because we are using a TPU, training will be quick - less than
# 2 minutes.

# %%
with strategy.scope():
    model = build_model()

    METRICS = [
        tf.keras.metrics.BinaryAccuracy(),
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall"),
    ]
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
        loss="binary_crossentropy",
        metrics=METRICS,
    )

history = model.fit(
    train_ds,
    epochs=100,
    validation_data=val_ds,
    class_weight=class_weight,
    callbacks=[checkpoint_cb, early_stopping_cb],
    verbose=2
)
print('Eval on validation:', model.evaluate(val_ds))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/100
# 17/17 - 214s - loss: 0.5225 - binary_accuracy: 0.7260 - precision: 0.9239 - recall: 0.6867 - val_loss: 8.0210 - val_binary_accuracy: 0.7471 - val_precision: 0.7471 - val_recall: 1.0000
# Epoch 2/100
# 17/17 - 138s - loss: 0.1925 - binary_accuracy: 0.9255 - precision: 0.9768 - recall: 0.9213 - val_loss: 19.7611 - val_binary_accuracy: 0.7471 - val_precision: 0.7471 - val_recall: 1.0000
# Epoch 3/100
# 17/17 - 137s - loss: 0.1756 - binary_accuracy: 0.9355 - precision: 0.9801 - recall: 0.9319 - val_loss: 2.9295 - val_binary_accuracy: 0.7471 - val_precision: 0.7471 - val_recall: 1.0000
# Epoch 4/100
# 17/17 - 138s - loss: 0.1286 - binary_accuracy: 0.9519 - precision: 0.9856 - recall: 0.9489 - val_loss: 10.6902 - val_binary_accuracy: 0.7471 - val_precision: 0.7471 - val_recall: 1.0000
# Epoch 5/100
# 17/17 - 139s - loss: 0.1158 - binary_accuracy: 0.9557 - precision: 0.9857 - recall: 0.9540 - val_loss: 10.2413 - val_binary_accuracy: 0.7471 - val_precision: 0.7471 - val_recall: 1.0000
# Epoch 6/100
# 17/17 - 139s - loss: 0.1268 - binary_accuracy: 0.9488 - precision: 0.9833 - recall: 0.9470 - val_loss: 2.2522 - val_binary_accuracy: 0.7471 - val_precision: 0.7471 - val_recall: 1.0000
# Epoch 7/100
# 17/17 - 138s - loss: 0.1078 - binary_accuracy: 0.9598 - precision: 0.9858 - recall: 0.9595 - val_loss: 0.6406 - val_binary_accuracy: 0.7529 - val_precision: 0.7515 - val_recall: 1.0000
# Epoch 8/100
# 17/17 - 140s - loss: 0.0867 - binary_accuracy: 0.9688 - precision: 0.9911 - recall: 0.9666 - val_loss: 0.1695 - val_binary_accuracy: 0.9331 - val_precision: 0.9209 - val_recall: 0.9961
# Epoch 9/100
# 17/17 - 138s - loss: 0.0993 - binary_accuracy: 0.9629 - precision: 0.9888 - recall: 0.9608 - val_loss: 4.9095 - val_binary_accuracy: 0.7471 - val_precision: 0.7471 - val_recall: 1.0000
# Epoch 10/100
# 17/17 - 138s - loss: 0.0902 - binary_accuracy: 0.9662 - precision: 0.9901 - recall: 0.9640 - val_loss: 0.2082 - val_binary_accuracy: 0.9264 - val_precision: 0.9132 - val_recall: 0.9961
# Epoch 11/100
# 17/17 - 139s - loss: 0.0799 - binary_accuracy: 0.9683 - precision: 0.9911 - recall: 0.9659 - val_loss: 0.4492 - val_binary_accuracy: 0.8798 - val_precision: 0.8623 - val_recall: 0.9987
# Epoch 12/100
# 17/17 - 139s - loss: 0.0840 - binary_accuracy: 0.9695 - precision: 0.9921 - recall: 0.9666 - val_loss: 0.8111 - val_binary_accuracy: 0.7752 - val_precision: 0.7687 - val_recall: 1.0000
# Epoch 13/100
# 17/17 - 137s - loss: 0.1031 - binary_accuracy: 0.9576 - precision: 0.9893 - recall: 0.9531 - val_loss: 0.2565 - val_binary_accuracy: 0.9457 - val_precision: 0.9419 - val_recall: 0.9883
# Epoch 14/100
# 17/17 - 139s - loss: 0.0859 - binary_accuracy: 0.9690 - precision: 0.9898 - recall: 0.9682 - val_loss: 0.6999 - val_binary_accuracy: 0.8798 - val_precision: 0.8631 - val_recall: 0.9974
# Epoch 15/100
# 17/17 - 139s - loss: 0.0630 - binary_accuracy: 0.9752 - precision: 0.9921 - recall: 0.9743 - val_loss: 0.1582 - val_binary_accuracy: 0.9632 - val_precision: 0.9598 - val_recall: 0.9922
# Epoch 16/100
# 17/17 - 137s - loss: 0.0685 - binary_accuracy: 0.9743 - precision: 0.9918 - recall: 0.9733 - val_loss: 2.6336 - val_binary_accuracy: 0.7888 - val_precision: 0.7801 - val_recall: 0.9987
# Epoch 17/100
# 17/17 - 138s - loss: 0.0698 - binary_accuracy: 0.9738 - precision: 0.9925 - recall: 0.9720 - val_loss: 0.3847 - val_binary_accuracy: 0.9138 - val_precision: 1.0000 - val_recall: 0.8846
# Epoch 18/100
# 17/17 - 139s - loss: 0.0564 - binary_accuracy: 0.9790 - precision: 0.9935 - recall: 0.9781 - val_loss: 0.3523 - val_binary_accuracy: 0.9157 - val_precision: 1.0000 - val_recall: 0.8872
# Epoch 19/100
# 17/17 - 138s - loss: 0.0493 - binary_accuracy: 0.9810 - precision: 0.9935 - recall: 0.9807 - val_loss: 0.2102 - val_binary_accuracy: 0.9622 - val_precision: 0.9610 - val_recall: 0.9896
# Epoch 20/100
# 17/17 - 137s - loss: 0.0437 - binary_accuracy: 0.9850 - precision: 0.9955 - recall: 0.9843 - val_loss: 0.2064 - val_binary_accuracy: 0.9641 - val_precision: 0.9959 - val_recall: 0.9559
# Epoch 21/100
# 17/17 - 139s - loss: 0.0462 - binary_accuracy: 0.9833 - precision: 0.9948 - recall: 0.9826 - val_loss: 0.6057 - val_binary_accuracy: 0.8876 - val_precision: 0.9985 - val_recall: 0.8508
# Epoch 22/100
# 17/17 - 137s - loss: 0.0388 - binary_accuracy: 0.9862 - precision: 0.9955 - recall: 0.9859 - val_loss: 1.4625 - val_binary_accuracy: 0.8227 - val_precision: 0.8095 - val_recall: 0.9974
# Epoch 23/100
# 17/17 - 140s - loss: 0.0516 - binary_accuracy: 0.9798 - precision: 0.9951 - recall: 0.9775 - val_loss: 0.1040 - val_binary_accuracy: 0.9651 - val_precision: 0.9565 - val_recall: 0.9987
# Epoch 24/100
# 17/17 - 138s - loss: 0.0478 - binary_accuracy: 0.9817 - precision: 0.9948 - recall: 0.9804 - val_loss: 0.3620 - val_binary_accuracy: 0.8973 - val_precision: 0.9985 - val_recall: 0.8638
# Epoch 25/100
# 17/17 - 140s - loss: 0.0432 - binary_accuracy: 0.9826 - precision: 0.9958 - recall: 0.9807 - val_loss: 2.8007 - val_binary_accuracy: 0.8266 - val_precision: 0.8116 - val_recall: 1.0000
# Epoch 26/100
# 17/17 - 138s - loss: 0.0378 - binary_accuracy: 0.9860 - precision: 0.9958 - recall: 0.9852 - val_loss: 0.1984 - val_binary_accuracy: 0.9641 - val_precision: 0.9986 - val_recall: 0.9533
# Epoch 27/100
# 17/17 - 139s - loss: 0.0509 - binary_accuracy: 0.9826 - precision: 0.9948 - recall: 0.9817 - val_loss: 0.2756 - val_binary_accuracy: 0.9574 - val_precision: 0.9919 - val_recall: 0.9507
# Epoch 28/100
# 17/17 - 138s - loss: 0.0369 - binary_accuracy: 0.9843 - precision: 0.9961 - recall: 0.9826 - val_loss: 0.1419 - val_binary_accuracy: 0.9593 - val_precision: 0.9986 - val_recall: 0.9468
# Epoch 29/100
# 17/17 - 138s - loss: 0.0343 - binary_accuracy: 0.9888 - precision: 0.9971 - recall: 0.9878 - val_loss: 0.4544 - val_binary_accuracy: 0.8866 - val_precision: 1.0000 - val_recall: 0.8482
# Epoch 30/100
# 17/17 - 138s - loss: 0.0264 - binary_accuracy: 0.9895 - precision: 0.9968 - recall: 0.9891 - val_loss: 0.1139 - val_binary_accuracy: 0.9632 - val_precision: 0.9542 - val_recall: 0.9987
# Epoch 31/100
# 17/17 - 138s - loss: 0.0266 - binary_accuracy: 0.9893 - precision: 0.9974 - recall: 0.9881 - val_loss: 0.3120 - val_binary_accuracy: 0.9196 - val_precision: 1.0000 - val_recall: 0.8923
# Epoch 32/100
# 17/17 - 140s - loss: 0.0329 - binary_accuracy: 0.9867 - precision: 0.9961 - recall: 0.9859 - val_loss: 0.9952 - val_binary_accuracy: 0.8924 - val_precision: 0.8741 - val_recall: 1.0000
# Epoch 33/100
# 17/17 - 138s - loss: 0.0351 - binary_accuracy: 0.9874 - precision: 0.9964 - recall: 0.9865 - val_loss: 0.1445 - val_binary_accuracy: 0.9700 - val_precision: 0.9830 - val_recall: 0.9767
# 5/5 [==============================] - 8s 1s/step - loss: 0.1040 - binary_accuracy: 0.9651 - precision: 0.9565 - recall: 0.9987
# Eval on validation: [0.10404057800769806, 0.9651162624359131, 0.95652174949646, 0.9987030029296875]

# %% [markdown]
# ## Visualizing model performance
#
# Let's plot the model accuracy and loss for the training and the validating set. Note that
# no random seed is specified for this notebook. For your notebook, there might be slight
# variance.

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(["precision", "recall", "binary_accuracy", "loss"]):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history["val_" + met])
    ax[i].set_title("Model {}".format(met))
    ax[i].set_xlabel("epochs")
    ax[i].set_ylabel(met)
    ax[i].legend(["train", "val"])

# %% [markdown]
# We see that the accuracy for our model is around 95%.

# %% [markdown]
# ## Predict and evaluate results
#
# Let's evaluate the model on our test data!

# %%
model.evaluate(test_ds, return_dict=True)
# Out:
# 3/3 [==============================] - 9s 2s/step - loss: 2.1931 - binary_accuracy: 0.6891 - precision: 0.6684 - recall: 0.9974
# {'binary_accuracy': 0.6891025900840759,
#  'loss': 2.1930882930755615,
#  'precision': 0.668384850025177,
#  'recall': 0.9974358677864075}

# %% [markdown]
# We see that our accuracy on our test data is lower than the accuracy for our validating
# set. This may indicate overfitting.
#
# Our recall is greater than our precision, indicating that almost all pneumonia images are
# correctly identified but some normal images are falsely identified. We should aim to
# increase our precision.

# %%
for image, label in test_ds.take(1):
    plt.imshow(image[0] / 255.0)
    plt.title(CLASS_NAMES[label[0].numpy()])

prediction = model.predict(test_ds.take(1))[0]
scores = [1 - prediction, prediction]

for score, name in zip(scores, CLASS_NAMES):
    print("This image is %.2f percent %s" % ((100 * score), name))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   This is separate from the ipykernel package so we can avoid doing imports until
# This image is 0.07 percent NORMAL
# This image is 99.93 percent PNEUMONIA

# %% [markdown]
# # WedgeDropout2D

# %% [markdown]
# Install WedgeDropout2D

# %%
# !pip uninstall -y keras-wedge-dropout
# !pip install -q git+https://github.com/LanceNorskog/keras-wedge.git
from keras_wedge_dropout import WedgeDropout2D

# %% [markdown]
# Define a variant of the above model that replaces the Dropout layer right after the final set of feature maps with a WedgeDropout2D layer. This layer examines the fully realized feature maps and applies negative feedback when randomly chosen pairs are too similar.

# %%
def dense_block_wedge(units, dropout_rate, inputs, bn=True):
    x = layers.Dense(units, activation="relu")(inputs)
    if bn:
        x = layers.BatchNormalization()(x)
    outputs = layers.Dropout(dropout_rate)(x)

    return outputs

def build_model_wedge():
    inputs = keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
    x = preprocessing.Rescaling(1.0 / 255)(inputs)
    x = layers.Conv2D(16, 3, activation="relu", padding="same")(x)
    x = layers.Conv2D(16, 3, activation="relu", padding="same")(x)
    x = layers.MaxPool2D()(x)

    x = conv_block(32, x)
    x = conv_block(64, x)

    x = conv_block(128, x)
    x = layers.Dropout(0.2)(x)

    x = conv_block(256, x)

    x = WedgeDropout2D(similarity=0.65, batchwise=True)(x)

    # x = layers.Dropout(0.2)(x)

    x = layers.Flatten()(x)
    x = dense_block_wedge(512, 0.7, x, False)
    x = dense_block_wedge(128, 0.5, x, False)
    x = dense_block_wedge(64, 0.3, x)

    outputs = layers.Dense(1, activation="sigmoid")(x)

    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# Train the new model exactly the same way as the original model

# %%
with strategy.scope():
    model = build_model_wedge()

    METRICS = [
        tf.keras.metrics.BinaryAccuracy(),
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall"),
    ]
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
        loss="binary_crossentropy",
        metrics=METRICS,
    )

history = model.fit(
    train_ds,
    epochs=100,
    validation_data=val_ds,
    class_weight=class_weight,
    callbacks=[checkpoint_cb, early_stopping_cb],
    verbose=2
)
print('Eval on validation:', model.evaluate(val_ds))
# Out:
# WedgeDropout2D.build: input_shape: (None, 5, 5, 256)
# Epoch 1/100
# 17/17 - 145s - loss: 0.4590 - binary_accuracy: 0.7964 - precision: 0.9306 - recall: 0.7837 - val_loss: 27.2944 - val_binary_accuracy: 0.2529 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 17/17 - 136s - loss: 0.2923 - binary_accuracy: 0.8929 - precision: 0.9609 - recall: 0.8917 - val_loss: 19.7894 - val_binary_accuracy: 0.2529 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/100
# 17/17 - 138s - loss: 0.2184 - binary_accuracy: 0.9114 - precision: 0.9810 - recall: 0.8978 - val_loss: 0.4339 - val_binary_accuracy: 0.7984 - val_precision: 0.9947 - val_recall: 0.7341
# Epoch 4/100
# 17/17 - 135s - loss: 0.1856 - binary_accuracy: 0.9302 - precision: 0.9793 - recall: 0.9254 - val_loss: 2.6583 - val_binary_accuracy: 0.2607 - val_precision: 1.0000 - val_recall: 0.0104
# Epoch 5/100
# 17/17 - 137s - loss: 0.1454 - binary_accuracy: 0.9436 - precision: 0.9819 - recall: 0.9412 - val_loss: 1.8677 - val_binary_accuracy: 0.7471 - val_precision: 0.7471 - val_recall: 1.0000
# Epoch 6/100
# 17/17 - 139s - loss: 0.1540 - binary_accuracy: 0.9417 - precision: 0.9809 - recall: 0.9396 - val_loss: 2.4169 - val_binary_accuracy: 0.7471 - val_precision: 0.7471 - val_recall: 1.0000
# Epoch 7/100
# 17/17 - 137s - loss: 0.1534 - binary_accuracy: 0.9340 - precision: 0.9823 - recall: 0.9277 - val_loss: 2.0081 - val_binary_accuracy: 0.7471 - val_precision: 0.7471 - val_recall: 1.0000
# Epoch 8/100
# 17/17 - 136s - loss: 0.1221 - binary_accuracy: 0.9505 - precision: 0.9859 - recall: 0.9467 - val_loss: 2.5293 - val_binary_accuracy: 0.7471 - val_precision: 0.7471 - val_recall: 1.0000
# Epoch 9/100
# 17/17 - 138s - loss: 0.1129 - binary_accuracy: 0.9557 - precision: 0.9886 - recall: 0.9512 - val_loss: 4.4783 - val_binary_accuracy: 0.7471 - val_precision: 0.7471 - val_recall: 1.0000
# Epoch 10/100
# 17/17 - 138s - loss: 0.1023 - binary_accuracy: 0.9588 - precision: 0.9842 - recall: 0.9598 - val_loss: 2.0734 - val_binary_accuracy: 0.7471 - val_precision: 0.7471 - val_recall: 1.0000
# Epoch 11/100
# 17/17 - 136s - loss: 0.1001 - binary_accuracy: 0.9631 - precision: 0.9891 - recall: 0.9608 - val_loss: 0.4071 - val_binary_accuracy: 0.8479 - val_precision: 0.8315 - val_recall: 0.9987
# Epoch 12/100
# 17/17 - 137s - loss: 0.0990 - binary_accuracy: 0.9626 - precision: 0.9871 - recall: 0.9621 - val_loss: 2.5975 - val_binary_accuracy: 0.7471 - val_precision: 0.7471 - val_recall: 1.0000
# Epoch 13/100
# 17/17 - 139s - loss: 0.0896 - binary_accuracy: 0.9655 - precision: 0.9911 - recall: 0.9621 - val_loss: 2.3426 - val_binary_accuracy: 0.7471 - val_precision: 0.7471 - val_recall: 1.0000
# Epoch 14/100
# 17/17 - 136s - loss: 0.0862 - binary_accuracy: 0.9662 - precision: 0.9898 - recall: 0.9643 - val_loss: 2.2731 - val_binary_accuracy: 0.7471 - val_precision: 0.7471 - val_recall: 1.0000
# Epoch 15/100
# 17/17 - 136s - loss: 0.0706 - binary_accuracy: 0.9710 - precision: 0.9911 - recall: 0.9695 - val_loss: 0.1354 - val_binary_accuracy: 0.9651 - val_precision: 0.9933 - val_recall: 0.9598
# Epoch 16/100
# 17/17 - 137s - loss: 0.0833 - binary_accuracy: 0.9657 - precision: 0.9901 - recall: 0.9634 - val_loss: 0.9864 - val_binary_accuracy: 0.8275 - val_precision: 0.8144 - val_recall: 0.9961
# Epoch 17/100
# 17/17 - 138s - loss: 0.0837 - binary_accuracy: 0.9645 - precision: 0.9881 - recall: 0.9637 - val_loss: 1.8471 - val_binary_accuracy: 0.7248 - val_precision: 1.0000 - val_recall: 0.6316
# Epoch 18/100
# 17/17 - 138s - loss: 0.0670 - binary_accuracy: 0.9760 - precision: 0.9931 - recall: 0.9743 - val_loss: 0.0935 - val_binary_accuracy: 0.9738 - val_precision: 0.9806 - val_recall: 0.9844
# Epoch 19/100
# 17/17 - 137s - loss: 0.0476 - binary_accuracy: 0.9836 - precision: 0.9951 - recall: 0.9826 - val_loss: 0.1571 - val_binary_accuracy: 0.9661 - val_precision: 0.9646 - val_recall: 0.9909
# Epoch 20/100
# 17/17 - 138s - loss: 0.0493 - binary_accuracy: 0.9810 - precision: 0.9945 - recall: 0.9798 - val_loss: 0.2086 - val_binary_accuracy: 0.9603 - val_precision: 0.9906 - val_recall: 0.9559
# Epoch 21/100
# 17/17 - 136s - loss: 0.0494 - binary_accuracy: 0.9790 - precision: 0.9964 - recall: 0.9753 - val_loss: 0.5996 - val_binary_accuracy: 0.9021 - val_precision: 0.8851 - val_recall: 0.9987
# Epoch 22/100
# 17/17 - 137s - loss: 0.0558 - binary_accuracy: 0.9790 - precision: 0.9932 - recall: 0.9785 - val_loss: 0.3240 - val_binary_accuracy: 0.9545 - val_precision: 0.9641 - val_recall: 0.9754
# Epoch 23/100
# 17/17 - 137s - loss: 0.0604 - binary_accuracy: 0.9779 - precision: 0.9944 - recall: 0.9756 - val_loss: 0.1669 - val_binary_accuracy: 0.9651 - val_precision: 0.9599 - val_recall: 0.9948
# Epoch 24/100
# 17/17 - 138s - loss: 0.0527 - binary_accuracy: 0.9798 - precision: 0.9948 - recall: 0.9778 - val_loss: 0.2470 - val_binary_accuracy: 0.9486 - val_precision: 0.9972 - val_recall: 0.9339
# Epoch 25/100
# 17/17 - 138s - loss: 0.0602 - binary_accuracy: 0.9769 - precision: 0.9935 - recall: 0.9753 - val_loss: 0.1582 - val_binary_accuracy: 0.9593 - val_precision: 0.9959 - val_recall: 0.9494
# Epoch 26/100
# 17/17 - 138s - loss: 0.0512 - binary_accuracy: 0.9781 - precision: 0.9922 - recall: 0.9781 - val_loss: 0.4940 - val_binary_accuracy: 0.9089 - val_precision: 1.0000 - val_recall: 0.8781
# Epoch 27/100
# 17/17 - 140s - loss: 0.0459 - binary_accuracy: 0.9829 - precision: 0.9945 - recall: 0.9823 - val_loss: 4.0479 - val_binary_accuracy: 0.7791 - val_precision: 0.7718 - val_recall: 1.0000
# Epoch 28/100
# 17/17 - 138s - loss: 0.0512 - binary_accuracy: 0.9812 - precision: 0.9938 - recall: 0.9807 - val_loss: 0.9772 - val_binary_accuracy: 0.8324 - val_precision: 1.0000 - val_recall: 0.7756
# 5/5 [==============================] - 8s 1s/step - loss: 0.0935 - binary_accuracy: 0.9738 - precision: 0.9806 - recall: 0.9844
# Eval on validation: [0.09354524314403534, 0.9738371968269348, 0.9806201457977295, 0.9844357967376709]

# %% [markdown]
# And evaluate again!

# %%
model.evaluate(test_ds, return_dict=True)
# Out:
# 3/3 [==============================] - 8s 1s/step - loss: 2.0190 - binary_accuracy: 0.7324 - precision: 0.7031 - recall: 0.9897
# {'binary_accuracy': 0.7323718070983887,
#  'loss': 2.0190396308898926,
#  'precision': 0.7030965685844421,
#  'recall': 0.9897435903549194}
