# %% [markdown]
# # Image classification via fine-tuning with EfficientNet
#
# **Author:** [Yixing Fu](https://github.com/yixingfu)<br>
# **Date created:** 2020/06/30<br>
# **Last modified:** 2020/07/16<br>
# **Description:** Use EfficientNet with weights pre-trained on imagenet for Stanford Dogs classification.

# %% [markdown]
# ## Introduction: what is EfficientNet
#
# EfficientNet, first introduced in [Tan and Le, 2019](https://arxiv.org/abs/1905.11946)
# is among the most efficient models (i.e. requiring least FLOPS for inference)
# that reaches State-of-the-Art accuracy on both
# imagenet and common image classification transfer learning tasks.
#
# The smallest base model is similar to [MnasNet](https://arxiv.org/abs/1807.11626), which
# reached near-SOTA with a significantly smaller model. By introducing a heuristic way to
# scale the model, EfficientNet provides a family of models (B0 to B7) that represents a
# good combination of efficiency and accuracy on a variety of scales. Such a scaling
# heuristics (compound-scaling, details see
# [Tan and Le, 2019](https://arxiv.org/abs/1905.11946)) allows the
# efficiency-oriented base model (B0) to surpass models at every scale, while avoiding
# extensive grid-search of hyperparameters.
#
# A summary of the latest updates on the model is available at
# [here](https://github.com/tensorflow/tpu/tree/master/models/official/efficientnet), where various
# augmentation schemes and semi-supervised learning approaches are applied to further
# improve the imagenet performance of the models. These extensions of the model can be used
# by updating weights without changing model architecture.
#
# ## B0 to B7 variants of EfficientNet
#
# *(This section provides some details on "compound scaling", and can be skipped
# if you're only interested in using the models)*
#
# Based on the [original paper](https://arxiv.org/abs/1905.11946) people may have the
# impression that EfficientNet is a continuous family of models created by arbitrarily
# choosing scaling factor in as Eq.(3) of the paper.  However, choice of resolution,
# depth and width are also restricted by many factors:
#
# - Resolution: Resolutions not divisible by 8, 16, etc. cause zero-padding near boundaries
# of some layers which wastes computational resources. This especially applies to smaller
# variants of the model, hence the input resolution for B0 and B1 are chosen as 224 and
# 240.
#
# - Depth and width: The building blocks of EfficientNet demands channel size to be
# multiples of 8.
#
# - Resource limit: Memory limitation may bottleneck resolution when depth
# and width can still increase. In such a situation, increasing depth and/or
# width but keep resolution can still improve performance.
#
# As a result, the depth, width and resolution of each variant of the EfficientNet models
# are hand-picked and proven to produce good results, though they may be significantly
# off from the compound scaling formula.
# Therefore, the keras implementation (detailed below) only provide these 8 models, B0 to B7,
# instead of allowing arbitray choice of width / depth / resolution parameters.
#
# ## Keras implementation of EfficientNet
#
# An implementation of EfficientNet B0 to B7 has been shipped with tf.keras since TF2.3. To
# use EfficientNetB0 for classifying 1000 classes of images from imagenet, run:
#
# ```python
# from tensorflow.keras.applications import EfficientNetB0
# model = EfficientNetB0(weights='imagenet')
# ```
#
# This model takes input images of shape (224, 224, 3), and the input data should range
# [0, 255]. Normalization is included as part of the model.
#
# Because training EfficientNet on ImageNet takes a tremendous amount of resources and
# several techniques that are not a part of the model architecture itself. Hence the Keras
# implementation by default loads pre-trained weights obtained via training with
# [AutoAugment](https://arxiv.org/abs/1805.09501).
#
# For B0 to B7 base models, the input shapes are different. Here is a list of input shape
# expected for each model:
#
# | Base model | resolution|
# |----------------|-----|
# | EfficientNetB0 | 224 |
# | EfficientNetB1 | 240 |
# | EfficientNetB2 | 260 |
# | EfficientNetB3 | 300 |
# | EfficientNetB4 | 380 |
# | EfficientNetB5 | 456 |
# | EfficientNetB6 | 528 |
# | EfficientNetB7 | 600 |
#
# When the model is intended for transfer learning, the Keras implementation
# provides a option to remove the top layers:
# ```
# model = EfficientNetB0(include_top=False, weights='imagenet')
# ```
# This option excludes the final `Dense` layer that turns 1280 features on the penultimate
# layer into prediction of the 1000 ImageNet classes. Replacing the top layer with custom
# layers allows using EfficientNet as a feature extractor in a transfer learning workflow.
#
# Another argument in the model constructor worth noticing is `drop_connect_rate` which controls
# the dropout rate responsible for [stochastic depth](https://arxiv.org/abs/1603.09382).
# This parameter serves as a toggle for extra regularization in finetuning, but does not
# affect loaded weights. For example, when stronger regularization is desired, try:
#
# ```python
# model = EfficientNetB0(weights='imagenet', drop_connect_rate=0.4)
# ```
# The default value is 0.2.
#
# ## Example: EfficientNetB0 for Stanford Dogs.
#
# EfficientNet is capable of a wide range of image classification tasks.
# This makes it a good model for transfer learning.
# As an end-to-end example, we will show using pre-trained EfficientNetB0 on
# [Stanford Dogs](http://vision.stanford.edu/aditya86/ImageNetDogs/main.html) dataset.

# %%
# IMG_SIZE is determined by EfficientNet model choice
IMG_SIZE = 224

# %% [markdown]
# ## Setup and data loading
#
# This example requires TensorFlow 2.3 or above.
#
# To use TPU, the TPU runtime must match current running TensorFlow
# version. If there is a mismatch, try:
#
# ```python
# from cloud_tpu_client import Client
# c = Client()
# c.configure_tpu_version(tf.__version__, restart_type="always")
# ```

# %%
import tensorflow as tf

try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection
    print("Running on TPU ", tpu.cluster_spec().as_dict()["worker"])
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except ValueError:
    print("Not connected to a TPU runtime. Using CPU/GPU strategy")
    strategy = tf.distribute.MirroredStrategy()
# Out:
# Not connected to a TPU runtime. Using CPU/GPU strategy
# WARNING:tensorflow:Collective ops is not configured at program startup. Some performance features may not be enabled.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %% [markdown]
# ### Loading data
#
# Here we load data from [tensorflow_datasets](https://www.tensorflow.org/datasets)
# (hereafter TFDS).
# Stanford Dogs dataset is provided in
# TFDS as [stanford_dogs](https://www.tensorflow.org/datasets/catalog/stanford_dogs).
# It features 20,580 images that belong to 120 classes of dog breeds
# (12,000 for training and 8,580 for testing).
#
# By simply changing `dataset_name` below, you may also try this notebook for
# other datasets in TFDS such as
# [cifar10](https://www.tensorflow.org/datasets/catalog/cifar10),
# [cifar100](https://www.tensorflow.org/datasets/catalog/cifar100),
# [food101](https://www.tensorflow.org/datasets/catalog/food101),
# etc. When the images are much smaller than the size of EfficientNet input,
# we can simply upsample the input images. It has been shown in
# [Tan and Le, 2019](https://arxiv.org/abs/1905.11946) that transfer learning
# result is better for increased resolution even if input images remain small.
#
# For TPU: if using TFDS datasets,
# a [GCS bucket](https://cloud.google.com/storage/docs/key-terms#buckets)
# location is required to save the datasets. For example:
#
# ```python
# tfds.load(dataset_name, data_dir="gs://example-bucket/datapath")
# ```
#
# Also, both the current environment and the TPU service account have
# proper [access](https://cloud.google.com/tpu/docs/storage-buckets#authorize_the_service_account)
# to the bucket. Alternatively, for small datasets you may try loading data
# into the memory and use `tf.data.Dataset.from_tensor_slices()`.

# %%
import tensorflow_datasets as tfds

batch_size = 64

dataset_name = "stanford_dogs"
(ds_train, ds_test), ds_info = tfds.load(
    dataset_name, split=["train", "test"], with_info=True, as_supervised=True
)
NUM_CLASSES = ds_info.features["label"].num_classes

# %% [markdown]
# When the dataset include images with various size, we need to resize them into a
# shared size. The Stanford Dogs dataset includes only images at least 200x200
# pixels in size. Here we resize the images to the input size needed for EfficientNet.

# %%
size = (IMG_SIZE, IMG_SIZE)
ds_train = ds_train.map(lambda image, label: (tf.image.resize(image, size), label))
ds_test = ds_test.map(lambda image, label: (tf.image.resize(image, size), label))

# %% [markdown]
# ### Visualizing the data
#
# The following code shows the first 9 images with their labels.

# %%
import matplotlib.pyplot as plt


def format_label(label):
    string_label = label_info.int2str(label)
    return string_label.split("-")[1]


label_info = ds_info.features["label"]
for i, (image, label) in enumerate(ds_train.take(9)):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image.numpy().astype("uint8"))
    plt.title("{}".format(format_label(label)))
    plt.axis("off")

# %% [markdown]
# ### Data augmentation
#
# We can use preprocessing layers APIs for image augmentation.

# %%
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

img_augmentation = Sequential(
    [
        preprocessing.RandomRotation(factor=0.15),
        preprocessing.RandomTranslation(height_factor=0.1, width_factor=0.1),
        preprocessing.RandomFlip(),
        preprocessing.RandomContrast(factor=0.1),
    ],
    name="img_augmentation",
)

# %% [markdown]
# This `Sequential` model object can be used both as a part of
# the model we later build, and as a function to preprocess
# data before feeding into the model. Using them as function makes
# it easy to visualize the augmented images. Here we plot 9 examples
# of augmentation result of a given figure.

# %%
for image, label in ds_train.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        aug_img = img_augmentation(tf.expand_dims(image, axis=0))
        plt.imshow(aug_img[0].numpy().astype("uint8"))
        plt.title("{}".format(format_label(label)))
        plt.axis("off")

# %% [markdown]
# ### Prepare inputs
#
# Once we verify the input data and augmentation are working correctly,
# we prepare dataset for training. The input data are resized to uniform
# `IMG_SIZE`. The labels are put into one-hot
# (a.k.a. categorical) encoding. The dataset is batched.
#
# Note: `prefetch` and `AUTOTUNE` may in some situation improve
# performance, but depends on environment and the specific dataset used.
# See this [guide](https://www.tensorflow.org/guide/data_performance)
# for more information on data pipeline performance.

# %%
# One-hot / categorical encoding
def input_preprocess(image, label):
    label = tf.one_hot(label, NUM_CLASSES)
    return image, label


ds_train = ds_train.map(
    input_preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE
)
ds_train = ds_train.batch(batch_size=batch_size, drop_remainder=True)
ds_train = ds_train.prefetch(tf.data.experimental.AUTOTUNE)

ds_test = ds_test.map(input_preprocess)
ds_test = ds_test.batch(batch_size=batch_size, drop_remainder=True)

# %% [markdown]
# ## Training a model from scratch
#
# We build an EfficientNetB0 with 120 output classes, that is initialized from scratch:
#
# Note: the accuracy will increase very slowly and may overfit.

# %%
from tensorflow.keras.applications import EfficientNetB0

with strategy.scope():
    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = img_augmentation(inputs)
    outputs = EfficientNetB0(include_top=True, weights=None, classes=NUM_CLASSES)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(
        optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"]
    )

model.summary()

epochs = 1  # @param {type: "slider", min:1, max:100}
hist = model.fit(ds_train, epochs=epochs, validation_data=ds_test, verbose=2)
print('Evaluate:', model.evaluate(ds_test))
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# img_augmentation (Sequential (None, 224, 224, 3)       0
# _________________________________________________________________
# efficientnetb0 (Functional)  (None, 120)               4203291
# =================================================================
# Total params: 4,203,291
# Trainable params: 4,161,268
# Non-trainable params: 42,023
# _________________________________________________________________
# 187/187 - 102s - loss: 4.9779 - accuracy: 0.0114 - val_loss: 4.9951 - val_accuracy: 0.0112
# 134/134 [==============================] - 14s 107ms/step - loss: 4.9951 - accuracy: 0.0112
# Evaluate: [4.995072364807129, 0.011194029822945595]

# %% [markdown]
# Training the model is relatively fast (takes only 20 seconds per epoch on TPUv2 that is
# available on Colab). This might make it sounds easy to simply train EfficientNet on any
# dataset wanted from scratch. However, training EfficientNet on smaller datasets,
# especially those with lower resolution like CIFAR-100, faces the significant challenge of
# overfitting.
#
# Hence training from scratch requires very careful choice of hyperparameters and is
# difficult to find suitable regularization. It would also be much more demanding in resources.
# Plotting the training and validation accuracy
# makes it clear that validation accuracy stagnates at a low value.

# %%
import matplotlib.pyplot as plt


def plot_hist(hist):
    plt.plot(hist.history["accuracy"])
    plt.plot(hist.history["val_accuracy"])
    plt.title("model accuracy")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.legend(["train", "validation"], loc="upper left")
    plt.show()


plot_hist(hist)

# %% [markdown]
# ## Transfer learning from pre-trained weights
#
# Here we initialize the model with pre-trained ImageNet weights,
# and we fine-tune it on our own dataset.

# %%
from tensorflow.keras.layers.experimental import preprocessing


def build_model(num_classes, use_wedge_dropout=False, lr=1e-2, similarity=0.65):
    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = img_augmentation(inputs)
    model = EfficientNetB0(include_top=False, input_tensor=x, weights="imagenet")

    # Freeze the pretrained weights
    model.trainable = False

    # Rebuild top
    if use_wedge_dropout:
        # x = layers.BatchNormalization()(x)
        x = WedgeDropout2D(similarity=similarity, batchwise=True, name="top_wedge")(x)
        x = layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
    else:
        x = layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
        x = layers.BatchNormalization()(x)
        top_dropout_rate = 0.2
        x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)
    outputs = layers.Dense(NUM_CLASSES, activation="softmax", name="pred")(x)

    # Compile
    model = tf.keras.Model(inputs, outputs, name="EfficientNet")
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(
        optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"]
    )
    return model

# %% [markdown]
# The first step to transfer learning is to freeze all layers and train only the top
# layers. For this step, a relatively large learning rate (1e-2) can be used.
# Note that validation accuracy and loss will usually be better than training
# accuracy and loss. This is because the regularization is strong, which only
# suppresses training-time metrics.
#
# Note that the convergence may take up to 50 epochs depending on choice of learning rate.
# If image augmentation layers were not
# applied, the validation accuracy may only reach ~60%.

# %%
with strategy.scope():
    model = build_model(num_classes=NUM_CLASSES, lr=1e-4)

earlystopping = tf.keras.callbacks.EarlyStopping(patience=15, restore_best_weights=True)

epochs = 80  # @param {type: "slider", min:8, max:80}
hist = model.fit(ds_train, epochs=epochs, validation_data=ds_test, verbose=2, callbacks=[earlystopping])
print('Evaluate:', model.evaluate(ds_test))
plot_hist(hist)
# Out:
# Epoch 1/80
# 187/187 - 44s - loss: 5.0006 - accuracy: 0.0383 - val_loss: 3.7517 - val_accuracy: 0.1899
# Epoch 2/80
# 187/187 - 34s - loss: 3.7155 - accuracy: 0.1640 - val_loss: 2.4607 - val_accuracy: 0.4248
# Epoch 3/80
# 187/187 - 35s - loss: 3.0402 - accuracy: 0.2682 - val_loss: 1.7566 - val_accuracy: 0.5584
# Epoch 4/80
# 187/187 - 34s - loss: 2.6404 - accuracy: 0.3429 - val_loss: 1.3996 - val_accuracy: 0.6353
# Epoch 5/80
# 187/187 - 35s - loss: 2.4187 - accuracy: 0.3853 - val_loss: 1.1967 - val_accuracy: 0.6784
# Epoch 6/80
# 187/187 - 34s - loss: 2.2166 - accuracy: 0.4233 - val_loss: 1.0665 - val_accuracy: 0.7011
# Epoch 7/80
# 187/187 - 36s - loss: 2.0836 - accuracy: 0.4530 - val_loss: 0.9687 - val_accuracy: 0.7248
# Epoch 8/80
# 187/187 - 35s - loss: 2.0103 - accuracy: 0.4703 - val_loss: 0.9026 - val_accuracy: 0.7393
# Epoch 9/80
# 187/187 - 41s - loss: 1.9086 - accuracy: 0.4893 - val_loss: 0.8535 - val_accuracy: 0.7501
# Epoch 10/80
# 187/187 - 35s - loss: 1.8242 - accuracy: 0.5109 - val_loss: 0.8130 - val_accuracy: 0.7591
# Epoch 11/80
# 187/187 - 36s - loss: 1.7790 - accuracy: 0.5260 - val_loss: 0.7863 - val_accuracy: 0.7657
# Epoch 12/80
# 187/187 - 34s - loss: 1.7320 - accuracy: 0.5273 - val_loss: 0.7627 - val_accuracy: 0.7705
# Epoch 13/80
# 187/187 - 36s - loss: 1.6688 - accuracy: 0.5478 - val_loss: 0.7402 - val_accuracy: 0.7740
# Epoch 14/80
# 187/187 - 34s - loss: 1.6222 - accuracy: 0.5546 - val_loss: 0.7205 - val_accuracy: 0.7826
# Epoch 15/80
# 187/187 - 35s - loss: 1.5955 - accuracy: 0.5626 - val_loss: 0.7125 - val_accuracy: 0.7823
# Epoch 16/80
# 187/187 - 35s - loss: 1.5477 - accuracy: 0.5706 - val_loss: 0.6962 - val_accuracy: 0.7891
# Epoch 17/80
# 187/187 - 36s - loss: 1.5342 - accuracy: 0.5775 - val_loss: 0.6843 - val_accuracy: 0.7901
# Epoch 18/80
# 187/187 - 35s - loss: 1.4879 - accuracy: 0.5906 - val_loss: 0.6759 - val_accuracy: 0.7921
# Epoch 19/80
# 187/187 - 35s - loss: 1.4828 - accuracy: 0.5892 - val_loss: 0.6683 - val_accuracy: 0.7928
# Epoch 20/80
# 187/187 - 35s - loss: 1.4418 - accuracy: 0.6000 - val_loss: 0.6602 - val_accuracy: 0.7963
# Epoch 21/80
# 187/187 - 36s - loss: 1.4376 - accuracy: 0.5972 - val_loss: 0.6521 - val_accuracy: 0.7989
# Epoch 22/80
# 187/187 - 34s - loss: 1.3901 - accuracy: 0.6065 - val_loss: 0.6433 - val_accuracy: 0.8010
# Epoch 23/80
# 187/187 - 36s - loss: 1.3743 - accuracy: 0.6122 - val_loss: 0.6385 - val_accuracy: 0.8042
# Epoch 24/80
# 187/187 - 34s - loss: 1.3663 - accuracy: 0.6204 - val_loss: 0.6369 - val_accuracy: 0.8028
# Epoch 25/80
# 187/187 - 36s - loss: 1.3301 - accuracy: 0.6254 - val_loss: 0.6324 - val_accuracy: 0.8039
# Epoch 26/80
# 187/187 - 36s - loss: 1.3289 - accuracy: 0.6232 - val_loss: 0.6253 - val_accuracy: 0.8047
# Epoch 27/80
# 187/187 - 35s - loss: 1.2943 - accuracy: 0.6324 - val_loss: 0.6216 - val_accuracy: 0.8082
# Epoch 28/80
# 187/187 - 35s - loss: 1.2839 - accuracy: 0.6388 - val_loss: 0.6208 - val_accuracy: 0.8070
# Epoch 29/80
# 187/187 - 35s - loss: 1.2683 - accuracy: 0.6405 - val_loss: 0.6165 - val_accuracy: 0.8070
# Epoch 30/80
# 187/187 - 35s - loss: 1.2634 - accuracy: 0.6461 - val_loss: 0.6168 - val_accuracy: 0.8085
# Epoch 31/80
# 187/187 - 35s - loss: 1.2243 - accuracy: 0.6497 - val_loss: 0.6149 - val_accuracy: 0.8078
# Epoch 32/80
# 187/187 - 34s - loss: 1.2042 - accuracy: 0.6584 - val_loss: 0.6143 - val_accuracy: 0.8088
# Epoch 33/80
# 187/187 - 36s - loss: 1.2193 - accuracy: 0.6532 - val_loss: 0.6123 - val_accuracy: 0.8077
# Epoch 34/80
# 187/187 - 36s - loss: 1.2017 - accuracy: 0.6589 - val_loss: 0.6095 - val_accuracy: 0.8091
# Epoch 35/80
# 187/187 - 35s - loss: 1.1906 - accuracy: 0.6593 - val_loss: 0.6087 - val_accuracy: 0.8097
# Epoch 36/80
# 187/187 - 36s - loss: 1.1730 - accuracy: 0.6587 - val_loss: 0.6068 - val_accuracy: 0.8109
# Epoch 37/80
# 187/187 - 35s - loss: 1.1517 - accuracy: 0.6699 - val_loss: 0.6018 - val_accuracy: 0.8119
# Epoch 38/80
# 187/187 - 35s - loss: 1.1521 - accuracy: 0.6719 - val_loss: 0.6023 - val_accuracy: 0.8119
# Epoch 39/80
# 187/187 - 35s - loss: 1.1487 - accuracy: 0.6671 - val_loss: 0.6003 - val_accuracy: 0.8139
# Epoch 40/80
# 187/187 - 35s - loss: 1.1079 - accuracy: 0.6794 - val_loss: 0.5997 - val_accuracy: 0.8122
# Epoch 41/80
# 187/187 - 35s - loss: 1.0962 - accuracy: 0.6803 - val_loss: 0.5988 - val_accuracy: 0.8111
# Epoch 42/80
# 187/187 - 35s - loss: 1.0986 - accuracy: 0.6776 - val_loss: 0.5965 - val_accuracy: 0.8148
# Epoch 43/80
# 187/187 - 35s - loss: 1.0962 - accuracy: 0.6872 - val_loss: 0.5957 - val_accuracy: 0.8144
# Epoch 44/80
# 187/187 - 36s - loss: 1.0861 - accuracy: 0.6849 - val_loss: 0.5960 - val_accuracy: 0.8141
# Epoch 45/80
# 187/187 - 34s - loss: 1.0639 - accuracy: 0.6933 - val_loss: 0.5964 - val_accuracy: 0.8127
# Epoch 46/80
# 187/187 - 36s - loss: 1.0676 - accuracy: 0.6923 - val_loss: 0.5932 - val_accuracy: 0.8120
# Epoch 47/80
# 187/187 - 34s - loss: 1.0540 - accuracy: 0.6937 - val_loss: 0.5933 - val_accuracy: 0.8132
# Epoch 48/80
# 187/187 - 36s - loss: 1.0488 - accuracy: 0.6933 - val_loss: 0.5931 - val_accuracy: 0.8145
# Epoch 49/80
# 187/187 - 34s - loss: 1.0473 - accuracy: 0.6969 - val_loss: 0.5921 - val_accuracy: 0.8130
# Epoch 50/80
# 187/187 - 35s - loss: 1.0262 - accuracy: 0.7036 - val_loss: 0.5925 - val_accuracy: 0.8146
# Epoch 51/80
# 187/187 - 34s - loss: 1.0325 - accuracy: 0.6989 - val_loss: 0.5900 - val_accuracy: 0.8151
# Epoch 52/80
# 187/187 - 36s - loss: 1.0238 - accuracy: 0.7041 - val_loss: 0.5926 - val_accuracy: 0.8159
# Epoch 53/80
# 187/187 - 35s - loss: 1.0267 - accuracy: 0.6982 - val_loss: 0.5917 - val_accuracy: 0.8141
# Epoch 54/80
# 187/187 - 35s - loss: 0.9924 - accuracy: 0.7102 - val_loss: 0.5919 - val_accuracy: 0.8141
# Epoch 55/80
# 187/187 - 35s - loss: 0.9882 - accuracy: 0.7102 - val_loss: 0.5917 - val_accuracy: 0.8130
# Epoch 56/80
# 187/187 - 35s - loss: 0.9811 - accuracy: 0.7161 - val_loss: 0.5902 - val_accuracy: 0.8127
# Epoch 57/80
# 187/187 - 35s - loss: 0.9776 - accuracy: 0.7127 - val_loss: 0.5914 - val_accuracy: 0.8149
# Epoch 58/80
# 187/187 - 35s - loss: 0.9778 - accuracy: 0.7125 - val_loss: 0.5929 - val_accuracy: 0.8111
# Epoch 59/80
# 187/187 - 35s - loss: 0.9641 - accuracy: 0.7185 - val_loss: 0.5928 - val_accuracy: 0.8125
# Epoch 60/80
# 187/187 - 36s - loss: 0.9698 - accuracy: 0.7204 - val_loss: 0.5886 - val_accuracy: 0.8148
# Epoch 61/80
# 187/187 - 34s - loss: 0.9632 - accuracy: 0.7183 - val_loss: 0.5890 - val_accuracy: 0.8145
# Epoch 62/80
# 187/187 - 36s - loss: 0.9417 - accuracy: 0.7254 - val_loss: 0.5879 - val_accuracy: 0.8125
# Epoch 63/80
# 187/187 - 36s - loss: 0.9478 - accuracy: 0.7236 - val_loss: 0.5869 - val_accuracy: 0.8142
# Epoch 64/80
# 187/187 - 34s - loss: 0.9351 - accuracy: 0.7234 - val_loss: 0.5890 - val_accuracy: 0.8152
# Epoch 65/80
# 187/187 - 36s - loss: 0.9361 - accuracy: 0.7248 - val_loss: 0.5883 - val_accuracy: 0.8130
# Epoch 66/80
# 187/187 - 35s - loss: 0.9285 - accuracy: 0.7294 - val_loss: 0.5880 - val_accuracy: 0.8113
# Epoch 67/80
# 187/187 - 35s - loss: 0.9289 - accuracy: 0.7207 - val_loss: 0.5898 - val_accuracy: 0.8140
# Epoch 68/80
# 187/187 - 35s - loss: 0.9045 - accuracy: 0.7342 - val_loss: 0.5902 - val_accuracy: 0.8135
# Epoch 69/80
# 187/187 - 35s - loss: 0.9038 - accuracy: 0.7335 - val_loss: 0.5879 - val_accuracy: 0.8149
# Epoch 70/80
# 187/187 - 35s - loss: 0.9010 - accuracy: 0.7355 - val_loss: 0.5881 - val_accuracy: 0.8147
# Epoch 71/80
# 187/187 - 36s - loss: 0.9022 - accuracy: 0.7335 - val_loss: 0.5911 - val_accuracy: 0.8140
# Epoch 72/80
# 187/187 - 35s - loss: 0.8954 - accuracy: 0.7370 - val_loss: 0.5893 - val_accuracy: 0.8126
# Epoch 73/80
# 187/187 - 36s - loss: 0.8895 - accuracy: 0.7339 - val_loss: 0.5870 - val_accuracy: 0.8142
# Epoch 74/80
# 187/187 - 35s - loss: 0.8773 - accuracy: 0.7426 - val_loss: 0.5899 - val_accuracy: 0.8122
# Epoch 75/80
# 187/187 - 35s - loss: 0.8961 - accuracy: 0.7372 - val_loss: 0.5900 - val_accuracy: 0.8133
# Epoch 76/80
# 187/187 - 34s - loss: 0.8727 - accuracy: 0.7411 - val_loss: 0.5870 - val_accuracy: 0.8142
# Epoch 77/80
# 187/187 - 36s - loss: 0.8673 - accuracy: 0.7417 - val_loss: 0.5872 - val_accuracy: 0.8138
# Epoch 78/80
# 187/187 - 34s - loss: 0.8644 - accuracy: 0.7437 - val_loss: 0.5871 - val_accuracy: 0.8135
# 134/134 [==============================] - 16s 117ms/step - loss: 0.5869 - accuracy: 0.8142
# Evaluate: [0.5868763327598572, 0.8142490386962891]

# %% [markdown]
# The second step is to unfreeze a number of layers and fit the model using smaller
# learning rate. In this example we show unfreezing all layers, but depending on
# specific dataset it may be desireble to only unfreeze a fraction of all layers.
#
# When the feature extraction with
# pretrained model works good enough, this step would give a very limited gain on
# validation accuracy. In our case we only see a small improvement,
# as ImageNet pretraining already exposed the model to a good amount of dogs.
#
# On the other hand, when we use pretrained weights on a dataset that is more different
# from ImageNet, this fine-tuning step can be crucial as the feature extractor also
# needs to be adjusted by a considerable amount. Such a situation can be demonstrated
# if choosing CIFAR-100 dataset instead, where fine-tuning boosts validation accuracy
# by about 10% to pass 80% on `EfficientNetB0`.
# In such a case the convergence may take more than 50 epochs.
#
# A side note on freezing/unfreezing models: setting `trainable` of a `Model` will
# simultaneously set all layers belonging to the `Model` to the same `trainable`
# attribute. Each layer is trainable only if both the layer itself and the model
# containing it are trainable. Hence when we need to partially freeze/unfreeze
# a model, we need to make sure the `trainable` attribute of the model is set
# to `True`.

# %%
def unfreeze_model(model, lr=1e-4):
    # We unfreeze the top 20 layers while leaving BatchNorm layers frozen
    for layer in model.layers[-20:]:
        if layer.name[0:3] == "top" or layer.name[0:6] == "block7":
            if not isinstance(layer, layers.BatchNormalization):
                layer.trainable = True
                print('unfreezing layer:', layer.name)
        else:
            print('not unfreeze:', layer.name)

    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(
        optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"]
    )


unfreeze_model(model, lr=1e-5)

epochs = 50  # @param {type: "slider", min:8, max:50}
hist = model.fit(ds_train, epochs=epochs, validation_data=ds_test, verbose=2, callbacks=[earlystopping])
print('Evaluate:', model.evaluate(ds_test))
plot_hist(hist)
# Out:
# unfreezing layer: block7a_expand_conv
# unfreezing layer: block7a_expand_activation
# unfreezing layer: block7a_dwconv
# unfreezing layer: block7a_activation
# unfreezing layer: block7a_se_squeeze
# unfreezing layer: block7a_se_reshape
# unfreezing layer: block7a_se_reduce
# unfreezing layer: block7a_se_expand
# unfreezing layer: block7a_se_excite
# unfreezing layer: block7a_project_conv
# unfreezing layer: top_conv
# unfreezing layer: top_activation
# not unfreeze: avg_pool
# not unfreeze: batch_normalization
# unfreezing layer: top_dropout
# not unfreeze: pred
# Epoch 1/50
# 187/187 - 44s - loss: 0.9196 - accuracy: 0.7246 - val_loss: 0.5876 - val_accuracy: 0.8140
# Epoch 2/50
# 187/187 - 35s - loss: 0.9182 - accuracy: 0.7290 - val_loss: 0.5866 - val_accuracy: 0.8137
# Epoch 3/50
# 187/187 - 35s - loss: 0.9097 - accuracy: 0.7316 - val_loss: 0.5873 - val_accuracy: 0.8133
# Epoch 4/50
# 187/187 - 34s - loss: 0.8919 - accuracy: 0.7380 - val_loss: 0.5863 - val_accuracy: 0.8133
# Epoch 5/50
# 187/187 - 35s - loss: 0.8853 - accuracy: 0.7409 - val_loss: 0.5864 - val_accuracy: 0.8137
# Epoch 6/50
# 187/187 - 35s - loss: 0.8865 - accuracy: 0.7368 - val_loss: 0.5861 - val_accuracy: 0.8140
# Epoch 7/50
# 187/187 - 36s - loss: 0.8694 - accuracy: 0.7426 - val_loss: 0.5867 - val_accuracy: 0.8137
# Epoch 8/50
# 187/187 - 35s - loss: 0.8548 - accuracy: 0.7461 - val_loss: 0.5859 - val_accuracy: 0.8142
# Epoch 9/50
# 187/187 - 35s - loss: 0.8614 - accuracy: 0.7416 - val_loss: 0.5869 - val_accuracy: 0.8137
# Epoch 10/50
# 187/187 - 35s - loss: 0.8612 - accuracy: 0.7513 - val_loss: 0.5864 - val_accuracy: 0.8133
# Epoch 11/50
# 187/187 - 36s - loss: 0.8440 - accuracy: 0.7477 - val_loss: 0.5865 - val_accuracy: 0.8133
# Epoch 12/50
# 187/187 - 35s - loss: 0.8309 - accuracy: 0.7575 - val_loss: 0.5877 - val_accuracy: 0.8126
# Epoch 13/50
# 187/187 - 37s - loss: 0.8271 - accuracy: 0.7613 - val_loss: 0.5877 - val_accuracy: 0.8119
# Epoch 14/50
# 187/187 - 35s - loss: 0.8234 - accuracy: 0.7616 - val_loss: 0.5882 - val_accuracy: 0.8118
# Epoch 15/50
# 187/187 - 36s - loss: 0.8173 - accuracy: 0.7627 - val_loss: 0.5881 - val_accuracy: 0.8112
# Epoch 16/50
# 187/187 - 35s - loss: 0.8045 - accuracy: 0.7620 - val_loss: 0.5882 - val_accuracy: 0.8111
# Epoch 17/50
# 187/187 - 36s - loss: 0.8101 - accuracy: 0.7644 - val_loss: 0.5902 - val_accuracy: 0.8116
# Epoch 18/50
# 187/187 - 35s - loss: 0.7962 - accuracy: 0.7653 - val_loss: 0.5909 - val_accuracy: 0.8112
# Epoch 19/50
# 187/187 - 36s - loss: 0.8041 - accuracy: 0.7652 - val_loss: 0.5907 - val_accuracy: 0.8108
# Epoch 20/50
# 187/187 - 35s - loss: 0.7900 - accuracy: 0.7645 - val_loss: 0.5910 - val_accuracy: 0.8108
# Epoch 21/50
# 187/187 - 37s - loss: 0.7727 - accuracy: 0.7695 - val_loss: 0.5908 - val_accuracy: 0.8108
# Epoch 22/50
# 187/187 - 36s - loss: 0.7795 - accuracy: 0.7739 - val_loss: 0.5922 - val_accuracy: 0.8104
# Epoch 23/50
# 187/187 - 36s - loss: 0.7875 - accuracy: 0.7653 - val_loss: 0.5939 - val_accuracy: 0.8101
# 134/134 [==============================] - 15s 112ms/step - loss: 0.5859 - accuracy: 0.8142
# Evaluate: [0.5859010815620422, 0.8142490386962891]

# %% [markdown]
# # Wedge Dropout

# %%
# !pip uninstall -y keras-wedge-dropout
# !pip install -q git+https://github.com/LanceNorskog/keras-wedge.git
import numpy as np
from keras_wedge_dropout import WedgeDropout2D

# %% [markdown]
# Once again, train a custom "top" and unfreeze the final processing block.

# %%
with strategy.scope():
    model_wedge = build_model(num_classes=NUM_CLASSES, use_wedge_dropout=True, lr=1e-4)

earlystopping = tf.keras.callbacks.EarlyStopping(patience=15, restore_best_weights=True)

epochs = 200  # @param {type: "slider", min:8, max:200}
hist = model_wedge.fit(ds_train, epochs=epochs, validation_data=ds_test, verbose=2, callbacks=[earlystopping])
print('Evaluate:', model_wedge.evaluate(ds_test))
plot_hist(hist)
# Out:
# WedgeDropout2D.build: input_shape: (None, 224, 224, 3)
# Epoch 1/200
# 187/187 - 44s - loss: 4.5522 - accuracy: 0.0555 - val_loss: 4.0590 - val_accuracy: 0.2057
# Epoch 2/200
# 187/187 - 33s - loss: 3.9486 - accuracy: 0.2105 - val_loss: 3.4085 - val_accuracy: 0.4333
# Epoch 3/200
# 187/187 - 35s - loss: 3.4848 - accuracy: 0.3325 - val_loss: 2.8894 - val_accuracy: 0.5596
# Epoch 4/200
# 187/187 - 33s - loss: 3.1187 - accuracy: 0.4086 - val_loss: 2.4800 - val_accuracy: 0.6302
# Epoch 5/200
# 187/187 - 35s - loss: 2.8301 - accuracy: 0.4503 - val_loss: 2.1578 - val_accuracy: 0.6744
# Epoch 6/200
# 187/187 - 35s - loss: 2.6174 - accuracy: 0.4784 - val_loss: 1.9081 - val_accuracy: 0.7025
# Epoch 7/200
# 187/187 - 34s - loss: 2.4343 - accuracy: 0.5039 - val_loss: 1.7107 - val_accuracy: 0.7248
# Epoch 8/200
# 187/187 - 36s - loss: 2.2974 - accuracy: 0.5220 - val_loss: 1.5535 - val_accuracy: 0.7413
# Epoch 9/200
# 187/187 - 34s - loss: 2.1757 - accuracy: 0.5351 - val_loss: 1.4254 - val_accuracy: 0.7522
# Epoch 10/200
# 187/187 - 35s - loss: 2.0786 - accuracy: 0.5438 - val_loss: 1.3212 - val_accuracy: 0.7622
# Epoch 11/200
# 187/187 - 34s - loss: 2.0016 - accuracy: 0.5534 - val_loss: 1.2351 - val_accuracy: 0.7706
# Epoch 12/200
# 187/187 - 35s - loss: 1.9330 - accuracy: 0.5670 - val_loss: 1.1639 - val_accuracy: 0.7751
# Epoch 13/200
# 187/187 - 35s - loss: 1.8793 - accuracy: 0.5659 - val_loss: 1.1043 - val_accuracy: 0.7821
# Epoch 14/200
# 187/187 - 36s - loss: 1.8084 - accuracy: 0.5856 - val_loss: 1.0527 - val_accuracy: 0.7863
# Epoch 15/200
# 187/187 - 35s - loss: 1.7673 - accuracy: 0.5840 - val_loss: 1.0103 - val_accuracy: 0.7872
# Epoch 16/200
# 187/187 - 35s - loss: 1.7291 - accuracy: 0.5900 - val_loss: 0.9744 - val_accuracy: 0.7899
# Epoch 17/200
# 187/187 - 35s - loss: 1.6971 - accuracy: 0.5933 - val_loss: 0.9415 - val_accuracy: 0.7940
# Epoch 18/200
# 187/187 - 35s - loss: 1.6545 - accuracy: 0.6015 - val_loss: 0.9120 - val_accuracy: 0.7963
# Epoch 19/200
# 187/187 - 34s - loss: 1.6336 - accuracy: 0.6057 - val_loss: 0.8868 - val_accuracy: 0.7983
# Epoch 20/200
# 187/187 - 36s - loss: 1.5839 - accuracy: 0.6152 - val_loss: 0.8631 - val_accuracy: 0.8001
# Epoch 21/200
# 187/187 - 34s - loss: 1.5701 - accuracy: 0.6138 - val_loss: 0.8426 - val_accuracy: 0.8022
# Epoch 22/200
# 187/187 - 36s - loss: 1.5545 - accuracy: 0.6189 - val_loss: 0.8243 - val_accuracy: 0.8027
# Epoch 23/200
# 187/187 - 34s - loss: 1.5115 - accuracy: 0.6231 - val_loss: 0.8087 - val_accuracy: 0.8040
# Epoch 24/200
# 187/187 - 36s - loss: 1.5051 - accuracy: 0.6242 - val_loss: 0.7937 - val_accuracy: 0.8048
# Epoch 25/200
# 187/187 - 35s - loss: 1.4826 - accuracy: 0.6247 - val_loss: 0.7794 - val_accuracy: 0.8066
# Epoch 26/200
# 187/187 - 35s - loss: 1.4634 - accuracy: 0.6314 - val_loss: 0.7677 - val_accuracy: 0.8064
# Epoch 27/200
# 187/187 - 35s - loss: 1.4392 - accuracy: 0.6365 - val_loss: 0.7564 - val_accuracy: 0.8078
# Epoch 28/200
# 187/187 - 35s - loss: 1.4236 - accuracy: 0.6409 - val_loss: 0.7455 - val_accuracy: 0.8108
# Epoch 29/200
# 187/187 - 35s - loss: 1.4147 - accuracy: 0.6418 - val_loss: 0.7369 - val_accuracy: 0.8115
# Epoch 30/200
# 187/187 - 35s - loss: 1.3994 - accuracy: 0.6401 - val_loss: 0.7275 - val_accuracy: 0.8111
# Epoch 31/200
# 187/187 - 34s - loss: 1.3824 - accuracy: 0.6508 - val_loss: 0.7195 - val_accuracy: 0.8117
# Epoch 32/200
# 187/187 - 36s - loss: 1.3790 - accuracy: 0.6447 - val_loss: 0.7116 - val_accuracy: 0.8112
# Epoch 33/200
# 187/187 - 36s - loss: 1.3591 - accuracy: 0.6506 - val_loss: 0.7059 - val_accuracy: 0.8118
# Epoch 34/200
# 187/187 - 34s - loss: 1.3517 - accuracy: 0.6512 - val_loss: 0.6996 - val_accuracy: 0.8130
# Epoch 35/200
# 187/187 - 36s - loss: 1.3247 - accuracy: 0.6580 - val_loss: 0.6936 - val_accuracy: 0.8141
# Epoch 36/200
# 187/187 - 35s - loss: 1.3218 - accuracy: 0.6600 - val_loss: 0.6882 - val_accuracy: 0.8138
# Epoch 37/200
# 187/187 - 35s - loss: 1.3078 - accuracy: 0.6620 - val_loss: 0.6820 - val_accuracy: 0.8153
# Epoch 38/200
# 187/187 - 35s - loss: 1.2917 - accuracy: 0.6650 - val_loss: 0.6762 - val_accuracy: 0.8166
# Epoch 39/200
# 187/187 - 35s - loss: 1.2756 - accuracy: 0.6730 - val_loss: 0.6717 - val_accuracy: 0.8168
# Epoch 40/200
# 187/187 - 35s - loss: 1.2727 - accuracy: 0.6708 - val_loss: 0.6659 - val_accuracy: 0.8183
# Epoch 41/200
# 187/187 - 35s - loss: 1.2686 - accuracy: 0.6705 - val_loss: 0.6622 - val_accuracy: 0.8186
# Epoch 42/200
# 187/187 - 35s - loss: 1.2524 - accuracy: 0.6724 - val_loss: 0.6584 - val_accuracy: 0.8182
# Epoch 43/200
# 187/187 - 36s - loss: 1.2523 - accuracy: 0.6757 - val_loss: 0.6541 - val_accuracy: 0.8194
# Epoch 44/200
# 187/187 - 34s - loss: 1.2352 - accuracy: 0.6744 - val_loss: 0.6510 - val_accuracy: 0.8196
# Epoch 45/200
# 187/187 - 36s - loss: 1.2386 - accuracy: 0.6735 - val_loss: 0.6482 - val_accuracy: 0.8200
# Epoch 46/200
# 187/187 - 35s - loss: 1.2309 - accuracy: 0.6766 - val_loss: 0.6447 - val_accuracy: 0.8212
# Epoch 47/200
# 187/187 - 36s - loss: 1.2100 - accuracy: 0.6841 - val_loss: 0.6425 - val_accuracy: 0.8208
# Epoch 48/200
# 187/187 - 34s - loss: 1.2028 - accuracy: 0.6880 - val_loss: 0.6394 - val_accuracy: 0.8203
# Epoch 49/200
# 187/187 - 35s - loss: 1.1923 - accuracy: 0.6883 - val_loss: 0.6371 - val_accuracy: 0.8208
# Epoch 50/200
# 187/187 - 34s - loss: 1.1853 - accuracy: 0.6854 - val_loss: 0.6357 - val_accuracy: 0.8202
# Epoch 51/200
# 187/187 - 36s - loss: 1.1768 - accuracy: 0.6848 - val_loss: 0.6315 - val_accuracy: 0.8221
# Epoch 52/200
# 187/187 - 35s - loss: 1.1776 - accuracy: 0.6882 - val_loss: 0.6288 - val_accuracy: 0.8229
# Epoch 53/200
# 187/187 - 35s - loss: 1.1601 - accuracy: 0.6960 - val_loss: 0.6266 - val_accuracy: 0.8230
# Epoch 54/200
# 187/187 - 35s - loss: 1.1552 - accuracy: 0.6962 - val_loss: 0.6238 - val_accuracy: 0.8233
# Epoch 55/200
# 187/187 - 35s - loss: 1.1475 - accuracy: 0.6983 - val_loss: 0.6220 - val_accuracy: 0.8231
# Epoch 56/200
# 187/187 - 34s - loss: 1.1381 - accuracy: 0.6947 - val_loss: 0.6204 - val_accuracy: 0.8232
# Epoch 57/200
# 187/187 - 36s - loss: 1.1334 - accuracy: 0.6950 - val_loss: 0.6187 - val_accuracy: 0.8236
# Epoch 58/200
# 187/187 - 34s - loss: 1.1309 - accuracy: 0.6992 - val_loss: 0.6166 - val_accuracy: 0.8239
# Epoch 59/200
# 187/187 - 36s - loss: 1.1382 - accuracy: 0.6989 - val_loss: 0.6153 - val_accuracy: 0.8237
# Epoch 60/200
# 187/187 - 34s - loss: 1.1279 - accuracy: 0.7027 - val_loss: 0.6141 - val_accuracy: 0.8233
# Epoch 61/200
# 187/187 - 35s - loss: 1.1279 - accuracy: 0.7071 - val_loss: 0.6114 - val_accuracy: 0.8239
# Epoch 62/200
# 187/187 - 35s - loss: 1.0993 - accuracy: 0.7077 - val_loss: 0.6089 - val_accuracy: 0.8246
# Epoch 63/200
# 187/187 - 34s - loss: 1.1025 - accuracy: 0.7064 - val_loss: 0.6078 - val_accuracy: 0.8247
# Epoch 64/200
# 187/187 - 35s - loss: 1.0923 - accuracy: 0.7066 - val_loss: 0.6064 - val_accuracy: 0.8253
# Epoch 65/200
# 187/187 - 35s - loss: 1.0913 - accuracy: 0.7096 - val_loss: 0.6059 - val_accuracy: 0.8244
# Epoch 66/200
# 187/187 - 34s - loss: 1.0871 - accuracy: 0.7094 - val_loss: 0.6041 - val_accuracy: 0.8254
# Epoch 67/200
# 187/187 - 35s - loss: 1.0836 - accuracy: 0.7132 - val_loss: 0.6032 - val_accuracy: 0.8247
# Epoch 68/200
# 187/187 - 35s - loss: 1.0810 - accuracy: 0.7117 - val_loss: 0.6019 - val_accuracy: 0.8247
# Epoch 69/200
# 187/187 - 36s - loss: 1.0581 - accuracy: 0.7184 - val_loss: 0.6005 - val_accuracy: 0.8251
# Epoch 70/200
# 187/187 - 36s - loss: 1.0564 - accuracy: 0.7172 - val_loss: 0.5998 - val_accuracy: 0.8259
# Epoch 71/200
# 187/187 - 35s - loss: 1.0642 - accuracy: 0.7162 - val_loss: 0.5987 - val_accuracy: 0.8260
# Epoch 72/200
# 187/187 - 35s - loss: 1.0559 - accuracy: 0.7195 - val_loss: 0.5978 - val_accuracy: 0.8251
# Epoch 73/200
# 187/187 - 34s - loss: 1.0537 - accuracy: 0.7230 - val_loss: 0.5971 - val_accuracy: 0.8244
# Epoch 74/200
# 187/187 - 35s - loss: 1.0341 - accuracy: 0.7262 - val_loss: 0.5963 - val_accuracy: 0.8243
# Epoch 75/200
# 187/187 - 41s - loss: 1.0398 - accuracy: 0.7236 - val_loss: 0.5949 - val_accuracy: 0.8243
# Epoch 76/200
# 187/187 - 35s - loss: 1.0272 - accuracy: 0.7294 - val_loss: 0.5939 - val_accuracy: 0.8240
# Epoch 77/200
# 187/187 - 36s - loss: 1.0284 - accuracy: 0.7257 - val_loss: 0.5925 - val_accuracy: 0.8247
# Epoch 78/200
# 187/187 - 34s - loss: 1.0232 - accuracy: 0.7239 - val_loss: 0.5917 - val_accuracy: 0.8246
# Epoch 79/200
# 187/187 - 36s - loss: 1.0136 - accuracy: 0.7274 - val_loss: 0.5903 - val_accuracy: 0.8250
# Epoch 80/200
# 187/187 - 34s - loss: 1.0224 - accuracy: 0.7233 - val_loss: 0.5896 - val_accuracy: 0.8251
# Epoch 81/200
# 187/187 - 36s - loss: 1.0053 - accuracy: 0.7273 - val_loss: 0.5892 - val_accuracy: 0.8246
# Epoch 82/200
# 187/187 - 34s - loss: 0.9937 - accuracy: 0.7338 - val_loss: 0.5888 - val_accuracy: 0.8257
# Epoch 83/200
# 187/187 - 36s - loss: 1.0025 - accuracy: 0.7273 - val_loss: 0.5865 - val_accuracy: 0.8250
# Epoch 84/200
# 187/187 - 35s - loss: 1.0113 - accuracy: 0.7326 - val_loss: 0.5867 - val_accuracy: 0.8247
# Epoch 85/200
# 187/187 - 35s - loss: 0.9951 - accuracy: 0.7322 - val_loss: 0.5871 - val_accuracy: 0.8257
# Epoch 86/200
# 187/187 - 35s - loss: 0.9954 - accuracy: 0.7310 - val_loss: 0.5865 - val_accuracy: 0.8259
# Epoch 87/200
# 187/187 - 36s - loss: 0.9727 - accuracy: 0.7384 - val_loss: 0.5862 - val_accuracy: 0.8242
# Epoch 88/200
# 187/187 - 35s - loss: 0.9804 - accuracy: 0.7389 - val_loss: 0.5849 - val_accuracy: 0.8256
# Epoch 89/200
# 187/187 - 35s - loss: 0.9846 - accuracy: 0.7385 - val_loss: 0.5840 - val_accuracy: 0.8251
# Epoch 90/200
# 187/187 - 35s - loss: 0.9766 - accuracy: 0.7335 - val_loss: 0.5831 - val_accuracy: 0.8259
# Epoch 91/200
# 187/187 - 35s - loss: 0.9623 - accuracy: 0.7421 - val_loss: 0.5831 - val_accuracy: 0.8257
# Epoch 92/200
# 187/187 - 35s - loss: 0.9655 - accuracy: 0.7401 - val_loss: 0.5828 - val_accuracy: 0.8260
# Epoch 93/200
# 187/187 - 36s - loss: 0.9578 - accuracy: 0.7439 - val_loss: 0.5823 - val_accuracy: 0.8254
# Epoch 94/200
# 187/187 - 34s - loss: 0.9616 - accuracy: 0.7406 - val_loss: 0.5819 - val_accuracy: 0.8256
# Epoch 95/200
# 187/187 - 36s - loss: 0.9470 - accuracy: 0.7441 - val_loss: 0.5816 - val_accuracy: 0.8266
# Epoch 96/200
# 187/187 - 35s - loss: 0.9506 - accuracy: 0.7452 - val_loss: 0.5815 - val_accuracy: 0.8261
# Epoch 97/200
# 187/187 - 35s - loss: 0.9461 - accuracy: 0.7491 - val_loss: 0.5809 - val_accuracy: 0.8261
# Epoch 98/200
# 187/187 - 35s - loss: 0.9364 - accuracy: 0.7464 - val_loss: 0.5802 - val_accuracy: 0.8264
# Epoch 99/200
# 187/187 - 35s - loss: 0.9478 - accuracy: 0.7477 - val_loss: 0.5799 - val_accuracy: 0.8263
# Epoch 100/200
# 187/187 - 35s - loss: 0.9328 - accuracy: 0.7492 - val_loss: 0.5798 - val_accuracy: 0.8265
# Epoch 101/200
# 187/187 - 35s - loss: 0.9291 - accuracy: 0.7482 - val_loss: 0.5786 - val_accuracy: 0.8274
# Epoch 102/200
# 187/187 - 35s - loss: 0.9305 - accuracy: 0.7478 - val_loss: 0.5785 - val_accuracy: 0.8277
# Epoch 103/200
# 187/187 - 35s - loss: 0.9110 - accuracy: 0.7579 - val_loss: 0.5766 - val_accuracy: 0.8273
# Epoch 104/200
# 187/187 - 34s - loss: 0.9185 - accuracy: 0.7535 - val_loss: 0.5767 - val_accuracy: 0.8273
# Epoch 105/200
# 187/187 - 37s - loss: 0.9154 - accuracy: 0.7567 - val_loss: 0.5776 - val_accuracy: 0.8268
# Epoch 106/200
# 187/187 - 36s - loss: 0.9104 - accuracy: 0.7537 - val_loss: 0.5767 - val_accuracy: 0.8266
# Epoch 107/200
# 187/187 - 34s - loss: 0.9015 - accuracy: 0.7617 - val_loss: 0.5758 - val_accuracy: 0.8260
# Epoch 108/200
# 187/187 - 36s - loss: 0.8981 - accuracy: 0.7565 - val_loss: 0.5752 - val_accuracy: 0.8267
# Epoch 109/200
# 187/187 - 35s - loss: 0.8923 - accuracy: 0.7621 - val_loss: 0.5751 - val_accuracy: 0.8268
# Epoch 110/200
# 187/187 - 35s - loss: 0.8922 - accuracy: 0.7584 - val_loss: 0.5747 - val_accuracy: 0.8268
# Epoch 111/200
# 187/187 - 35s - loss: 0.9096 - accuracy: 0.7602 - val_loss: 0.5749 - val_accuracy: 0.8266
# Epoch 112/200
# 187/187 - 35s - loss: 0.8886 - accuracy: 0.7640 - val_loss: 0.5750 - val_accuracy: 0.8253
# Epoch 113/200
# 187/187 - 35s - loss: 0.8795 - accuracy: 0.7619 - val_loss: 0.5749 - val_accuracy: 0.8280
# Epoch 114/200
# 187/187 - 36s - loss: 0.8930 - accuracy: 0.7628 - val_loss: 0.5747 - val_accuracy: 0.8263
# Epoch 115/200
# 187/187 - 35s - loss: 0.8724 - accuracy: 0.7658 - val_loss: 0.5742 - val_accuracy: 0.8260
# Epoch 116/200
# 187/187 - 35s - loss: 0.8897 - accuracy: 0.7634 - val_loss: 0.5748 - val_accuracy: 0.8265
# Epoch 117/200
# 187/187 - 35s - loss: 0.8835 - accuracy: 0.7666 - val_loss: 0.5746 - val_accuracy: 0.8278
# Epoch 118/200
# 187/187 - 36s - loss: 0.8863 - accuracy: 0.7600 - val_loss: 0.5742 - val_accuracy: 0.8261
# Epoch 119/200
# 187/187 - 34s - loss: 0.8802 - accuracy: 0.7640 - val_loss: 0.5733 - val_accuracy: 0.8270
# Epoch 120/200
# 187/187 - 36s - loss: 0.8772 - accuracy: 0.7635 - val_loss: 0.5739 - val_accuracy: 0.8252
# Epoch 121/200
# 187/187 - 34s - loss: 0.8618 - accuracy: 0.7672 - val_loss: 0.5737 - val_accuracy: 0.8267
# Epoch 122/200
# 187/187 - 35s - loss: 0.8670 - accuracy: 0.7667 - val_loss: 0.5730 - val_accuracy: 0.8254
# Epoch 123/200
# 187/187 - 35s - loss: 0.8610 - accuracy: 0.7679 - val_loss: 0.5736 - val_accuracy: 0.8260
# Epoch 124/200
# 187/187 - 36s - loss: 0.8599 - accuracy: 0.7709 - val_loss: 0.5734 - val_accuracy: 0.8265
# Epoch 125/200
# 187/187 - 36s - loss: 0.8357 - accuracy: 0.7750 - val_loss: 0.5735 - val_accuracy: 0.8267
# Epoch 126/200
# 187/187 - 35s - loss: 0.8544 - accuracy: 0.7711 - val_loss: 0.5728 - val_accuracy: 0.8279
# Epoch 127/200
# 187/187 - 35s - loss: 0.8519 - accuracy: 0.7677 - val_loss: 0.5717 - val_accuracy: 0.8268
# Epoch 128/200
# 187/187 - 35s - loss: 0.8417 - accuracy: 0.7792 - val_loss: 0.5721 - val_accuracy: 0.8270
# Epoch 129/200
# 187/187 - 35s - loss: 0.8401 - accuracy: 0.7766 - val_loss: 0.5715 - val_accuracy: 0.8270
# Epoch 130/200
# 187/187 - 35s - loss: 0.8426 - accuracy: 0.7776 - val_loss: 0.5716 - val_accuracy: 0.8263
# Epoch 131/200
# 187/187 - 34s - loss: 0.8354 - accuracy: 0.7771 - val_loss: 0.5718 - val_accuracy: 0.8268
# Epoch 132/200
# 187/187 - 36s - loss: 0.8370 - accuracy: 0.7746 - val_loss: 0.5715 - val_accuracy: 0.8259
# Epoch 133/200
# 187/187 - 36s - loss: 0.8203 - accuracy: 0.7798 - val_loss: 0.5722 - val_accuracy: 0.8247
# Epoch 134/200
# 187/187 - 34s - loss: 0.8355 - accuracy: 0.7726 - val_loss: 0.5705 - val_accuracy: 0.8274
# Epoch 135/200
# 187/187 - 36s - loss: 0.8306 - accuracy: 0.7731 - val_loss: 0.5718 - val_accuracy: 0.8275
# Epoch 136/200
# 187/187 - 34s - loss: 0.8354 - accuracy: 0.7736 - val_loss: 0.5715 - val_accuracy: 0.8271
# Epoch 137/200
# 187/187 - 36s - loss: 0.8160 - accuracy: 0.7819 - val_loss: 0.5709 - val_accuracy: 0.8279
# Epoch 138/200
# 187/187 - 34s - loss: 0.8253 - accuracy: 0.7782 - val_loss: 0.5709 - val_accuracy: 0.8270
# Epoch 139/200
# 187/187 - 35s - loss: 0.8188 - accuracy: 0.7778 - val_loss: 0.5710 - val_accuracy: 0.8272
# Epoch 140/200
# 187/187 - 35s - loss: 0.8162 - accuracy: 0.7802 - val_loss: 0.5712 - val_accuracy: 0.8265
# Epoch 141/200
# 187/187 - 35s - loss: 0.8307 - accuracy: 0.7752 - val_loss: 0.5717 - val_accuracy: 0.8267
# Epoch 142/200
# 187/187 - 35s - loss: 0.8196 - accuracy: 0.7787 - val_loss: 0.5711 - val_accuracy: 0.8274
# Epoch 143/200
# 187/187 - 36s - loss: 0.8166 - accuracy: 0.7830 - val_loss: 0.5716 - val_accuracy: 0.8273
# Epoch 144/200
# 187/187 - 35s - loss: 0.7951 - accuracy: 0.7837 - val_loss: 0.5703 - val_accuracy: 0.8275
# Epoch 145/200
# 187/187 - 36s - loss: 0.8104 - accuracy: 0.7838 - val_loss: 0.5711 - val_accuracy: 0.8268
# Epoch 146/200
# 187/187 - 35s - loss: 0.8063 - accuracy: 0.7819 - val_loss: 0.5707 - val_accuracy: 0.8270
# Epoch 147/200
# 187/187 - 35s - loss: 0.8001 - accuracy: 0.7823 - val_loss: 0.5709 - val_accuracy: 0.8246
# Epoch 148/200
# 187/187 - 34s - loss: 0.7883 - accuracy: 0.7875 - val_loss: 0.5696 - val_accuracy: 0.8261
# Epoch 149/200
# 187/187 - 35s - loss: 0.8031 - accuracy: 0.7831 - val_loss: 0.5712 - val_accuracy: 0.8260
# Epoch 150/200
# 187/187 - 34s - loss: 0.7850 - accuracy: 0.7881 - val_loss: 0.5707 - val_accuracy: 0.8259
# Epoch 151/200
# 187/187 - 36s - loss: 0.7946 - accuracy: 0.7866 - val_loss: 0.5707 - val_accuracy: 0.8265
# Epoch 152/200
# 187/187 - 35s - loss: 0.7838 - accuracy: 0.7909 - val_loss: 0.5701 - val_accuracy: 0.8254
# Epoch 153/200
# 187/187 - 35s - loss: 0.7856 - accuracy: 0.7873 - val_loss: 0.5700 - val_accuracy: 0.8264
# Epoch 154/200
# 187/187 - 35s - loss: 0.7926 - accuracy: 0.7863 - val_loss: 0.5695 - val_accuracy: 0.8274
# Epoch 155/200
# 187/187 - 35s - loss: 0.7834 - accuracy: 0.7961 - val_loss: 0.5699 - val_accuracy: 0.8260
# Epoch 156/200
# 187/187 - 35s - loss: 0.7668 - accuracy: 0.7972 - val_loss: 0.5703 - val_accuracy: 0.8264
# Epoch 157/200
# 187/187 - 35s - loss: 0.7690 - accuracy: 0.7919 - val_loss: 0.5707 - val_accuracy: 0.8254
# Epoch 158/200
# 187/187 - 35s - loss: 0.7672 - accuracy: 0.7955 - val_loss: 0.5713 - val_accuracy: 0.8264
# Epoch 159/200
# 187/187 - 36s - loss: 0.7848 - accuracy: 0.7931 - val_loss: 0.5702 - val_accuracy: 0.8268
# Epoch 160/200
# 187/187 - 35s - loss: 0.7869 - accuracy: 0.7871 - val_loss: 0.5706 - val_accuracy: 0.8273
# Epoch 161/200
# 187/187 - 34s - loss: 0.7557 - accuracy: 0.8000 - val_loss: 0.5704 - val_accuracy: 0.8263
# Epoch 162/200
# 187/187 - 35s - loss: 0.7575 - accuracy: 0.7965 - val_loss: 0.5698 - val_accuracy: 0.8281
# Epoch 163/200
# 187/187 - 34s - loss: 0.7669 - accuracy: 0.7943 - val_loss: 0.5695 - val_accuracy: 0.8261
# Epoch 164/200
# 187/187 - 35s - loss: 0.7612 - accuracy: 0.7978 - val_loss: 0.5694 - val_accuracy: 0.8254
# Epoch 165/200
# 187/187 - 34s - loss: 0.7716 - accuracy: 0.7904 - val_loss: 0.5698 - val_accuracy: 0.8263
# Epoch 166/200
# 187/187 - 35s - loss: 0.7623 - accuracy: 0.7928 - val_loss: 0.5705 - val_accuracy: 0.8249
# Epoch 167/200
# 187/187 - 34s - loss: 0.7525 - accuracy: 0.7965 - val_loss: 0.5702 - val_accuracy: 0.8260
# Epoch 168/200
# 187/187 - 36s - loss: 0.7551 - accuracy: 0.7973 - val_loss: 0.5702 - val_accuracy: 0.8252
# Epoch 169/200
# 187/187 - 35s - loss: 0.7483 - accuracy: 0.7960 - val_loss: 0.5700 - val_accuracy: 0.8247
# Epoch 170/200
# 187/187 - 35s - loss: 0.7443 - accuracy: 0.8023 - val_loss: 0.5710 - val_accuracy: 0.8249
# Epoch 171/200
# 187/187 - 35s - loss: 0.7514 - accuracy: 0.7935 - val_loss: 0.5715 - val_accuracy: 0.8240
# Epoch 172/200
# 187/187 - 35s - loss: 0.7544 - accuracy: 0.7965 - val_loss: 0.5694 - val_accuracy: 0.8244
# Epoch 173/200
# 187/187 - 34s - loss: 0.7400 - accuracy: 0.8019 - val_loss: 0.5697 - val_accuracy: 0.8250
# Epoch 174/200
# 187/187 - 35s - loss: 0.7459 - accuracy: 0.7999 - val_loss: 0.5710 - val_accuracy: 0.8247
# Epoch 175/200
# 187/187 - 35s - loss: 0.7364 - accuracy: 0.8053 - val_loss: 0.5715 - val_accuracy: 0.8229
# Epoch 176/200
# 187/187 - 36s - loss: 0.7367 - accuracy: 0.8020 - val_loss: 0.5703 - val_accuracy: 0.8242
# Epoch 177/200
# 187/187 - 34s - loss: 0.7427 - accuracy: 0.8023 - val_loss: 0.5703 - val_accuracy: 0.8233
# Epoch 178/200
# 187/187 - 36s - loss: 0.7329 - accuracy: 0.7996 - val_loss: 0.5698 - val_accuracy: 0.8250
# Epoch 179/200
# 187/187 - 35s - loss: 0.7400 - accuracy: 0.8046 - val_loss: 0.5701 - val_accuracy: 0.8240
# 134/134 [==============================] - 15s 113ms/step - loss: 0.5694 - accuracy: 0.8254
# Evaluate: [0.5693607330322266, 0.8254430890083313]

# %%
def unfreeze_model(model, lr=1e-5):
    # We unfreeze the top 20 layers while leaving BatchNorm layers frozen
    for layer in model.layers[-20:]:
        if layer.name[0:3] == "top" or layer.name[0:6] == "block7":
            if not isinstance(layer, layers.BatchNormalization):
                layer.trainable = True
                print('unfreezing layer:', layer.name)
        else:
            print('not unfreeze:', layer.name)

    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(
        optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"]
    )


unfreeze_model(model_wedge, lr=5e-6)

epochs = 50  # @param {type: "slider", min:8, max:50}
hist = model_wedge.fit(ds_train, epochs=epochs, validation_data=ds_test, verbose=2, callbacks=[earlystopping])
print('Evaluate:', model_wedge.evaluate(ds_test))
plot_hist(hist)
# Out:
# not unfreeze: block6d_drop
# not unfreeze: block6d_add
# unfreezing layer: block7a_expand_conv
# unfreezing layer: block7a_expand_activation
# unfreezing layer: block7a_dwconv
# unfreezing layer: block7a_activation
# unfreezing layer: block7a_se_squeeze
# unfreezing layer: block7a_se_reshape
# unfreezing layer: block7a_se_reduce
# unfreezing layer: block7a_se_expand
# unfreezing layer: block7a_se_excite
# unfreezing layer: block7a_project_conv
# unfreezing layer: top_conv
# unfreezing layer: top_activation
# not unfreeze: avg_pool
# not unfreeze: pred
# Epoch 1/50
# 187/187 - 44s - loss: 0.7350 - accuracy: 0.7994 - val_loss: 0.5683 - val_accuracy: 0.8246
# Epoch 2/50
# 187/187 - 34s - loss: 0.7333 - accuracy: 0.7957 - val_loss: 0.5691 - val_accuracy: 0.8236
# Epoch 3/50
# 187/187 - 35s - loss: 0.7259 - accuracy: 0.7920 - val_loss: 0.5704 - val_accuracy: 0.8240
# Epoch 4/50
# 187/187 - 34s - loss: 0.7009 - accuracy: 0.8001 - val_loss: 0.5723 - val_accuracy: 0.8229
# Epoch 5/50
# 187/187 - 35s - loss: 0.6956 - accuracy: 0.7946 - val_loss: 0.5738 - val_accuracy: 0.8222
# Epoch 6/50
# 187/187 - 34s - loss: 0.6809 - accuracy: 0.8036 - val_loss: 0.5753 - val_accuracy: 0.8223
# Epoch 7/50
# 187/187 - 36s - loss: 0.6884 - accuracy: 0.7994 - val_loss: 0.5770 - val_accuracy: 0.8215
# Epoch 8/50
# 187/187 - 35s - loss: 0.6822 - accuracy: 0.7992 - val_loss: 0.5778 - val_accuracy: 0.8211
# Epoch 9/50
# 187/187 - 36s - loss: 0.6743 - accuracy: 0.8016 - val_loss: 0.5791 - val_accuracy: 0.8210
# Epoch 10/50
# 187/187 - 36s - loss: 0.6673 - accuracy: 0.8043 - val_loss: 0.5814 - val_accuracy: 0.8202
# Epoch 11/50
# 187/187 - 36s - loss: 0.6652 - accuracy: 0.8056 - val_loss: 0.5827 - val_accuracy: 0.8196
# Epoch 12/50
# 187/187 - 35s - loss: 0.6684 - accuracy: 0.8051 - val_loss: 0.5840 - val_accuracy: 0.8196
# Epoch 13/50
# 187/187 - 36s - loss: 0.6733 - accuracy: 0.7990 - val_loss: 0.5844 - val_accuracy: 0.8187
# Epoch 14/50
# 187/187 - 35s - loss: 0.6541 - accuracy: 0.8066 - val_loss: 0.5852 - val_accuracy: 0.8189
# Epoch 15/50
# 187/187 - 36s - loss: 0.6591 - accuracy: 0.8067 - val_loss: 0.5863 - val_accuracy: 0.8184
# Epoch 16/50
# 187/187 - 35s - loss: 0.6531 - accuracy: 0.8061 - val_loss: 0.5874 - val_accuracy: 0.8184
# 134/134 [==============================] - 16s 121ms/step - loss: 0.5683 - accuracy: 0.8246
# Evaluate: [0.568342924118042, 0.8246268630027771]

# %% [markdown]
# ### Tips for fine tuning EfficientNet
#
# On unfreezing layers:
#
# - The `BathcNormalization` layers need to be kept frozen
# ([more details](https://keras.io/guides/transfer_learning/)).
# If they are also turned to trainable, the
# first epoch after unfreezing will significantly reduce accuracy.
# - In some cases it may be beneficial to open up only a portion of layers instead of
# unfreezing all. This will make fine tuning much faster when going to larger models like
# B7.
# - Each block needs to be all turned on or off. This is because the architecture includes
# a shortcut from the first layer to the last layer for each block. Not respecting blocks
# also significantly harms the final performance.
#
# Some other tips for utilizing EfficientNet:
#
# - Larger variants of EfficientNet do not guarantee improved performance, especially for
# tasks with less data or fewer classes. In such a case, the larger variant of EfficientNet
# chosen, the harder it is to tune hyperparameters.
# - EMA (Exponential Moving Average) is very helpful in training EfficientNet from scratch,
# but not so much for transfer learning.
# - Do not use the RMSprop setup as in the original paper for transfer learning. The
# momentum and learning rate are too high for transfer learning. It will easily corrupt the
# pretrained weight and blow up the loss. A quick check is to see if loss (as categorical
# cross entropy) is getting significantly larger than log(NUM_CLASSES) after the same
# epoch. If so, the initial learning rate/momentum is too high.
# - Smaller batch size benefit validation accuracy, possibly due to effectively providing
# regularization.
#
# ## Using the latest EfficientNet weights
#
# Since the initial paper, the EfficientNet has been improved by various methods for data
# preprocessing and for using unlabelled data to enhance learning results. These
# improvements are relatively hard and computationally costly to reproduce, and require
# extra code; but the weights are readily available in the form of TF checkpoint files. The
# model architecture has not changed, so loading the improved checkpoints is possible.
#
# To use a checkpoint provided at
# [the official model repository](https://github.com/tensorflow/tpu/tree/master/models/official/efficientnet), first
# download the checkpoint. As example, here we download noisy-student version of B1:
#
# ```
# !wget https://storage.googleapis.com/cloud-tpu-checkpoints/efficientnet\
#        /noisystudent/noisy_student_efficientnet-b1.tar.gz
# !tar -xf noisy_student_efficientnet-b1.tar.gz
# ```
#
# Then use the script [efficientnet_weight_update_util.py](https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/keras/applications/efficientnet_weight_update_util.py) to convert ckpt file to h5 file.
#
# ```
# !python efficientnet_weight_update_util.py --model b1 --notop --ckpt \
#         efficientnet-b1/model.ckpt --o efficientnetb1_notop.h5
# ```
#
# When creating model, use the following to load new weight:
#
# ```python
# model = EfficientNetB1(weights="efficientnetb1_notop.h5", include_top=False)
# ```
