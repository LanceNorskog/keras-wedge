# %% [markdown]
# # Image classification via fine-tuning with EfficientNet
#
# **Author:** [Yixing Fu](https://github.com/yixingfu)<br>
# **Date created:** 2020/06/30<br>
# **Last modified:** 2020/07/16<br>
# **Description:** Use EfficientNet with weights pre-trained on imagenet for Stanford Dogs classification.

# %% [markdown]
# ## Introduction: what is EfficientNet
#
# EfficientNet, first introduced in [Tan and Le, 2019](https://arxiv.org/abs/1905.11946)
# is among the most efficient models (i.e. requiring least FLOPS for inference)
# that reaches State-of-the-Art accuracy on both
# imagenet and common image classification transfer learning tasks.
#
# The smallest base model is similar to [MnasNet](https://arxiv.org/abs/1807.11626), which
# reached near-SOTA with a significantly smaller model. By introducing a heuristic way to
# scale the model, EfficientNet provides a family of models (B0 to B7) that represents a
# good combination of efficiency and accuracy on a variety of scales. Such a scaling
# heuristics (compound-scaling, details see
# [Tan and Le, 2019](https://arxiv.org/abs/1905.11946)) allows the
# efficiency-oriented base model (B0) to surpass models at every scale, while avoiding
# extensive grid-search of hyperparameters.
#
# A summary of the latest updates on the model is available at
# [here](https://github.com/tensorflow/tpu/tree/master/models/official/efficientnet), where various
# augmentation schemes and semi-supervised learning approaches are applied to further
# improve the imagenet performance of the models. These extensions of the model can be used
# by updating weights without changing model architecture.
#
# ## B0 to B7 variants of EfficientNet
#
# *(This section provides some details on "compound scaling", and can be skipped
# if you're only interested in using the models)*
#
# Based on the [original paper](https://arxiv.org/abs/1905.11946) people may have the
# impression that EfficientNet is a continuous family of models created by arbitrarily
# choosing scaling factor in as Eq.(3) of the paper.  However, choice of resolution,
# depth and width are also restricted by many factors:
#
# - Resolution: Resolutions not divisible by 8, 16, etc. cause zero-padding near boundaries
# of some layers which wastes computational resources. This especially applies to smaller
# variants of the model, hence the input resolution for B0 and B1 are chosen as 224 and
# 240.
#
# - Depth and width: The building blocks of EfficientNet demands channel size to be
# multiples of 8.
#
# - Resource limit: Memory limitation may bottleneck resolution when depth
# and width can still increase. In such a situation, increasing depth and/or
# width but keep resolution can still improve performance.
#
# As a result, the depth, width and resolution of each variant of the EfficientNet models
# are hand-picked and proven to produce good results, though they may be significantly
# off from the compound scaling formula.
# Therefore, the keras implementation (detailed below) only provide these 8 models, B0 to B7,
# instead of allowing arbitray choice of width / depth / resolution parameters.
#
# ## Keras implementation of EfficientNet
#
# An implementation of EfficientNet B0 to B7 has been shipped with tf.keras since TF2.3. To
# use EfficientNetB0 for classifying 1000 classes of images from imagenet, run:
#
# ```python
# from tensorflow.keras.applications import EfficientNetB0
# model = EfficientNetB0(weights='imagenet')
# ```
#
# This model takes input images of shape (224, 224, 3), and the input data should range
# [0, 255]. Normalization is included as part of the model.
#
# Because training EfficientNet on ImageNet takes a tremendous amount of resources and
# several techniques that are not a part of the model architecture itself. Hence the Keras
# implementation by default loads pre-trained weights obtained via training with
# [AutoAugment](https://arxiv.org/abs/1805.09501).
#
# For B0 to B7 base models, the input shapes are different. Here is a list of input shape
# expected for each model:
#
# | Base model | resolution|
# |----------------|-----|
# | EfficientNetB0 | 224 |
# | EfficientNetB1 | 240 |
# | EfficientNetB2 | 260 |
# | EfficientNetB3 | 300 |
# | EfficientNetB4 | 380 |
# | EfficientNetB5 | 456 |
# | EfficientNetB6 | 528 |
# | EfficientNetB7 | 600 |
#
# When the model is intended for transfer learning, the Keras implementation
# provides a option to remove the top layers:
# ```
# model = EfficientNetB0(include_top=False, weights='imagenet')
# ```
# This option excludes the final `Dense` layer that turns 1280 features on the penultimate
# layer into prediction of the 1000 ImageNet classes. Replacing the top layer with custom
# layers allows using EfficientNet as a feature extractor in a transfer learning workflow.
#
# Another argument in the model constructor worth noticing is `drop_connect_rate` which controls
# the dropout rate responsible for [stochastic depth](https://arxiv.org/abs/1603.09382).
# This parameter serves as a toggle for extra regularization in finetuning, but does not
# affect loaded weights. For example, when stronger regularization is desired, try:
#
# ```python
# model = EfficientNetB0(weights='imagenet', drop_connect_rate=0.4)
# ```
# The default value is 0.2.
#
# ## Example: EfficientNetB0 for Stanford Dogs.
#
# EfficientNet is capable of a wide range of image classification tasks.
# This makes it a good model for transfer learning.
# As an end-to-end example, we will show using pre-trained EfficientNetB0 on
# [Stanford Dogs](http://vision.stanford.edu/aditya86/ImageNetDogs/main.html) dataset.

# %%
# IMG_SIZE is determined by EfficientNet model choice
IMG_SIZE = 224

# %% [markdown]
# ## Setup and data loading
#
# This example requires TensorFlow 2.3 or above.
#
# To use TPU, the TPU runtime must match current running TensorFlow
# version. If there is a mismatch, try:
#
# ```python
# from cloud_tpu_client import Client
# c = Client()
# c.configure_tpu_version(tf.__version__, restart_type="always")
# ```

# %%
import tensorflow as tf

try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection
    print("Running on TPU ", tpu.cluster_spec().as_dict()["worker"])
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except ValueError:
    print("Not connected to a TPU runtime. Using CPU/GPU strategy")
    strategy = tf.distribute.MirroredStrategy()
# Out:
# Not connected to a TPU runtime. Using CPU/GPU strategy
# WARNING:tensorflow:Collective ops is not configured at program startup. Some performance features may not be enabled.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %% [markdown]
# ### Loading data
#
# Here we load data from [tensorflow_datasets](https://www.tensorflow.org/datasets)
# (hereafter TFDS).
# Stanford Dogs dataset is provided in
# TFDS as [stanford_dogs](https://www.tensorflow.org/datasets/catalog/stanford_dogs).
# It features 20,580 images that belong to 120 classes of dog breeds
# (12,000 for training and 8,580 for testing).
#
# By simply changing `dataset_name` below, you may also try this notebook for
# other datasets in TFDS such as
# [cifar10](https://www.tensorflow.org/datasets/catalog/cifar10),
# [cifar100](https://www.tensorflow.org/datasets/catalog/cifar100),
# [food101](https://www.tensorflow.org/datasets/catalog/food101),
# etc. When the images are much smaller than the size of EfficientNet input,
# we can simply upsample the input images. It has been shown in
# [Tan and Le, 2019](https://arxiv.org/abs/1905.11946) that transfer learning
# result is better for increased resolution even if input images remain small.
#
# For TPU: if using TFDS datasets,
# a [GCS bucket](https://cloud.google.com/storage/docs/key-terms#buckets)
# location is required to save the datasets. For example:
#
# ```python
# tfds.load(dataset_name, data_dir="gs://example-bucket/datapath")
# ```
#
# Also, both the current environment and the TPU service account have
# proper [access](https://cloud.google.com/tpu/docs/storage-buckets#authorize_the_service_account)
# to the bucket. Alternatively, for small datasets you may try loading data
# into the memory and use `tf.data.Dataset.from_tensor_slices()`.

# %%
import tensorflow_datasets as tfds

batch_size = 64

dataset_name = "stanford_dogs"
(ds_train, ds_test), ds_info = tfds.load(
    dataset_name, split=["train", "test"], with_info=True, as_supervised=True
)
NUM_CLASSES = ds_info.features["label"].num_classes

# %% [markdown]
# When the dataset include images with various size, we need to resize them into a
# shared size. The Stanford Dogs dataset includes only images at least 200x200
# pixels in size. Here we resize the images to the input size needed for EfficientNet.

# %%
size = (IMG_SIZE, IMG_SIZE)
ds_train = ds_train.map(lambda image, label: (tf.image.resize(image, size), label))
ds_test = ds_test.map(lambda image, label: (tf.image.resize(image, size), label))

# %% [markdown]
# ### Visualizing the data
#
# The following code shows the first 9 images with their labels.

# %%
import matplotlib.pyplot as plt


def format_label(label):
    string_label = label_info.int2str(label)
    return string_label.split("-")[1]


label_info = ds_info.features["label"]
for i, (image, label) in enumerate(ds_train.take(9)):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image.numpy().astype("uint8"))
    plt.title("{}".format(format_label(label)))
    plt.axis("off")

# %% [markdown]
# ### Data augmentation
#
# We can use preprocessing layers APIs for image augmentation.

# %%
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

img_augmentation = Sequential(
    [
        preprocessing.RandomRotation(factor=0.15),
        preprocessing.RandomTranslation(height_factor=0.1, width_factor=0.1),
        preprocessing.RandomFlip(),
        preprocessing.RandomContrast(factor=0.1),
    ],
    name="img_augmentation",
)

# %% [markdown]
# This `Sequential` model object can be used both as a part of
# the model we later build, and as a function to preprocess
# data before feeding into the model. Using them as function makes
# it easy to visualize the augmented images. Here we plot 9 examples
# of augmentation result of a given figure.

# %%
for image, label in ds_train.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        aug_img = img_augmentation(tf.expand_dims(image, axis=0))
        plt.imshow(aug_img[0].numpy().astype("uint8"))
        plt.title("{}".format(format_label(label)))
        plt.axis("off")

# %% [markdown]
# ### Prepare inputs
#
# Once we verify the input data and augmentation are working correctly,
# we prepare dataset for training. The input data are resized to uniform
# `IMG_SIZE`. The labels are put into one-hot
# (a.k.a. categorical) encoding. The dataset is batched.
#
# Note: `prefetch` and `AUTOTUNE` may in some situation improve
# performance, but depends on environment and the specific dataset used.
# See this [guide](https://www.tensorflow.org/guide/data_performance)
# for more information on data pipeline performance.

# %%
# One-hot / categorical encoding
def input_preprocess(image, label):
    label = tf.one_hot(label, NUM_CLASSES)
    return image, label


ds_train = ds_train.map(
    input_preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE
)
ds_train = ds_train.batch(batch_size=batch_size, drop_remainder=True)
ds_train = ds_train.prefetch(tf.data.experimental.AUTOTUNE)

ds_test = ds_test.map(input_preprocess)
ds_test = ds_test.batch(batch_size=batch_size, drop_remainder=True)

# %% [markdown]
# ## Training a model from scratch
#
# We build an EfficientNetB0 with 120 output classes, that is initialized from scratch:
#
# Note: the accuracy will increase very slowly and may overfit.

# %%
from tensorflow.keras.applications import EfficientNetB0

with strategy.scope():
    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = img_augmentation(inputs)
    outputs = EfficientNetB0(include_top=True, weights=None, classes=NUM_CLASSES)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(
        optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"]
    )

model.summary()

epochs = 1  # @param {type: "slider", min:1, max:100}
hist = model.fit(ds_train, epochs=epochs, validation_data=ds_test, verbose=2)
print('Evaluate:', model.evaluate(ds_test))
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# img_augmentation (Sequential (None, 224, 224, 3)       0
# _________________________________________________________________
# efficientnetb0 (Functional)  (None, 120)               4203291
# =================================================================
# Total params: 4,203,291
# Trainable params: 4,161,268
# Non-trainable params: 42,023
# _________________________________________________________________
# 187/187 - 78s - loss: 4.9750 - accuracy: 0.0123 - val_loss: 4.9047 - val_accuracy: 0.0100
# 134/134 [==============================] - 14s 105ms/step - loss: 4.9047 - accuracy: 0.0100
# Evaluate: [4.904716968536377, 0.010027985088527203]

# %% [markdown]
# Training the model is relatively fast (takes only 20 seconds per epoch on TPUv2 that is
# available on Colab). This might make it sounds easy to simply train EfficientNet on any
# dataset wanted from scratch. However, training EfficientNet on smaller datasets,
# especially those with lower resolution like CIFAR-100, faces the significant challenge of
# overfitting.
#
# Hence training from scratch requires very careful choice of hyperparameters and is
# difficult to find suitable regularization. It would also be much more demanding in resources.
# Plotting the training and validation accuracy
# makes it clear that validation accuracy stagnates at a low value.

# %%
import matplotlib.pyplot as plt


def plot_hist(hist):
    plt.plot(hist.history["accuracy"])
    plt.plot(hist.history["val_accuracy"])
    plt.title("model accuracy")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.legend(["train", "validation"], loc="upper left")
    plt.show()


plot_hist(hist)

# %% [markdown]
# ## Transfer learning from pre-trained weights
#
# Here we initialize the model with pre-trained ImageNet weights,
# and we fine-tune it on our own dataset.

# %%
from tensorflow.keras.layers.experimental import preprocessing


def build_model(num_classes, use_wedge_dropout=False, lr=1e-2, similarity=0.65):
    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = img_augmentation(inputs)
    model = EfficientNetB0(include_top=False, input_tensor=x, weights="imagenet")

    # Freeze the pretrained weights
    model.trainable = False

    # Rebuild top
    if use_wedge_dropout:
        # x = layers.BatchNormalization()(x)
        x = WedgeDropout2D(similarity=similarity, batchwise=True, norm=True, name="top_wedge")(x)
        x = layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
    else:
        x = layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
        x = layers.BatchNormalization()(x)
        top_dropout_rate = 0.2
        x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)
    outputs = layers.Dense(NUM_CLASSES, activation="softmax", name="pred")(x)

    # Compile
    model = tf.keras.Model(inputs, outputs, name="EfficientNet")
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(
        optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"]
    )
    return model

# %% [markdown]
# The first step to transfer learning is to freeze all layers and train only the top
# layers. For this step, a relatively large learning rate (1e-2) can be used.
# Note that validation accuracy and loss will usually be better than training
# accuracy and loss. This is because the regularization is strong, which only
# suppresses training-time metrics.
#
# Note that the convergence may take up to 50 epochs depending on choice of learning rate.
# If image augmentation layers were not
# applied, the validation accuracy may only reach ~60%.

# %%
with strategy.scope():
    model = build_model(num_classes=NUM_CLASSES, lr=1e-4)

earlystopping = tf.keras.callbacks.EarlyStopping(patience=15, restore_best_weights=True)

epochs = 80  # @param {type: "slider", min:8, max:80}
hist = model.fit(ds_train, epochs=epochs, validation_data=ds_test, verbose=2, callbacks=[earlystopping])
print('Evaluate:', model.evaluate(ds_test))
plot_hist(hist)
# Out:
# Epoch 1/80
# 187/187 - 44s - loss: 4.9355 - accuracy: 0.0467 - val_loss: 3.7269 - val_accuracy: 0.1993
# Epoch 2/80
# 187/187 - 33s - loss: 3.7033 - accuracy: 0.1639 - val_loss: 2.4536 - val_accuracy: 0.4355
# Epoch 3/80
# 187/187 - 34s - loss: 3.0528 - accuracy: 0.2721 - val_loss: 1.7705 - val_accuracy: 0.5574
# Epoch 4/80
# 187/187 - 33s - loss: 2.6494 - accuracy: 0.3431 - val_loss: 1.4205 - val_accuracy: 0.6284
# Epoch 5/80
# 187/187 - 34s - loss: 2.3903 - accuracy: 0.3926 - val_loss: 1.2086 - val_accuracy: 0.6740
# Epoch 6/80
# 187/187 - 33s - loss: 2.2110 - accuracy: 0.4220 - val_loss: 1.0768 - val_accuracy: 0.7032
# Epoch 7/80
# 187/187 - 34s - loss: 2.0955 - accuracy: 0.4494 - val_loss: 0.9863 - val_accuracy: 0.7220
# Epoch 8/80
# 187/187 - 33s - loss: 1.9879 - accuracy: 0.4766 - val_loss: 0.9218 - val_accuracy: 0.7365
# Epoch 9/80
# 187/187 - 35s - loss: 1.9087 - accuracy: 0.4862 - val_loss: 0.8688 - val_accuracy: 0.7514
# Epoch 10/80
# 187/187 - 35s - loss: 1.8235 - accuracy: 0.5111 - val_loss: 0.8297 - val_accuracy: 0.7590
# Epoch 11/80
# 187/187 - 33s - loss: 1.7777 - accuracy: 0.5221 - val_loss: 0.8029 - val_accuracy: 0.7635
# Epoch 12/80
# 187/187 - 35s - loss: 1.7226 - accuracy: 0.5318 - val_loss: 0.7817 - val_accuracy: 0.7668
# Epoch 13/80
# 187/187 - 33s - loss: 1.6791 - accuracy: 0.5433 - val_loss: 0.7585 - val_accuracy: 0.7718
# Epoch 14/80
# 187/187 - 35s - loss: 1.6477 - accuracy: 0.5495 - val_loss: 0.7400 - val_accuracy: 0.7759
# Epoch 15/80
# 187/187 - 33s - loss: 1.5955 - accuracy: 0.5614 - val_loss: 0.7259 - val_accuracy: 0.7811
# Epoch 16/80
# 187/187 - 35s - loss: 1.5816 - accuracy: 0.5656 - val_loss: 0.7084 - val_accuracy: 0.7849
# Epoch 17/80
# 187/187 - 34s - loss: 1.5491 - accuracy: 0.5729 - val_loss: 0.6980 - val_accuracy: 0.7879
# Epoch 18/80
# 187/187 - 35s - loss: 1.4911 - accuracy: 0.5860 - val_loss: 0.6877 - val_accuracy: 0.7908
# Epoch 19/80
# 187/187 - 34s - loss: 1.4653 - accuracy: 0.5887 - val_loss: 0.6811 - val_accuracy: 0.7894
# Epoch 20/80
# 187/187 - 34s - loss: 1.4074 - accuracy: 0.6096 - val_loss: 0.6709 - val_accuracy: 0.7954
# Epoch 21/80
# 187/187 - 34s - loss: 1.4445 - accuracy: 0.5972 - val_loss: 0.6669 - val_accuracy: 0.7962
# Epoch 22/80
# 187/187 - 34s - loss: 1.4032 - accuracy: 0.6079 - val_loss: 0.6598 - val_accuracy: 0.7972
# Epoch 23/80
# 187/187 - 34s - loss: 1.3838 - accuracy: 0.6114 - val_loss: 0.6563 - val_accuracy: 0.7986
# Epoch 24/80
# 187/187 - 34s - loss: 1.3647 - accuracy: 0.6221 - val_loss: 0.6511 - val_accuracy: 0.7978
# Epoch 25/80
# 187/187 - 34s - loss: 1.3167 - accuracy: 0.6286 - val_loss: 0.6446 - val_accuracy: 0.8032
# Epoch 26/80
# 187/187 - 34s - loss: 1.3189 - accuracy: 0.6271 - val_loss: 0.6406 - val_accuracy: 0.8022
# Epoch 27/80
# 187/187 - 33s - loss: 1.2964 - accuracy: 0.6351 - val_loss: 0.6430 - val_accuracy: 0.7983
# Epoch 28/80
# 187/187 - 34s - loss: 1.2767 - accuracy: 0.6412 - val_loss: 0.6371 - val_accuracy: 0.8014
# Epoch 29/80
# 187/187 - 34s - loss: 1.2896 - accuracy: 0.6326 - val_loss: 0.6356 - val_accuracy: 0.8028
# Epoch 30/80
# 187/187 - 33s - loss: 1.2399 - accuracy: 0.6486 - val_loss: 0.6315 - val_accuracy: 0.8043
# Epoch 31/80
# 187/187 - 34s - loss: 1.2473 - accuracy: 0.6466 - val_loss: 0.6258 - val_accuracy: 0.8057
# Epoch 32/80
# 187/187 - 33s - loss: 1.2359 - accuracy: 0.6507 - val_loss: 0.6233 - val_accuracy: 0.8055
# Epoch 33/80
# 187/187 - 34s - loss: 1.2234 - accuracy: 0.6507 - val_loss: 0.6208 - val_accuracy: 0.8050
# Epoch 34/80
# 187/187 - 33s - loss: 1.1762 - accuracy: 0.6628 - val_loss: 0.6211 - val_accuracy: 0.8048
# Epoch 35/80
# 187/187 - 34s - loss: 1.1722 - accuracy: 0.6606 - val_loss: 0.6214 - val_accuracy: 0.8041
# Epoch 36/80
# 187/187 - 33s - loss: 1.1651 - accuracy: 0.6665 - val_loss: 0.6185 - val_accuracy: 0.8041
# Epoch 37/80
# 187/187 - 35s - loss: 1.1783 - accuracy: 0.6618 - val_loss: 0.6165 - val_accuracy: 0.8029
# Epoch 38/80
# 187/187 - 35s - loss: 1.1544 - accuracy: 0.6639 - val_loss: 0.6160 - val_accuracy: 0.8027
# Epoch 39/80
# 187/187 - 40s - loss: 1.1381 - accuracy: 0.6699 - val_loss: 0.6153 - val_accuracy: 0.8064
# Epoch 40/80
# 187/187 - 34s - loss: 1.1277 - accuracy: 0.6729 - val_loss: 0.6122 - val_accuracy: 0.8083
# Epoch 41/80
# 187/187 - 33s - loss: 1.1110 - accuracy: 0.6796 - val_loss: 0.6086 - val_accuracy: 0.8081
# Epoch 42/80
# 187/187 - 34s - loss: 1.1145 - accuracy: 0.6838 - val_loss: 0.6073 - val_accuracy: 0.8096
# Epoch 43/80
# 187/187 - 33s - loss: 1.1029 - accuracy: 0.6829 - val_loss: 0.6102 - val_accuracy: 0.8075
# Epoch 44/80
# 187/187 - 34s - loss: 1.0810 - accuracy: 0.6852 - val_loss: 0.6097 - val_accuracy: 0.8091
# Epoch 45/80
# 187/187 - 33s - loss: 1.0762 - accuracy: 0.6883 - val_loss: 0.6095 - val_accuracy: 0.8076
# Epoch 46/80
# 187/187 - 34s - loss: 1.0624 - accuracy: 0.6969 - val_loss: 0.6090 - val_accuracy: 0.8087
# Epoch 47/80
# 187/187 - 34s - loss: 1.0581 - accuracy: 0.6973 - val_loss: 0.6021 - val_accuracy: 0.8104
# Epoch 48/80
# 187/187 - 35s - loss: 1.0606 - accuracy: 0.6925 - val_loss: 0.6051 - val_accuracy: 0.8102
# Epoch 49/80
# 187/187 - 34s - loss: 1.0380 - accuracy: 0.7007 - val_loss: 0.6034 - val_accuracy: 0.8097
# Epoch 50/80
# 187/187 - 34s - loss: 1.0415 - accuracy: 0.6980 - val_loss: 0.6041 - val_accuracy: 0.8082
# Epoch 51/80
# 187/187 - 34s - loss: 1.0098 - accuracy: 0.7032 - val_loss: 0.6036 - val_accuracy: 0.8078
# Epoch 52/80
# 187/187 - 34s - loss: 1.0099 - accuracy: 0.7087 - val_loss: 0.6063 - val_accuracy: 0.8101
# Epoch 53/80
# 187/187 - 34s - loss: 1.0210 - accuracy: 0.7010 - val_loss: 0.6038 - val_accuracy: 0.8078
# Epoch 54/80
# 187/187 - 34s - loss: 0.9941 - accuracy: 0.7142 - val_loss: 0.6033 - val_accuracy: 0.8087
# Epoch 55/80
# 187/187 - 33s - loss: 1.0100 - accuracy: 0.7050 - val_loss: 0.6015 - val_accuracy: 0.8101
# Epoch 56/80
# 187/187 - 34s - loss: 0.9804 - accuracy: 0.7149 - val_loss: 0.6001 - val_accuracy: 0.8113
# Epoch 57/80
# 187/187 - 34s - loss: 0.9838 - accuracy: 0.7111 - val_loss: 0.6001 - val_accuracy: 0.8096
# Epoch 58/80
# 187/187 - 33s - loss: 0.9874 - accuracy: 0.7106 - val_loss: 0.5990 - val_accuracy: 0.8098
# Epoch 59/80
# 187/187 - 34s - loss: 0.9591 - accuracy: 0.7196 - val_loss: 0.6021 - val_accuracy: 0.8108
# Epoch 60/80
# 187/187 - 33s - loss: 0.9630 - accuracy: 0.7209 - val_loss: 0.5978 - val_accuracy: 0.8132
# Epoch 61/80
# 187/187 - 34s - loss: 0.9468 - accuracy: 0.7205 - val_loss: 0.5974 - val_accuracy: 0.8112
# Epoch 62/80
# 187/187 - 33s - loss: 0.9387 - accuracy: 0.7244 - val_loss: 0.5977 - val_accuracy: 0.8122
# Epoch 63/80
# 187/187 - 34s - loss: 0.9388 - accuracy: 0.7248 - val_loss: 0.6010 - val_accuracy: 0.8085
# Epoch 64/80
# 187/187 - 33s - loss: 0.9196 - accuracy: 0.7322 - val_loss: 0.5999 - val_accuracy: 0.8088
# Epoch 65/80
# 187/187 - 34s - loss: 0.9347 - accuracy: 0.7255 - val_loss: 0.6006 - val_accuracy: 0.8083
# Epoch 66/80
# 187/187 - 35s - loss: 0.9241 - accuracy: 0.7304 - val_loss: 0.6012 - val_accuracy: 0.8090
# Epoch 67/80
# 187/187 - 33s - loss: 0.9301 - accuracy: 0.7287 - val_loss: 0.5986 - val_accuracy: 0.8108
# Epoch 68/80
# 187/187 - 34s - loss: 0.9066 - accuracy: 0.7312 - val_loss: 0.5999 - val_accuracy: 0.8098
# Epoch 69/80
# 187/187 - 33s - loss: 0.9059 - accuracy: 0.7299 - val_loss: 0.6008 - val_accuracy: 0.8102
# Epoch 70/80
# 187/187 - 34s - loss: 0.9124 - accuracy: 0.7323 - val_loss: 0.6011 - val_accuracy: 0.8108
# Epoch 71/80
# 187/187 - 33s - loss: 0.8863 - accuracy: 0.7400 - val_loss: 0.5985 - val_accuracy: 0.8113
# Epoch 72/80
# 187/187 - 34s - loss: 0.8876 - accuracy: 0.7433 - val_loss: 0.6029 - val_accuracy: 0.8110
# Epoch 73/80
# 187/187 - 33s - loss: 0.8841 - accuracy: 0.7435 - val_loss: 0.5982 - val_accuracy: 0.8117
# Epoch 74/80
# 187/187 - 34s - loss: 0.9019 - accuracy: 0.7341 - val_loss: 0.6004 - val_accuracy: 0.8108
# Epoch 75/80
# 187/187 - 33s - loss: 0.8739 - accuracy: 0.7425 - val_loss: 0.6020 - val_accuracy: 0.8091
# Epoch 76/80
# 187/187 - 34s - loss: 0.8784 - accuracy: 0.7344 - val_loss: 0.5995 - val_accuracy: 0.8088
# 134/134 [==============================] - 15s 113ms/step - loss: 0.5974 - accuracy: 0.8112
# Evaluate: [0.5973592400550842, 0.8112173676490784]

# %% [markdown]
# The second step is to unfreeze a number of layers and fit the model using smaller
# learning rate. In this example we show unfreezing all layers, but depending on
# specific dataset it may be desireble to only unfreeze a fraction of all layers.
#
# When the feature extraction with
# pretrained model works good enough, this step would give a very limited gain on
# validation accuracy. In our case we only see a small improvement,
# as ImageNet pretraining already exposed the model to a good amount of dogs.
#
# On the other hand, when we use pretrained weights on a dataset that is more different
# from ImageNet, this fine-tuning step can be crucial as the feature extractor also
# needs to be adjusted by a considerable amount. Such a situation can be demonstrated
# if choosing CIFAR-100 dataset instead, where fine-tuning boosts validation accuracy
# by about 10% to pass 80% on `EfficientNetB0`.
# In such a case the convergence may take more than 50 epochs.
#
# A side note on freezing/unfreezing models: setting `trainable` of a `Model` will
# simultaneously set all layers belonging to the `Model` to the same `trainable`
# attribute. Each layer is trainable only if both the layer itself and the model
# containing it are trainable. Hence when we need to partially freeze/unfreeze
# a model, we need to make sure the `trainable` attribute of the model is set
# to `True`.

# %%
def unfreeze_model(model, lr=1e-4):
    # We unfreeze the top 20 layers while leaving BatchNorm layers frozen
    for layer in model.layers[-20:]:
        if layer.name[0:3] == "top" or layer.name[0:6] == "block7":
            if not isinstance(layer, layers.BatchNormalization):
                layer.trainable = True
                print('unfreezing layer:', layer.name)
        else:
            print('not unfreeze:', layer.name)

    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(
        optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"]
    )


unfreeze_model(model, lr=1e-5)

epochs = 50  # @param {type: "slider", min:8, max:50}
hist = model.fit(ds_train, epochs=epochs, validation_data=ds_test, verbose=2, callbacks=[earlystopping])
print('Evaluate:', model.evaluate(ds_test))
plot_hist(hist)
# Out:
# unfreezing layer: block7a_expand_conv
# unfreezing layer: block7a_expand_activation
# unfreezing layer: block7a_dwconv
# unfreezing layer: block7a_activation
# unfreezing layer: block7a_se_squeeze
# unfreezing layer: block7a_se_reshape
# unfreezing layer: block7a_se_reduce
# unfreezing layer: block7a_se_expand
# unfreezing layer: block7a_se_excite
# unfreezing layer: block7a_project_conv
# unfreezing layer: top_conv
# unfreezing layer: top_activation
# not unfreeze: avg_pool
# not unfreeze: batch_normalization
# unfreezing layer: top_dropout
# not unfreeze: pred
# Epoch 1/50
# 187/187 - 44s - loss: 0.8039 - accuracy: 0.7599 - val_loss: 0.6096 - val_accuracy: 0.8067
# Epoch 2/50
# 187/187 - 32s - loss: 0.8010 - accuracy: 0.7624 - val_loss: 0.6097 - val_accuracy: 0.8068
# Epoch 3/50
# 187/187 - 34s - loss: 0.7866 - accuracy: 0.7666 - val_loss: 0.6104 - val_accuracy: 0.8062
# Epoch 4/50
# 187/187 - 33s - loss: 0.7755 - accuracy: 0.7726 - val_loss: 0.6109 - val_accuracy: 0.8074
# Epoch 5/50
# 187/187 - 34s - loss: 0.7611 - accuracy: 0.7777 - val_loss: 0.6113 - val_accuracy: 0.8074
# Epoch 6/50
# 187/187 - 33s - loss: 0.7616 - accuracy: 0.7757 - val_loss: 0.6115 - val_accuracy: 0.8057
# Epoch 7/50
# 187/187 - 34s - loss: 0.7593 - accuracy: 0.7777 - val_loss: 0.6118 - val_accuracy: 0.8069
# Epoch 8/50
# 187/187 - 33s - loss: 0.7489 - accuracy: 0.7777 - val_loss: 0.6124 - val_accuracy: 0.8067
# Epoch 9/50
# 187/187 - 35s - loss: 0.7509 - accuracy: 0.7800 - val_loss: 0.6138 - val_accuracy: 0.8068
# Epoch 10/50
# 187/187 - 34s - loss: 0.7472 - accuracy: 0.7791 - val_loss: 0.6149 - val_accuracy: 0.8055
# Epoch 11/50
# 187/187 - 34s - loss: 0.7401 - accuracy: 0.7846 - val_loss: 0.6141 - val_accuracy: 0.8061
# Epoch 12/50
# 187/187 - 34s - loss: 0.7429 - accuracy: 0.7790 - val_loss: 0.6154 - val_accuracy: 0.8062
# Epoch 13/50
# 187/187 - 34s - loss: 0.7245 - accuracy: 0.7823 - val_loss: 0.6159 - val_accuracy: 0.8063
# Epoch 14/50
# 187/187 - 34s - loss: 0.7232 - accuracy: 0.7868 - val_loss: 0.6181 - val_accuracy: 0.8068
# Epoch 15/50
# 187/187 - 35s - loss: 0.7265 - accuracy: 0.7846 - val_loss: 0.6185 - val_accuracy: 0.8062
# Epoch 16/50
# 187/187 - 34s - loss: 0.7108 - accuracy: 0.7878 - val_loss: 0.6180 - val_accuracy: 0.8043
# 134/134 [==============================] - 15s 109ms/step - loss: 0.6096 - accuracy: 0.8067
# Evaluate: [0.6096044778823853, 0.8066697716712952]

# %% [markdown]
# # Wedge Dropout

# %%
# !pip uninstall -y keras-wedge-dropout
# !pip install -q git+https://github.com/LanceNorskog/keras-wedge.git
import numpy as np
from keras_wedge_dropout import WedgeDropout2D
# Out:
# Found existing installation: keras-wedge-dropout 0.1.0
# Uninstalling keras-wedge-dropout-0.1.0:
#   Successfully uninstalled keras-wedge-dropout-0.1.0
#   Building wheel for keras-wedge-dropout (setup.py) ... done

# %% [markdown]
# Once again, train a custom "top" and unfreeze the final processing block.

# %%
with strategy.scope():
    model_wedge = build_model(num_classes=NUM_CLASSES, use_wedge_dropout=True, lr=1e-4)

earlystopping = tf.keras.callbacks.EarlyStopping(patience=15, restore_best_weights=True)

epochs = 200  # @param {type: "slider", min:8, max:200}
hist = model_wedge.fit(ds_train, epochs=epochs, validation_data=ds_test, verbose=2, callbacks=[earlystopping])
print('Evaluate:', model_wedge.evaluate(ds_test))
plot_hist(hist)
# Out:
# WedgeDropout2D.build: input_shape: (None, 224, 224, 3)
# Epoch 1/200
# 187/187 - 43s - loss: 4.5563 - accuracy: 0.0532 - val_loss: 4.0452 - val_accuracy: 0.2086
# Epoch 2/200
# 187/187 - 32s - loss: 3.9489 - accuracy: 0.2190 - val_loss: 3.4042 - val_accuracy: 0.4374
# Epoch 3/200
# 187/187 - 33s - loss: 3.4861 - accuracy: 0.3338 - val_loss: 2.8903 - val_accuracy: 0.5637
# Epoch 4/200
# 187/187 - 32s - loss: 3.1176 - accuracy: 0.4109 - val_loss: 2.4832 - val_accuracy: 0.6311
# Epoch 5/200
# 187/187 - 32s - loss: 2.8350 - accuracy: 0.4544 - val_loss: 2.1632 - val_accuracy: 0.6683
# Epoch 6/200
# 187/187 - 33s - loss: 2.6196 - accuracy: 0.4780 - val_loss: 1.9119 - val_accuracy: 0.6971
# Epoch 7/200
# 187/187 - 33s - loss: 2.4497 - accuracy: 0.4948 - val_loss: 1.7152 - val_accuracy: 0.7168
# Epoch 8/200
# 187/187 - 34s - loss: 2.3026 - accuracy: 0.5154 - val_loss: 1.5585 - val_accuracy: 0.7316
# Epoch 9/200
# 187/187 - 33s - loss: 2.1924 - accuracy: 0.5293 - val_loss: 1.4307 - val_accuracy: 0.7434
# Epoch 10/200
# 187/187 - 34s - loss: 2.0921 - accuracy: 0.5426 - val_loss: 1.3282 - val_accuracy: 0.7564
# Epoch 11/200
# 187/187 - 33s - loss: 1.9971 - accuracy: 0.5523 - val_loss: 1.2426 - val_accuracy: 0.7654
# Epoch 12/200
# 187/187 - 34s - loss: 1.9366 - accuracy: 0.5644 - val_loss: 1.1712 - val_accuracy: 0.7727
# Epoch 13/200
# 187/187 - 33s - loss: 1.8777 - accuracy: 0.5714 - val_loss: 1.1114 - val_accuracy: 0.7776
# Epoch 14/200
# 187/187 - 33s - loss: 1.8181 - accuracy: 0.5792 - val_loss: 1.0599 - val_accuracy: 0.7802
# Epoch 15/200
# 187/187 - 33s - loss: 1.7646 - accuracy: 0.5902 - val_loss: 1.0147 - val_accuracy: 0.7845
# Epoch 16/200
# 187/187 - 33s - loss: 1.7250 - accuracy: 0.5940 - val_loss: 0.9770 - val_accuracy: 0.7872
# Epoch 17/200
# 187/187 - 33s - loss: 1.6966 - accuracy: 0.5948 - val_loss: 0.9439 - val_accuracy: 0.7934
# Epoch 18/200
# 187/187 - 34s - loss: 1.6610 - accuracy: 0.6063 - val_loss: 0.9151 - val_accuracy: 0.7963
# Epoch 19/200
# 187/187 - 33s - loss: 1.6199 - accuracy: 0.6147 - val_loss: 0.8879 - val_accuracy: 0.7998
# Epoch 20/200
# 187/187 - 34s - loss: 1.6043 - accuracy: 0.6092 - val_loss: 0.8655 - val_accuracy: 0.8018
# Epoch 21/200
# 187/187 - 34s - loss: 1.5821 - accuracy: 0.6130 - val_loss: 0.8463 - val_accuracy: 0.8015
# Epoch 22/200
# 187/187 - 33s - loss: 1.5578 - accuracy: 0.6197 - val_loss: 0.8280 - val_accuracy: 0.8027
# Epoch 23/200
# 187/187 - 34s - loss: 1.5224 - accuracy: 0.6232 - val_loss: 0.8124 - val_accuracy: 0.8050
# Epoch 24/200
# 187/187 - 33s - loss: 1.5045 - accuracy: 0.6281 - val_loss: 0.7972 - val_accuracy: 0.8047
# Epoch 25/200
# 187/187 - 34s - loss: 1.4716 - accuracy: 0.6340 - val_loss: 0.7830 - val_accuracy: 0.8068
# Epoch 26/200
# 187/187 - 33s - loss: 1.4612 - accuracy: 0.6288 - val_loss: 0.7700 - val_accuracy: 0.8077
# Epoch 27/200
# 187/187 - 34s - loss: 1.4402 - accuracy: 0.6372 - val_loss: 0.7597 - val_accuracy: 0.8073
# Epoch 28/200
# 187/187 - 33s - loss: 1.4252 - accuracy: 0.6400 - val_loss: 0.7482 - val_accuracy: 0.8105
# Epoch 29/200
# 187/187 - 34s - loss: 1.4184 - accuracy: 0.6393 - val_loss: 0.7390 - val_accuracy: 0.8118
# Epoch 30/200
# 187/187 - 34s - loss: 1.3958 - accuracy: 0.6411 - val_loss: 0.7296 - val_accuracy: 0.8137
# Epoch 31/200
# 187/187 - 33s - loss: 1.3887 - accuracy: 0.6455 - val_loss: 0.7211 - val_accuracy: 0.8142
# Epoch 32/200
# 187/187 - 34s - loss: 1.3694 - accuracy: 0.6505 - val_loss: 0.7127 - val_accuracy: 0.8145
# Epoch 33/200
# 187/187 - 32s - loss: 1.3612 - accuracy: 0.6503 - val_loss: 0.7053 - val_accuracy: 0.8156
# Epoch 34/200
# 187/187 - 34s - loss: 1.3633 - accuracy: 0.6491 - val_loss: 0.6997 - val_accuracy: 0.8154
# Epoch 35/200
# 187/187 - 32s - loss: 1.3284 - accuracy: 0.6603 - val_loss: 0.6936 - val_accuracy: 0.8152
# Epoch 36/200
# 187/187 - 34s - loss: 1.3196 - accuracy: 0.6593 - val_loss: 0.6871 - val_accuracy: 0.8176
# Epoch 37/200
# 187/187 - 32s - loss: 1.3112 - accuracy: 0.6620 - val_loss: 0.6807 - val_accuracy: 0.8195
# Epoch 38/200
# 187/187 - 34s - loss: 1.2973 - accuracy: 0.6598 - val_loss: 0.6770 - val_accuracy: 0.8186
# Epoch 39/200
# 187/187 - 33s - loss: 1.2863 - accuracy: 0.6635 - val_loss: 0.6716 - val_accuracy: 0.8190
# Epoch 40/200
# 187/187 - 34s - loss: 1.2729 - accuracy: 0.6702 - val_loss: 0.6676 - val_accuracy: 0.8180
# Epoch 41/200
# 187/187 - 34s - loss: 1.2688 - accuracy: 0.6725 - val_loss: 0.6638 - val_accuracy: 0.8182
# Epoch 42/200
# 187/187 - 33s - loss: 1.2654 - accuracy: 0.6674 - val_loss: 0.6600 - val_accuracy: 0.8186
# Epoch 43/200
# 187/187 - 34s - loss: 1.2513 - accuracy: 0.6740 - val_loss: 0.6553 - val_accuracy: 0.8189
# Epoch 44/200
# 187/187 - 33s - loss: 1.2373 - accuracy: 0.6783 - val_loss: 0.6523 - val_accuracy: 0.8208
# Epoch 45/200
# 187/187 - 34s - loss: 1.2176 - accuracy: 0.6829 - val_loss: 0.6491 - val_accuracy: 0.8216
# Epoch 46/200
# 187/187 - 33s - loss: 1.2145 - accuracy: 0.6796 - val_loss: 0.6464 - val_accuracy: 0.8209
# Epoch 47/200
# 187/187 - 34s - loss: 1.2085 - accuracy: 0.6829 - val_loss: 0.6420 - val_accuracy: 0.8214
# Epoch 48/200
# 187/187 - 33s - loss: 1.2027 - accuracy: 0.6887 - val_loss: 0.6398 - val_accuracy: 0.8209
# Epoch 49/200
# 187/187 - 34s - loss: 1.2054 - accuracy: 0.6814 - val_loss: 0.6372 - val_accuracy: 0.8216
# Epoch 50/200
# 187/187 - 34s - loss: 1.1901 - accuracy: 0.6826 - val_loss: 0.6346 - val_accuracy: 0.8212
# Epoch 51/200
# 187/187 - 33s - loss: 1.1802 - accuracy: 0.6893 - val_loss: 0.6312 - val_accuracy: 0.8212
# Epoch 52/200
# 187/187 - 33s - loss: 1.1837 - accuracy: 0.6898 - val_loss: 0.6287 - val_accuracy: 0.8219
# Epoch 53/200
# 187/187 - 33s - loss: 1.1596 - accuracy: 0.6981 - val_loss: 0.6272 - val_accuracy: 0.8218
# Epoch 54/200
# 187/187 - 33s - loss: 1.1510 - accuracy: 0.6939 - val_loss: 0.6235 - val_accuracy: 0.8228
# Epoch 55/200
# 187/187 - 33s - loss: 1.1610 - accuracy: 0.6940 - val_loss: 0.6223 - val_accuracy: 0.8223
# Epoch 56/200
# 187/187 - 34s - loss: 1.1470 - accuracy: 0.6982 - val_loss: 0.6199 - val_accuracy: 0.8226
# Epoch 57/200
# 187/187 - 33s - loss: 1.1369 - accuracy: 0.6970 - val_loss: 0.6181 - val_accuracy: 0.8222
# Epoch 58/200
# 187/187 - 33s - loss: 1.1266 - accuracy: 0.7015 - val_loss: 0.6158 - val_accuracy: 0.8230
# Epoch 59/200
# 187/187 - 34s - loss: 1.1154 - accuracy: 0.7045 - val_loss: 0.6145 - val_accuracy: 0.8223
# Epoch 60/200
# 187/187 - 34s - loss: 1.1147 - accuracy: 0.7055 - val_loss: 0.6124 - val_accuracy: 0.8232
# Epoch 61/200
# 187/187 - 33s - loss: 1.1092 - accuracy: 0.7050 - val_loss: 0.6107 - val_accuracy: 0.8228
# Epoch 62/200
# 187/187 - 34s - loss: 1.1006 - accuracy: 0.7110 - val_loss: 0.6090 - val_accuracy: 0.8222
# Epoch 63/200
# 187/187 - 33s - loss: 1.1119 - accuracy: 0.7035 - val_loss: 0.6072 - val_accuracy: 0.8236
# Epoch 64/200
# 187/187 - 34s - loss: 1.0936 - accuracy: 0.7109 - val_loss: 0.6057 - val_accuracy: 0.8244
# Epoch 65/200
# 187/187 - 33s - loss: 1.0899 - accuracy: 0.7106 - val_loss: 0.6054 - val_accuracy: 0.8232
# Epoch 66/200
# 187/187 - 34s - loss: 1.0849 - accuracy: 0.7081 - val_loss: 0.6038 - val_accuracy: 0.8243
# Epoch 67/200
# 187/187 - 33s - loss: 1.0795 - accuracy: 0.7166 - val_loss: 0.6026 - val_accuracy: 0.8232
# Epoch 68/200
# 187/187 - 34s - loss: 1.0793 - accuracy: 0.7080 - val_loss: 0.6012 - val_accuracy: 0.8229
# Epoch 69/200
# 187/187 - 34s - loss: 1.0626 - accuracy: 0.7166 - val_loss: 0.5995 - val_accuracy: 0.8231
# Epoch 70/200
# 187/187 - 33s - loss: 1.0726 - accuracy: 0.7128 - val_loss: 0.5991 - val_accuracy: 0.8229
# Epoch 71/200
# 187/187 - 34s - loss: 1.0636 - accuracy: 0.7148 - val_loss: 0.5978 - val_accuracy: 0.8240
# Epoch 72/200
# 187/187 - 33s - loss: 1.0598 - accuracy: 0.7196 - val_loss: 0.5961 - val_accuracy: 0.8244
# Epoch 73/200
# 187/187 - 34s - loss: 1.0431 - accuracy: 0.7183 - val_loss: 0.5957 - val_accuracy: 0.8235
# Epoch 74/200
# 187/187 - 33s - loss: 1.0364 - accuracy: 0.7254 - val_loss: 0.5954 - val_accuracy: 0.8238
# Epoch 75/200
# 187/187 - 34s - loss: 1.0444 - accuracy: 0.7203 - val_loss: 0.5933 - val_accuracy: 0.8242
# Epoch 76/200
# 187/187 - 33s - loss: 1.0386 - accuracy: 0.7201 - val_loss: 0.5933 - val_accuracy: 0.8249
# Epoch 77/200
# 187/187 - 34s - loss: 1.0400 - accuracy: 0.7201 - val_loss: 0.5919 - val_accuracy: 0.8245
# Epoch 78/200
# 187/187 - 34s - loss: 1.0177 - accuracy: 0.7247 - val_loss: 0.5902 - val_accuracy: 0.8244
# Epoch 79/200
# 187/187 - 33s - loss: 1.0325 - accuracy: 0.7229 - val_loss: 0.5904 - val_accuracy: 0.8242
# Epoch 80/200
# 187/187 - 34s - loss: 1.0171 - accuracy: 0.7307 - val_loss: 0.5901 - val_accuracy: 0.8244
# Epoch 81/200
# 187/187 - 33s - loss: 1.0139 - accuracy: 0.7320 - val_loss: 0.5891 - val_accuracy: 0.8250
# Epoch 82/200
# 187/187 - 34s - loss: 1.0078 - accuracy: 0.7315 - val_loss: 0.5890 - val_accuracy: 0.8237
# Epoch 83/200
# 187/187 - 33s - loss: 1.0008 - accuracy: 0.7313 - val_loss: 0.5874 - val_accuracy: 0.8251
# Epoch 84/200
# 187/187 - 34s - loss: 1.0020 - accuracy: 0.7308 - val_loss: 0.5862 - val_accuracy: 0.8254
# Epoch 85/200
# 187/187 - 33s - loss: 0.9985 - accuracy: 0.7347 - val_loss: 0.5861 - val_accuracy: 0.8258
# Epoch 86/200
# 187/187 - 34s - loss: 0.9854 - accuracy: 0.7372 - val_loss: 0.5852 - val_accuracy: 0.8271
# Epoch 87/200
# 187/187 - 33s - loss: 0.9849 - accuracy: 0.7341 - val_loss: 0.5842 - val_accuracy: 0.8271
# Epoch 88/200
# 187/187 - 34s - loss: 0.9916 - accuracy: 0.7314 - val_loss: 0.5845 - val_accuracy: 0.8264
# Epoch 89/200
# 187/187 - 34s - loss: 0.9792 - accuracy: 0.7401 - val_loss: 0.5843 - val_accuracy: 0.8266
# Epoch 90/200
# 187/187 - 33s - loss: 0.9719 - accuracy: 0.7363 - val_loss: 0.5835 - val_accuracy: 0.8265
# Epoch 91/200
# 187/187 - 34s - loss: 0.9627 - accuracy: 0.7431 - val_loss: 0.5822 - val_accuracy: 0.8277
# Epoch 92/200
# 187/187 - 33s - loss: 0.9603 - accuracy: 0.7411 - val_loss: 0.5815 - val_accuracy: 0.8280
# Epoch 93/200
# 187/187 - 34s - loss: 0.9626 - accuracy: 0.7428 - val_loss: 0.5816 - val_accuracy: 0.8274
# Epoch 94/200
# 187/187 - 34s - loss: 0.9530 - accuracy: 0.7444 - val_loss: 0.5816 - val_accuracy: 0.8252
# Epoch 95/200
# 187/187 - 33s - loss: 0.9484 - accuracy: 0.7453 - val_loss: 0.5809 - val_accuracy: 0.8253
# Epoch 96/200
# 187/187 - 34s - loss: 0.9487 - accuracy: 0.7502 - val_loss: 0.5798 - val_accuracy: 0.8267
# Epoch 97/200
# 187/187 - 34s - loss: 0.9491 - accuracy: 0.7442 - val_loss: 0.5793 - val_accuracy: 0.8266
# Epoch 98/200
# 187/187 - 33s - loss: 0.9335 - accuracy: 0.7506 - val_loss: 0.5783 - val_accuracy: 0.8263
# Epoch 99/200
# 187/187 - 34s - loss: 0.9321 - accuracy: 0.7459 - val_loss: 0.5777 - val_accuracy: 0.8267
# Epoch 100/200
# 187/187 - 33s - loss: 0.9400 - accuracy: 0.7454 - val_loss: 0.5784 - val_accuracy: 0.8257
# Epoch 101/200
# 187/187 - 34s - loss: 0.9395 - accuracy: 0.7486 - val_loss: 0.5776 - val_accuracy: 0.8268
# Epoch 102/200
# 187/187 - 33s - loss: 0.9272 - accuracy: 0.7526 - val_loss: 0.5771 - val_accuracy: 0.8268
# Epoch 103/200
# 187/187 - 34s - loss: 0.9227 - accuracy: 0.7498 - val_loss: 0.5765 - val_accuracy: 0.8256
# Epoch 104/200
# 187/187 - 33s - loss: 0.9268 - accuracy: 0.7475 - val_loss: 0.5766 - val_accuracy: 0.8259
# Epoch 105/200
# 187/187 - 34s - loss: 0.9173 - accuracy: 0.7582 - val_loss: 0.5761 - val_accuracy: 0.8261
# Epoch 106/200
# 187/187 - 33s - loss: 0.9042 - accuracy: 0.7628 - val_loss: 0.5759 - val_accuracy: 0.8264
# Epoch 107/200
# 187/187 - 34s - loss: 0.9098 - accuracy: 0.7560 - val_loss: 0.5759 - val_accuracy: 0.8277
# Epoch 108/200
# 187/187 - 34s - loss: 0.9101 - accuracy: 0.7538 - val_loss: 0.5756 - val_accuracy: 0.8268
# Epoch 109/200
# 187/187 - 33s - loss: 0.9145 - accuracy: 0.7511 - val_loss: 0.5754 - val_accuracy: 0.8267
# Epoch 110/200
# 187/187 - 34s - loss: 0.9050 - accuracy: 0.7539 - val_loss: 0.5742 - val_accuracy: 0.8266
# Epoch 111/200
# 187/187 - 33s - loss: 0.9058 - accuracy: 0.7572 - val_loss: 0.5739 - val_accuracy: 0.8264
# Epoch 112/200
# 187/187 - 34s - loss: 0.8934 - accuracy: 0.7630 - val_loss: 0.5738 - val_accuracy: 0.8265
# Epoch 113/200
# 187/187 - 33s - loss: 0.8922 - accuracy: 0.7589 - val_loss: 0.5737 - val_accuracy: 0.8265
# Epoch 114/200
# 187/187 - 34s - loss: 0.8897 - accuracy: 0.7602 - val_loss: 0.5733 - val_accuracy: 0.8265
# Epoch 115/200
# 187/187 - 33s - loss: 0.8864 - accuracy: 0.7640 - val_loss: 0.5728 - val_accuracy: 0.8259
# Epoch 116/200
# 187/187 - 34s - loss: 0.8940 - accuracy: 0.7592 - val_loss: 0.5715 - val_accuracy: 0.8267
# Epoch 117/200
# 187/187 - 34s - loss: 0.8853 - accuracy: 0.7598 - val_loss: 0.5721 - val_accuracy: 0.8258
# Epoch 118/200
# 187/187 - 33s - loss: 0.8720 - accuracy: 0.7660 - val_loss: 0.5722 - val_accuracy: 0.8258
# Epoch 119/200
# 187/187 - 34s - loss: 0.8670 - accuracy: 0.7670 - val_loss: 0.5715 - val_accuracy: 0.8259
# Epoch 120/200
# 187/187 - 33s - loss: 0.8532 - accuracy: 0.7687 - val_loss: 0.5722 - val_accuracy: 0.8256
# Epoch 121/200
# 187/187 - 34s - loss: 0.8686 - accuracy: 0.7657 - val_loss: 0.5717 - val_accuracy: 0.8252
# Epoch 122/200
# 187/187 - 33s - loss: 0.8559 - accuracy: 0.7731 - val_loss: 0.5714 - val_accuracy: 0.8257
# Epoch 123/200
# 187/187 - 34s - loss: 0.8565 - accuracy: 0.7677 - val_loss: 0.5704 - val_accuracy: 0.8267
# Epoch 124/200
# 187/187 - 33s - loss: 0.8678 - accuracy: 0.7649 - val_loss: 0.5711 - val_accuracy: 0.8252
# Epoch 125/200
# 187/187 - 35s - loss: 0.8430 - accuracy: 0.7712 - val_loss: 0.5700 - val_accuracy: 0.8268
# Epoch 126/200
# 187/187 - 34s - loss: 0.8531 - accuracy: 0.7730 - val_loss: 0.5705 - val_accuracy: 0.8261
# Epoch 127/200
# 187/187 - 35s - loss: 0.8543 - accuracy: 0.7740 - val_loss: 0.5714 - val_accuracy: 0.8259
# Epoch 128/200
# 187/187 - 34s - loss: 0.8385 - accuracy: 0.7767 - val_loss: 0.5715 - val_accuracy: 0.8258
# Epoch 129/200
# 187/187 - 33s - loss: 0.8427 - accuracy: 0.7749 - val_loss: 0.5707 - val_accuracy: 0.8254
# Epoch 130/200
# 187/187 - 34s - loss: 0.8526 - accuracy: 0.7711 - val_loss: 0.5706 - val_accuracy: 0.8258
# Epoch 131/200
# 187/187 - 33s - loss: 0.8364 - accuracy: 0.7759 - val_loss: 0.5700 - val_accuracy: 0.8257
# Epoch 132/200
# 187/187 - 33s - loss: 0.8310 - accuracy: 0.7760 - val_loss: 0.5697 - val_accuracy: 0.8267
# Epoch 133/200
# 187/187 - 33s - loss: 0.8492 - accuracy: 0.7706 - val_loss: 0.5686 - val_accuracy: 0.8280
# Epoch 134/200
# 187/187 - 33s - loss: 0.8337 - accuracy: 0.7793 - val_loss: 0.5686 - val_accuracy: 0.8280
# Epoch 135/200
# 187/187 - 34s - loss: 0.8397 - accuracy: 0.7738 - val_loss: 0.5680 - val_accuracy: 0.8271
# Epoch 136/200
# 187/187 - 34s - loss: 0.8319 - accuracy: 0.7786 - val_loss: 0.5683 - val_accuracy: 0.8266
# Epoch 137/200
# 187/187 - 33s - loss: 0.8230 - accuracy: 0.7758 - val_loss: 0.5686 - val_accuracy: 0.8267
# Epoch 138/200
# 187/187 - 34s - loss: 0.8123 - accuracy: 0.7826 - val_loss: 0.5691 - val_accuracy: 0.8260
# Epoch 139/200
# 187/187 - 33s - loss: 0.8214 - accuracy: 0.7826 - val_loss: 0.5700 - val_accuracy: 0.8256
# Epoch 140/200
# 187/187 - 34s - loss: 0.8254 - accuracy: 0.7787 - val_loss: 0.5695 - val_accuracy: 0.8267
# Epoch 141/200
# 187/187 - 33s - loss: 0.8109 - accuracy: 0.7846 - val_loss: 0.5692 - val_accuracy: 0.8251
# Epoch 142/200
# 187/187 - 34s - loss: 0.8132 - accuracy: 0.7807 - val_loss: 0.5690 - val_accuracy: 0.8259
# Epoch 143/200
# 187/187 - 33s - loss: 0.8096 - accuracy: 0.7828 - val_loss: 0.5687 - val_accuracy: 0.8259
# Epoch 144/200
# 187/187 - 34s - loss: 0.8055 - accuracy: 0.7807 - val_loss: 0.5681 - val_accuracy: 0.8252
# Epoch 145/200
# 187/187 - 33s - loss: 0.8073 - accuracy: 0.7869 - val_loss: 0.5688 - val_accuracy: 0.8242
# Epoch 146/200
# 187/187 - 34s - loss: 0.7944 - accuracy: 0.7863 - val_loss: 0.5691 - val_accuracy: 0.8259
# Epoch 147/200
# 187/187 - 34s - loss: 0.7993 - accuracy: 0.7876 - val_loss: 0.5686 - val_accuracy: 0.8256
# Epoch 148/200
# 187/187 - 33s - loss: 0.8055 - accuracy: 0.7862 - val_loss: 0.5682 - val_accuracy: 0.8257
# Epoch 149/200
# 187/187 - 34s - loss: 0.8064 - accuracy: 0.7842 - val_loss: 0.5678 - val_accuracy: 0.8256
# Epoch 150/200
# 187/187 - 33s - loss: 0.7953 - accuracy: 0.7861 - val_loss: 0.5685 - val_accuracy: 0.8247
# Epoch 151/200
# 187/187 - 34s - loss: 0.7933 - accuracy: 0.7865 - val_loss: 0.5684 - val_accuracy: 0.8231
# Epoch 152/200
# 187/187 - 33s - loss: 0.7872 - accuracy: 0.7897 - val_loss: 0.5676 - val_accuracy: 0.8246
# Epoch 153/200
# 187/187 - 34s - loss: 0.7780 - accuracy: 0.7918 - val_loss: 0.5669 - val_accuracy: 0.8261
# Epoch 154/200
# 187/187 - 33s - loss: 0.7802 - accuracy: 0.7885 - val_loss: 0.5680 - val_accuracy: 0.8245
# Epoch 155/200
# 187/187 - 34s - loss: 0.7952 - accuracy: 0.7847 - val_loss: 0.5682 - val_accuracy: 0.8257
# Epoch 156/200
# 187/187 - 34s - loss: 0.7734 - accuracy: 0.7934 - val_loss: 0.5682 - val_accuracy: 0.8246
# Epoch 157/200
# 187/187 - 33s - loss: 0.7819 - accuracy: 0.7888 - val_loss: 0.5679 - val_accuracy: 0.8256
# Epoch 158/200
# 187/187 - 34s - loss: 0.7784 - accuracy: 0.7899 - val_loss: 0.5685 - val_accuracy: 0.8252
# Epoch 159/200
# 187/187 - 33s - loss: 0.7690 - accuracy: 0.7937 - val_loss: 0.5691 - val_accuracy: 0.8242
# Epoch 160/200
# 187/187 - 34s - loss: 0.7762 - accuracy: 0.7970 - val_loss: 0.5682 - val_accuracy: 0.8253
# Epoch 161/200
# 187/187 - 33s - loss: 0.7759 - accuracy: 0.7918 - val_loss: 0.5688 - val_accuracy: 0.8265
# Epoch 162/200
# 187/187 - 34s - loss: 0.7639 - accuracy: 0.7940 - val_loss: 0.5682 - val_accuracy: 0.8254
# Epoch 163/200
# 187/187 - 33s - loss: 0.7753 - accuracy: 0.7917 - val_loss: 0.5687 - val_accuracy: 0.8242
# Epoch 164/200
# 187/187 - 34s - loss: 0.7587 - accuracy: 0.7964 - val_loss: 0.5692 - val_accuracy: 0.8243
# Epoch 165/200
# 187/187 - 33s - loss: 0.7533 - accuracy: 0.7999 - val_loss: 0.5696 - val_accuracy: 0.8242
# Epoch 166/200
# 187/187 - 34s - loss: 0.7607 - accuracy: 0.7954 - val_loss: 0.5687 - val_accuracy: 0.8246
# Epoch 167/200
# 187/187 - 34s - loss: 0.7482 - accuracy: 0.7990 - val_loss: 0.5691 - val_accuracy: 0.8242
# Epoch 168/200
# 187/187 - 33s - loss: 0.7474 - accuracy: 0.7998 - val_loss: 0.5691 - val_accuracy: 0.8242
# 134/134 [==============================] - 15s 114ms/step - loss: 0.5669 - accuracy: 0.8261
# Evaluate: [0.5669338703155518, 0.8261427283287048]

# %%
def unfreeze_model(model, lr=1e-5):
    # We unfreeze the top 20 layers while leaving BatchNorm layers frozen
    for layer in model.layers[-20:]:
        if layer.name[0:3] == "top" or layer.name[0:6] == "block7":
            if not isinstance(layer, layers.BatchNormalization):
                layer.trainable = True
                print('unfreezing layer:', layer.name)
        else:
            print('not unfreeze:', layer.name)

    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    model.compile(
        optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"]
    )


unfreeze_model(model_wedge, lr=1e-5)

epochs = 50  # @param {type: "slider", min:8, max:50}
hist = model_wedge.fit(ds_train, epochs=epochs, validation_data=ds_test, verbose=2, callbacks=[earlystopping])
print('Evaluate:', model_wedge.evaluate(ds_test))
plot_hist(hist)
# Out:
# not unfreeze: block6d_drop
# not unfreeze: block6d_add
# unfreezing layer: block7a_expand_conv
# unfreezing layer: block7a_expand_activation
# unfreezing layer: block7a_dwconv
# unfreezing layer: block7a_activation
# unfreezing layer: block7a_se_squeeze
# unfreezing layer: block7a_se_reshape
# unfreezing layer: block7a_se_reduce
# unfreezing layer: block7a_se_expand
# unfreezing layer: block7a_se_excite
# unfreezing layer: block7a_project_conv
# unfreezing layer: top_conv
# unfreezing layer: top_activation
# not unfreeze: avg_pool
# not unfreeze: pred
# Epoch 1/50
# 187/187 - 43s - loss: 0.6810 - accuracy: 0.7999 - val_loss: 0.5973 - val_accuracy: 0.8119
# Epoch 2/50
# 187/187 - 33s - loss: 0.6603 - accuracy: 0.8043 - val_loss: 0.5977 - val_accuracy: 0.8138
# Epoch 3/50
# 187/187 - 33s - loss: 0.6565 - accuracy: 0.8049 - val_loss: 0.5963 - val_accuracy: 0.8135
# Epoch 4/50
# 187/187 - 33s - loss: 0.6341 - accuracy: 0.8136 - val_loss: 0.5978 - val_accuracy: 0.8149
# Epoch 5/50
# 187/187 - 33s - loss: 0.6474 - accuracy: 0.8082 - val_loss: 0.5991 - val_accuracy: 0.8131
# Epoch 6/50
# 187/187 - 33s - loss: 0.6392 - accuracy: 0.8129 - val_loss: 0.6001 - val_accuracy: 0.8127
# Epoch 7/50
# 187/187 - 33s - loss: 0.6232 - accuracy: 0.8143 - val_loss: 0.6013 - val_accuracy: 0.8127
# Epoch 8/50
# 187/187 - 34s - loss: 0.6216 - accuracy: 0.8147 - val_loss: 0.6024 - val_accuracy: 0.8144
# Epoch 9/50
# 187/187 - 35s - loss: 0.6215 - accuracy: 0.8170 - val_loss: 0.6022 - val_accuracy: 0.8135
# Epoch 10/50
# 187/187 - 33s - loss: 0.6091 - accuracy: 0.8198 - val_loss: 0.6055 - val_accuracy: 0.8124
# Epoch 11/50
# 187/187 - 35s - loss: 0.6158 - accuracy: 0.8175 - val_loss: 0.6042 - val_accuracy: 0.8134
# Epoch 12/50
# 187/187 - 33s - loss: 0.5916 - accuracy: 0.8212 - val_loss: 0.6072 - val_accuracy: 0.8131
# Epoch 13/50
# 187/187 - 35s - loss: 0.5996 - accuracy: 0.8206 - val_loss: 0.6095 - val_accuracy: 0.8125
# Epoch 14/50
# 187/187 - 33s - loss: 0.5869 - accuracy: 0.8230 - val_loss: 0.6102 - val_accuracy: 0.8127
# Epoch 15/50
# 187/187 - 35s - loss: 0.5809 - accuracy: 0.8265 - val_loss: 0.6130 - val_accuracy: 0.8117
# Epoch 16/50
# 187/187 - 33s - loss: 0.5852 - accuracy: 0.8257 - val_loss: 0.6137 - val_accuracy: 0.8120
# Epoch 17/50
# 187/187 - 35s - loss: 0.5831 - accuracy: 0.8285 - val_loss: 0.6148 - val_accuracy: 0.8112
# Epoch 18/50
# 187/187 - 33s - loss: 0.5795 - accuracy: 0.8274 - val_loss: 0.6166 - val_accuracy: 0.8112
# 134/134 [==============================] - 15s 112ms/step - loss: 0.5963 - accuracy: 0.8135
# Evaluate: [0.5963000059127808, 0.8135494589805603]

# %% [markdown]
# ### Tips for fine tuning EfficientNet
#
# On unfreezing layers:
#
# - The `BathcNormalization` layers need to be kept frozen
# ([more details](https://keras.io/guides/transfer_learning/)).
# If they are also turned to trainable, the
# first epoch after unfreezing will significantly reduce accuracy.
# - In some cases it may be beneficial to open up only a portion of layers instead of
# unfreezing all. This will make fine tuning much faster when going to larger models like
# B7.
# - Each block needs to be all turned on or off. This is because the architecture includes
# a shortcut from the first layer to the last layer for each block. Not respecting blocks
# also significantly harms the final performance.
#
# Some other tips for utilizing EfficientNet:
#
# - Larger variants of EfficientNet do not guarantee improved performance, especially for
# tasks with less data or fewer classes. In such a case, the larger variant of EfficientNet
# chosen, the harder it is to tune hyperparameters.
# - EMA (Exponential Moving Average) is very helpful in training EfficientNet from scratch,
# but not so much for transfer learning.
# - Do not use the RMSprop setup as in the original paper for transfer learning. The
# momentum and learning rate are too high for transfer learning. It will easily corrupt the
# pretrained weight and blow up the loss. A quick check is to see if loss (as categorical
# cross entropy) is getting significantly larger than log(NUM_CLASSES) after the same
# epoch. If so, the initial learning rate/momentum is too high.
# - Smaller batch size benefit validation accuracy, possibly due to effectively providing
# regularization.
#
# ## Using the latest EfficientNet weights
#
# Since the initial paper, the EfficientNet has been improved by various methods for data
# preprocessing and for using unlabelled data to enhance learning results. These
# improvements are relatively hard and computationally costly to reproduce, and require
# extra code; but the weights are readily available in the form of TF checkpoint files. The
# model architecture has not changed, so loading the improved checkpoints is possible.
#
# To use a checkpoint provided at
# [the official model repository](https://github.com/tensorflow/tpu/tree/master/models/official/efficientnet), first
# download the checkpoint. As example, here we download noisy-student version of B1:
#
# ```
# !wget https://storage.googleapis.com/cloud-tpu-checkpoints/efficientnet\
#        /noisystudent/noisy_student_efficientnet-b1.tar.gz
# !tar -xf noisy_student_efficientnet-b1.tar.gz
# ```
#
# Then use the script [efficientnet_weight_update_util.py](https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/keras/applications/efficientnet_weight_update_util.py) to convert ckpt file to h5 file.
#
# ```
# !python efficientnet_weight_update_util.py --model b1 --notop --ckpt \
#         efficientnet-b1/model.ckpt --o efficientnetb1_notop.h5
# ```
#
# When creating model, use the following to load new weight:
#
# ```python
# model = EfficientNetB1(weights="efficientnetb1_notop.h5", include_top=False)
# ```
