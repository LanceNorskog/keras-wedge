# %% [markdown]
# # Speaker Recognition
#
# **Author:** [Fadi Badine](https://twitter.com/fadibadine)<br>
# **Date created:** 14/06/2020<br>
# **Last modified:** 03/07/2020<br>
# **Description:** Classify speakers using Fast Fourier Transform (FFT) and a 1D Convnet.

# %% [markdown]
# ## Introduction
#
# This example demonstrates how to create a model to classify speakers from the
# frequency domain representation of speech recordings, obtained via Fast Fourier
# Transform (FFT).
#
# It shows the following:
#
# - How to use `tf.data` to load, preprocess and feed audio streams into a model
# - How to create a 1D convolutional network with residual
# connections for audio classification.
#
# Our process:
#
# - We prepare a dataset of speech samples from different speakers, with the speaker as label.
# - We add background noise to these samples to augment our data.
# - We take the FFT of these samples.
# - We train a 1D convnet to predict the correct speaker given a noisy FFT speech sample.
#
# Note:
#
# - This example should be run with TensorFlow 2.3 or higher, or `tf-nightly`.
# - The noise samples in the dataset need to be resampled to a sampling rate of 16000 Hz
# before using the code in this example. In order to do this, you will need to have
# installed `ffmpg`.

# %% [markdown]
# ## Setup

# %%
# !apt-get install -q ffmpeg
# !mkdir -p /root/.kaggle
# !echo '{"username":"lancenorskog","key":"a6c862917b36eaa8fddbc7392bf56251"}' > /root/.kaggle/kaggle.json
# !kaggle datasets download -d kongaevans/speaker-recognition-dataset
# !mkdir -p /root/Downloads; cd /root/Downloads; unzip -q -n /content/speaker-recognition-dataset.zip
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 40 not upgraded.
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading speaker-recognition-dataset.zip to /content
#  94% 217M/231M [00:04<00:00, 41.7MB/s]
# 100% 231M/231M [00:04<00:00, 59.4MB/s]

# %%
import os
import shutil
import numpy as np

import tensorflow as tf
from tensorflow import keras

from pathlib import Path
from IPython.display import display, Audio

# Get the data from https://www.kaggle.com/kongaevans/speaker-recognition-dataset/download
# and save it to the 'Downloads' folder in your HOME directory
DATASET_ROOT = os.path.join(os.path.expanduser("~"), "Downloads/16000_pcm_speeches")

# The folders in which we will put the audio samples and the noise samples
AUDIO_SUBFOLDER = "audio"
NOISE_SUBFOLDER = "noise"

DATASET_AUDIO_PATH = os.path.join(DATASET_ROOT, AUDIO_SUBFOLDER)
DATASET_NOISE_PATH = os.path.join(DATASET_ROOT, NOISE_SUBFOLDER)

# Percentage of samples to use for validation
VALID_SPLIT = 0.1

# Seed to use when shuffling the dataset and the noise
SHUFFLE_SEED = 43

# The sampling rate to use.
# This is the one used in all of the audio samples.
# We will resample all of the noise to this sampling rate.
# This will also be the output size of the audio wave samples
# (since all samples are of 1 second long)
SAMPLING_RATE = 16000

# The factor to multiply the noise with according to:
#   noisy_sample = sample + noise * prop * scale
#      where prop = sample_amplitude / noise_amplitude
SCALE = 0.5

BATCH_SIZE = 512
EPOCHS = 200

# %% [markdown]
# ## Data preparation
#
# The dataset is composed of 7 folders, divided into 2 groups:
#
# - Speech samples, with 5 folders for 5 different speakers. Each folder contains
# 1500 audio files, each 1 second long and sampled at 16000 Hz.
# - Background noise samples, with 2 folders and a total of 6 files. These files
# are longer than 1 second (and originally not sampled at 16000 Hz, but we will resample them to 16000 Hz).
# We will use those 6 files to create 354 1-second-long noise samples to be used for training.
#
# Let's sort these 2 categories into 2 folders:
#
# - An `audio` folder which will contain all the per-speaker speech sample folders
# - A `noise` folder which will contain all the noise samples

# %% [markdown]
# Before sorting the audio and noise categories into 2 folders,
# we have the following directory structure:
#
# ```
# main_directory/
# ...speaker_a/
# ...speaker_b/
# ...speaker_c/
# ...speaker_d/
# ...speaker_e/
# ...other/
# ..._background_noise_/
# ```
#
# After sorting, we end up with the following structure:
#
# ```
# main_directory/
# ...audio/
# ......speaker_a/
# ......speaker_b/
# ......speaker_c/
# ......speaker_d/
# ......speaker_e/
# ...noise/
# ......other/
# ......_background_noise_/
# ```

# %%
# If folder `audio`, does not exist, create it, otherwise do nothing
if os.path.exists(DATASET_AUDIO_PATH) is False:
    os.makedirs(DATASET_AUDIO_PATH)

    # If folder `noise`, does not exist, create it, otherwise do nothing
    if os.path.exists(DATASET_NOISE_PATH) is False:
        os.makedirs(DATASET_NOISE_PATH)

    for folder in os.listdir(DATASET_ROOT):
        if os.path.isdir(os.path.join(DATASET_ROOT, folder)):
            if folder in [AUDIO_SUBFOLDER, NOISE_SUBFOLDER]:
                # If folder is `audio` or `noise`, do nothing
                continue
            elif folder in ["other", "_background_noise_"]:
                # If folder is one of the folders that contains noise samples,
                # move it to the `noise` folder
                shutil.move(
                    os.path.join(DATASET_ROOT, folder),
                    os.path.join(DATASET_NOISE_PATH, folder),
                )
            else:
                # Otherwise, it should be a speaker folder, then move it to
                # `audio` folder
                shutil.move(
                    os.path.join(DATASET_ROOT, folder),
                    os.path.join(DATASET_AUDIO_PATH, folder),
                )

# %% [markdown]
# ## Noise preparation
#
# In this section:
#
# - We load all noise samples (which should have been resampled to 16000)
# - We split those noise samples to chuncks of 16000 samples which
# correspond to 1 second duration each

# %%
# Get the list of all noise files
noise_paths = []
for subdir in os.listdir(DATASET_NOISE_PATH):
    subdir_path = Path(DATASET_NOISE_PATH) / subdir
    if os.path.isdir(subdir_path):
        noise_paths += [
            os.path.join(subdir_path, filepath)
            for filepath in os.listdir(subdir_path)
            if filepath.endswith(".wav")
        ]

print(
    "Found {} files belonging to {} directories".format(
        len(noise_paths), len(os.listdir(DATASET_NOISE_PATH))
    )
)
# Out:
# Found 6 files belonging to 2 directories

# %% [markdown]
# Resample all noise samples to 16000 Hz

# %%
command = (
    "for dir in `ls -1 " + DATASET_NOISE_PATH + "`; do "
    "for file in `ls -1 " + DATASET_NOISE_PATH + "/$dir/*.wav`; do "
    "sample_rate=`ffprobe -hide_banner -loglevel panic -show_streams "
    "$file | grep sample_rate | cut -f2 -d=`; "
    "if [ $sample_rate -ne 16000 ]; then "
    "ffmpeg -hide_banner -loglevel panic -y "
    "-i $file -ar 16000 temp.wav; "
    "mv temp.wav $file; "
    "fi; done; done"
)
os.system(command)

# Split noise into chunks of 16,000 steps each
def load_noise_sample(path):
    sample, sampling_rate = tf.audio.decode_wav(
        tf.io.read_file(path), desired_channels=1
    )
    if sampling_rate == SAMPLING_RATE:
        # Number of slices of 16000 each that can be generated from the noise sample
        slices = int(sample.shape[0] / SAMPLING_RATE)
        sample = tf.split(sample[: slices * SAMPLING_RATE], slices)
        return sample
    else:
        print("Sampling rate for {} is incorrect. Ignoring it".format(path))
        return None


noises = []
for path in noise_paths:
    sample = load_noise_sample(path)
    if sample:
        noises.extend(sample)
noises = tf.stack(noises)

print(
    "{} noise files were split into {} noise samples where each is {} sec. long".format(
        len(noise_paths), noises.shape[0], noises.shape[1] // SAMPLING_RATE
    )
)
# Out:
# 6 noise files were split into 354 noise samples where each is 1 sec. long

# %% [markdown]
# ## Dataset generation

# %%
def paths_and_labels_to_dataset(audio_paths, labels):
    """Constructs a dataset of audios and labels."""
    path_ds = tf.data.Dataset.from_tensor_slices(audio_paths)
    audio_ds = path_ds.map(lambda x: path_to_audio(x))
    label_ds = tf.data.Dataset.from_tensor_slices(labels)
    return tf.data.Dataset.zip((audio_ds, label_ds))


def path_to_audio(path):
    """Reads and decodes an audio file."""
    audio = tf.io.read_file(path)
    audio, _ = tf.audio.decode_wav(audio, 1, SAMPLING_RATE)
    return audio


def add_noise(audio, noises=None, scale=0.5):
    if noises is not None:
        # Create a random tensor of the same size as audio ranging from
        # 0 to the number of noise stream samples that we have.
        tf_rnd = tf.random.uniform(
            (tf.shape(audio)[0],), 0, noises.shape[0], dtype=tf.int32
        )
        noise = tf.gather(noises, tf_rnd, axis=0)

        # Get the amplitude proportion between the audio and the noise
        prop = tf.math.reduce_max(audio, axis=1) / tf.math.reduce_max(noise, axis=1)
        prop = tf.repeat(tf.expand_dims(prop, axis=1), tf.shape(audio)[1], axis=1)

        # Adding the rescaled noise to audio
        audio = audio + noise * prop * scale

    return audio


def audio_to_fft(audio):
    # Since tf.signal.fft applies FFT on the innermost dimension,
    # we need to squeeze the dimensions and then expand them again
    # after FFT
    audio = tf.squeeze(audio, axis=-1)
    fft = tf.signal.fft(
        tf.cast(tf.complex(real=audio, imag=tf.zeros_like(audio)), tf.complex64)
    )
    fft = tf.expand_dims(fft, axis=-1)

    # Return the absolute value of the first half of the FFT
    # which represents the positive frequencies
    return tf.math.abs(fft[:, : (audio.shape[1] // 2), :])


# Get the list of audio file paths along with their corresponding labels

class_names = os.listdir(DATASET_AUDIO_PATH)
print("Our class names: {}".format(class_names,))

audio_paths = []
labels = []
for label, name in enumerate(class_names):
    print("Processing speaker {}".format(name,))
    dir_path = Path(DATASET_AUDIO_PATH) / name
    speaker_sample_paths = [
        os.path.join(dir_path, filepath)
        for filepath in os.listdir(dir_path)
        if filepath.endswith(".wav")
    ]
    audio_paths += speaker_sample_paths
    labels += [label] * len(speaker_sample_paths)

print(
    "Found {} files belonging to {} classes.".format(len(audio_paths), len(class_names))
)

# Shuffle
rng = np.random.RandomState(SHUFFLE_SEED)
rng.shuffle(audio_paths)
rng = np.random.RandomState(SHUFFLE_SEED)
rng.shuffle(labels)

# Split into training and validation
num_val_samples = int(VALID_SPLIT * len(audio_paths))
print("Using {} files for training.".format(len(audio_paths) - num_val_samples))
train_audio_paths = audio_paths[:-num_val_samples]
train_labels = labels[:-num_val_samples]

print("Using {} files for validation.".format(num_val_samples))
valid_audio_paths = audio_paths[-num_val_samples:]
valid_labels = labels[-num_val_samples:]

# Create 2 datasets, one for training and the other for validation
train_ds = paths_and_labels_to_dataset(train_audio_paths, train_labels)
train_ds = train_ds.shuffle(buffer_size=BATCH_SIZE * 8, seed=SHUFFLE_SEED).batch(
    BATCH_SIZE
)

valid_ds = paths_and_labels_to_dataset(valid_audio_paths, valid_labels)
valid_ds = valid_ds.shuffle(buffer_size=32 * 8, seed=SHUFFLE_SEED).batch(32)


# Add noise to the training set
train_ds = train_ds.map(
    lambda x, y: (add_noise(x, noises, scale=SCALE), y),
    num_parallel_calls=tf.data.experimental.AUTOTUNE,
)

# Transform audio wave to the frequency domain using `audio_to_fft`
train_ds = train_ds.map(
    lambda x, y: (audio_to_fft(x), y), num_parallel_calls=tf.data.experimental.AUTOTUNE
)
train_ds = train_ds.prefetch(tf.data.experimental.AUTOTUNE)

valid_ds = valid_ds.map(
    lambda x, y: (audio_to_fft(x), y), num_parallel_calls=tf.data.experimental.AUTOTUNE
)
valid_ds = valid_ds.prefetch(tf.data.experimental.AUTOTUNE)
# Out:
# Our class names: ['Julia_Gillard', 'Nelson_Mandela', 'Jens_Stoltenberg', 'Benjamin_Netanyau', 'Magaret_Tarcher']
# Processing speaker Julia_Gillard
# Processing speaker Nelson_Mandela
# Processing speaker Jens_Stoltenberg
# Processing speaker Benjamin_Netanyau
# Processing speaker Magaret_Tarcher
# Found 7501 files belonging to 5 classes.
# Using 6751 files for training.
# Using 750 files for validation.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.

# %% [markdown]
# ## Model Definition

# %%
def residual_block(x, filters, conv_num=3, activation="relu"):
    # Shortcut
    s = keras.layers.Conv1D(filters, 1, padding="same")(x)
    for i in range(conv_num - 1):
        x = keras.layers.Conv1D(filters, 3, padding="same")(x)
        x = keras.layers.Activation(activation)(x)
    x = keras.layers.Conv1D(filters, 3, padding="same")(x)
    x = keras.layers.Add()([x, s])
    x = keras.layers.Activation(activation)(x)
    return keras.layers.MaxPool1D(pool_size=2, strides=2)(x)


def build_model(input_shape, num_classes):
    inputs = keras.layers.Input(shape=input_shape, name="input")

    x = residual_block(inputs, 16, 2)
    x = residual_block(x, 32, 2)
    x = residual_block(x, 64, 3)
    x = residual_block(x, 128, 3)
    x = residual_block(x, 128, 3)

    x = keras.layers.AveragePooling1D(pool_size=3, strides=3)(x)
    x = keras.layers.Flatten()(x)
    x = keras.layers.Dense(256, activation="relu")(x)
    x = keras.layers.Dense(128, activation="relu")(x)

    outputs = keras.layers.Dense(num_classes, activation="softmax", name="output")(x)

    return keras.models.Model(inputs=inputs, outputs=outputs)


model = build_model((SAMPLING_RATE // 2, 1), len(class_names))

model.summary()

# Compile the model using Adam's default learning rate
model.compile(
    optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)

# Add callbacks:
# 'EarlyStopping' to stop training when the model is not enhancing anymore
# 'ModelCheckPoint' to always keep the model that has the best val_accuracy
model_save_filename = "model.h5"

earlystopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
mdlcheckpoint_cb = keras.callbacks.ModelCheckpoint(
    model_save_filename, monitor="val_loss", save_best_only=True
)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 8000, 1)]    0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 8000, 16)     64          input[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 8000, 16)     0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 8000, 16)     784         activation[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 8000, 16)     32          input[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 8000, 16)     0           conv1d_2[0][0]
#                                                                  conv1d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 8000, 16)     0           add[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 4000, 16)     0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 4000, 32)     1568        max_pooling1d[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 4000, 32)     0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 4000, 32)     3104        activation_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 4000, 32)     544         max_pooling1d[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 4000, 32)     0           conv1d_5[0][0]
#                                                                  conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 4000, 32)     0           add_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 2000, 32)     0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 2000, 64)     6208        max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 2000, 64)     0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 2000, 64)     12352       activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 2000, 64)     0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 2000, 64)     12352       activation_5[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 2000, 64)     2112        max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 2000, 64)     0           conv1d_9[0][0]
#                                                                  conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 2000, 64)     0           add_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 1000, 64)     0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 1000, 128)    24704       max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 1000, 128)    0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 1000, 128)    49280       activation_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 1000, 128)    0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 1000, 128)    49280       activation_8[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 1000, 128)    8320        max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 1000, 128)    0           conv1d_13[0][0]
#                                                                  conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 1000, 128)    0           add_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 500, 128)     0           activation_9[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 500, 128)     49280       max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 500, 128)     0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 500, 128)     49280       activation_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 500, 128)     0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 500, 128)     49280       activation_11[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 500, 128)     16512       max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 500, 128)     0           conv1d_17[0][0]
#                                                                  conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 500, 128)     0           add_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 250, 128)     0           activation_12[0][0]
# __________________________________________________________________________________________________
# average_pooling1d (AveragePooli (None, 83, 128)      0           max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 10624)        0           average_pooling1d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          2720000     flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          32896       dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 5)            645         dense_1[0][0]
# ==================================================================================================
# Total params: 3,088,597
# Trainable params: 3,088,597
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training

# %%
history = model.fit(
    train_ds,
    epochs=EPOCHS,
    validation_data=valid_ds,
    callbacks=[earlystopping_cb, mdlcheckpoint_cb],
    verbose=2
)
# Out:
# Epoch 1/200
# 14/14 - 49s - loss: 3.3544 - accuracy: 0.3758 - val_loss: 0.8962 - val_accuracy: 0.6253
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/200
# 14/14 - 38s - loss: 0.6908 - accuracy: 0.7451 - val_loss: 0.6314 - val_accuracy: 0.7627
# Epoch 3/200
# 14/14 - 38s - loss: 0.4982 - accuracy: 0.8214 - val_loss: 0.3919 - val_accuracy: 0.8453
# Epoch 4/200
# 14/14 - 38s - loss: 0.3244 - accuracy: 0.8825 - val_loss: 0.3033 - val_accuracy: 0.8653
# Epoch 5/200
# 14/14 - 38s - loss: 0.2503 - accuracy: 0.9048 - val_loss: 0.2160 - val_accuracy: 0.8947
# Epoch 6/200
# 14/14 - 38s - loss: 0.1988 - accuracy: 0.9259 - val_loss: 0.1811 - val_accuracy: 0.9107
# Epoch 7/200
# 14/14 - 40s - loss: 0.1626 - accuracy: 0.9366 - val_loss: 0.2212 - val_accuracy: 0.9053
# Epoch 8/200
# 14/14 - 38s - loss: 0.2616 - accuracy: 0.9008 - val_loss: 0.1557 - val_accuracy: 0.9520
# Epoch 9/200
# 14/14 - 38s - loss: 0.1969 - accuracy: 0.9262 - val_loss: 0.1101 - val_accuracy: 0.9680
# Epoch 10/200
# 14/14 - 38s - loss: 0.1440 - accuracy: 0.9468 - val_loss: 0.0883 - val_accuracy: 0.9720
# Epoch 11/200
# 14/14 - 38s - loss: 0.1167 - accuracy: 0.9581 - val_loss: 0.1253 - val_accuracy: 0.9533
# Epoch 12/200
# 14/14 - 38s - loss: 0.1156 - accuracy: 0.9542 - val_loss: 0.0684 - val_accuracy: 0.9747
# Epoch 13/200
# 14/14 - 38s - loss: 0.1026 - accuracy: 0.9607 - val_loss: 0.0647 - val_accuracy: 0.9693
# Epoch 14/200
# 14/14 - 38s - loss: 0.0863 - accuracy: 0.9684 - val_loss: 0.0663 - val_accuracy: 0.9747
# Epoch 15/200
# 14/14 - 38s - loss: 0.0928 - accuracy: 0.9639 - val_loss: 0.0766 - val_accuracy: 0.9707
# Epoch 16/200
# 14/14 - 38s - loss: 0.1528 - accuracy: 0.9452 - val_loss: 0.0773 - val_accuracy: 0.9787
# Epoch 17/200
# 14/14 - 38s - loss: 0.1137 - accuracy: 0.9600 - val_loss: 0.0616 - val_accuracy: 0.9773
# Epoch 18/200
# 14/14 - 38s - loss: 0.0902 - accuracy: 0.9656 - val_loss: 0.0859 - val_accuracy: 0.9613
# Epoch 19/200
# 14/14 - 38s - loss: 0.0869 - accuracy: 0.9655 - val_loss: 0.0488 - val_accuracy: 0.9800
# Epoch 20/200
# 14/14 - 38s - loss: 0.0776 - accuracy: 0.9723 - val_loss: 0.0525 - val_accuracy: 0.9800
# Epoch 21/200
# 14/14 - 38s - loss: 0.0786 - accuracy: 0.9729 - val_loss: 0.0407 - val_accuracy: 0.9867
# Epoch 22/200
# 14/14 - 38s - loss: 0.0731 - accuracy: 0.9732 - val_loss: 0.0414 - val_accuracy: 0.9827
# Epoch 23/200
# 14/14 - 38s - loss: 0.0624 - accuracy: 0.9778 - val_loss: 0.0509 - val_accuracy: 0.9787
# Epoch 24/200
# 14/14 - 38s - loss: 0.0664 - accuracy: 0.9741 - val_loss: 0.0505 - val_accuracy: 0.9787
# Epoch 25/200
# 14/14 - 38s - loss: 0.0549 - accuracy: 0.9802 - val_loss: 0.0347 - val_accuracy: 0.9893
# Epoch 26/200
# 14/14 - 38s - loss: 0.0458 - accuracy: 0.9840 - val_loss: 0.0269 - val_accuracy: 0.9947
# Epoch 27/200
# 14/14 - 38s - loss: 0.0415 - accuracy: 0.9859 - val_loss: 0.0356 - val_accuracy: 0.9880
# Epoch 28/200
# 14/14 - 38s - loss: 0.0455 - accuracy: 0.9834 - val_loss: 0.0551 - val_accuracy: 0.9813
# Epoch 29/200
# 14/14 - 38s - loss: 0.0459 - accuracy: 0.9831 - val_loss: 0.0280 - val_accuracy: 0.9920
# Epoch 30/200
# 14/14 - 38s - loss: 0.0455 - accuracy: 0.9839 - val_loss: 0.0370 - val_accuracy: 0.9880
# Epoch 31/200
# 14/14 - 38s - loss: 0.1201 - accuracy: 0.9616 - val_loss: 0.0780 - val_accuracy: 0.9733
# Epoch 32/200
# 14/14 - 38s - loss: 0.0754 - accuracy: 0.9763 - val_loss: 0.0541 - val_accuracy: 0.9800
# Epoch 33/200
# 14/14 - 38s - loss: 0.0511 - accuracy: 0.9833 - val_loss: 0.0336 - val_accuracy: 0.9853
# Epoch 34/200
# 14/14 - 38s - loss: 0.0356 - accuracy: 0.9884 - val_loss: 0.0204 - val_accuracy: 0.9933
# Epoch 35/200
# 14/14 - 38s - loss: 0.0323 - accuracy: 0.9877 - val_loss: 0.0213 - val_accuracy: 0.9920
# Epoch 36/200
# 14/14 - 38s - loss: 0.0300 - accuracy: 0.9879 - val_loss: 0.0370 - val_accuracy: 0.9880
# Epoch 37/200
# 14/14 - 38s - loss: 0.0400 - accuracy: 0.9849 - val_loss: 0.0275 - val_accuracy: 0.9920
# Epoch 38/200
# 14/14 - 38s - loss: 0.0455 - accuracy: 0.9831 - val_loss: 0.0423 - val_accuracy: 0.9773
# Epoch 39/200
# 14/14 - 38s - loss: 0.0417 - accuracy: 0.9843 - val_loss: 0.0257 - val_accuracy: 0.9920
# Epoch 40/200
# 14/14 - 38s - loss: 0.0329 - accuracy: 0.9886 - val_loss: 0.0192 - val_accuracy: 0.9933
# Epoch 41/200
# 14/14 - 38s - loss: 0.0248 - accuracy: 0.9913 - val_loss: 0.0228 - val_accuracy: 0.9907
# Epoch 42/200
# 14/14 - 38s - loss: 0.0280 - accuracy: 0.9895 - val_loss: 0.0262 - val_accuracy: 0.9893
# Epoch 43/200
# 14/14 - 38s - loss: 0.0269 - accuracy: 0.9893 - val_loss: 0.0159 - val_accuracy: 0.9960
# Epoch 44/200
# 14/14 - 38s - loss: 0.0215 - accuracy: 0.9929 - val_loss: 0.0168 - val_accuracy: 0.9947
# Epoch 45/200
# 14/14 - 38s - loss: 0.0177 - accuracy: 0.9947 - val_loss: 0.0130 - val_accuracy: 0.9947
# Epoch 46/200
# 14/14 - 38s - loss: 0.0231 - accuracy: 0.9914 - val_loss: 0.0310 - val_accuracy: 0.9880
# Epoch 47/200
# 14/14 - 38s - loss: 0.0638 - accuracy: 0.9778 - val_loss: 0.0424 - val_accuracy: 0.9840
# Epoch 48/200
# 14/14 - 38s - loss: 0.0787 - accuracy: 0.9720 - val_loss: 0.0318 - val_accuracy: 0.9907
# Epoch 49/200
# 14/14 - 38s - loss: 0.0387 - accuracy: 0.9883 - val_loss: 0.0173 - val_accuracy: 0.9947
# Epoch 50/200
# 14/14 - 38s - loss: 0.0222 - accuracy: 0.9920 - val_loss: 0.0188 - val_accuracy: 0.9947
# Epoch 51/200
# 14/14 - 38s - loss: 0.0198 - accuracy: 0.9927 - val_loss: 0.0190 - val_accuracy: 0.9960
# Epoch 52/200
# 14/14 - 38s - loss: 0.0221 - accuracy: 0.9920 - val_loss: 0.0208 - val_accuracy: 0.9920
# Epoch 53/200
# 14/14 - 38s - loss: 0.0549 - accuracy: 0.9831 - val_loss: 0.0353 - val_accuracy: 0.9907
# Epoch 54/200
# 14/14 - 38s - loss: 0.0333 - accuracy: 0.9883 - val_loss: 0.0226 - val_accuracy: 0.9907
# Epoch 55/200
# 14/14 - 38s - loss: 0.0232 - accuracy: 0.9920 - val_loss: 0.0154 - val_accuracy: 0.9920

# %% [markdown]
# ## Evaluation

# %%
print(model.evaluate(valid_ds))
# Out:
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0130 - accuracy: 0.9947
# [0.012993885204195976, 0.9946666955947876]

# %% [markdown]
# We get ~ 98% validation accuracy.

# %% [markdown]
# ## Demonstration
#
# Let's take some samples and:
#
# - Predict the speaker
# - Compare the prediction with the real speaker
# - Listen to the audio to see that despite the samples being noisy,
# the model is still pretty accurate

# %%
SAMPLES_TO_DISPLAY = 10

test_ds = paths_and_labels_to_dataset(valid_audio_paths, valid_labels)
test_ds = test_ds.shuffle(buffer_size=BATCH_SIZE * 8, seed=SHUFFLE_SEED).batch(
    BATCH_SIZE
)

test_ds = test_ds.map(lambda x, y: (add_noise(x, noises, scale=SCALE), y))

for audios, labels in test_ds.take(1):
    # Get the signal FFT
    ffts = audio_to_fft(audios)
    # Predict
    y_pred = model.predict(ffts)
    # Take random samples
    rnd = np.random.randint(0, BATCH_SIZE, SAMPLES_TO_DISPLAY)
    audios = audios.numpy()[rnd, :, :]
    labels = labels.numpy()[rnd]
    y_pred = np.argmax(y_pred, axis=-1)[rnd]

    for index in range(SAMPLES_TO_DISPLAY):
        # For every sample, print the true and predicted label
        # as well as run the voice with the noise
        print(
            "Speaker:\33{} {}\33[0m\tPredicted:\33{} {}\33[0m".format(
                "[92m" if labels[index] == y_pred[index] else "[91m",
                class_names[labels[index]],
                "[92m" if labels[index] == y_pred[index] else "[91m",
                class_names[y_pred[index]],
            )
        )
        display(Audio(audios[index, :, :].squeeze(), rate=SAMPLING_RATE))
# Out:
# Speaker: Jens_Stoltenberg	Predicted: Jens_Stoltenberg
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Magaret_Tarcher	Predicted: Magaret_Tarcher
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Benjamin_Netanyau	Predicted: Benjamin_Netanyau
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Magaret_Tarcher	Predicted: Magaret_Tarcher
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Jens_Stoltenberg	Predicted: Jens_Stoltenberg
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Benjamin_Netanyau	Predicted: Benjamin_Netanyau
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Nelson_Mandela	Predicted: Nelson_Mandela
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Julia_Gillard	Predicted: Julia_Gillard
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Magaret_Tarcher	Predicted: Magaret_Tarcher
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Julia_Gillard	Predicted: Julia_Gillard
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # WedgeDropout1D

# %%
# !pip uninstall -y keras-wedge-dropout
# !pip install -q git+https://github.com/LanceNorskog/keras-wedge.git
from keras_wedge_dropout import WedgeDropout2D
# Out:
# WARNING: Skipping keras-wedge-dropout as it is not installed.
#   Building wheel for keras-wedge-dropout (setup.py) ... done

# %%
def residual_block(x, filters, conv_num=3, activation="relu"):
    # Shortcut
    s = keras.layers.Conv1D(filters, 1, padding="same")(x)
    for i in range(conv_num - 1):
        x = keras.layers.Conv1D(filters, 3, padding="same")(x)
        x = keras.layers.Activation(activation)(x)
    x = keras.layers.Conv1D(filters, 3, padding="same")(x)
    x = keras.layers.Add()([x, s])
    x = keras.layers.Activation(activation)(x)
    return keras.layers.MaxPool1D(pool_size=2, strides=2)(x)


def build_model_wedge(input_shape, num_classes):
    inputs = keras.layers.Input(shape=input_shape, name="input")

    x = residual_block(inputs, 16, 2)
    x = residual_block(x, 32, 2)
    x = residual_block(x, 64, 3)
    x = residual_block(x, 128, 3)
    x = residual_block(x, 128, 3)

    # before or after avgpool?
    x = WedgeDropout1D(similarity=0.65)(x)

    x = keras.layers.AveragePooling1D(pool_size=3, strides=3)(x)
    x = keras.layers.Flatten()(x)
    x = keras.layers.Dense(256, activation="relu")(x)
    x = keras.layers.Dense(128, activation="relu")(x)

    outputs = keras.layers.Dense(num_classes, activation="softmax", name="output")(x)

    return keras.models.Model(inputs=inputs, outputs=outputs)


model = build_model((SAMPLING_RATE // 2, 1), len(class_names))

model.summary()

# Compile the model using Adam's default learning rate
opt = keras.optimizers.Adam(learning_rate=0.0005)
model.compile(
    optimizer=opt, loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)

# Add callbacks:
# 'EarlyStopping' to stop training when the model is not enhancing anymore

earlystopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 8000, 1)]    0
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 8000, 16)     64          input[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8000, 16)     0           conv1d_19[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 8000, 16)     784         activation_13[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 8000, 16)     32          input[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8000, 16)     0           conv1d_20[0][0]
#                                                                  conv1d_18[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8000, 16)     0           add_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 4000, 16)     0           activation_14[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 4000, 32)     1568        max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 4000, 32)     0           conv1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 4000, 32)     3104        activation_15[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 4000, 32)     544         max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4000, 32)     0           conv1d_23[0][0]
#                                                                  conv1d_21[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 4000, 32)     0           add_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 2000, 32)     0           activation_16[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 2000, 64)     6208        max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 2000, 64)     0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 2000, 64)     12352       activation_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 2000, 64)     0           conv1d_26[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 2000, 64)     12352       activation_18[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 2000, 64)     2112        max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 2000, 64)     0           conv1d_27[0][0]
#                                                                  conv1d_24[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 2000, 64)     0           add_7[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 1000, 64)     0           activation_19[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 1000, 128)    24704       max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 1000, 128)    0           conv1d_29[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 1000, 128)    49280       activation_20[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 1000, 128)    0           conv1d_30[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 1000, 128)    49280       activation_21[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 1000, 128)    8320        max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 1000, 128)    0           conv1d_31[0][0]
#                                                                  conv1d_28[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 1000, 128)    0           add_8[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_8 (MaxPooling1D)  (None, 500, 128)     0           activation_22[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 500, 128)     49280       max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 500, 128)     0           conv1d_33[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 500, 128)     49280       activation_23[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 500, 128)     0           conv1d_34[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 500, 128)     49280       activation_24[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 500, 128)     16512       max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 500, 128)     0           conv1d_35[0][0]
#                                                                  conv1d_32[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 500, 128)     0           add_9[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_9 (MaxPooling1D)  (None, 250, 128)     0           activation_25[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_1 (AveragePoo (None, 83, 128)      0           max_pooling1d_9[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 10624)        0           average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          2720000     flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          32896       dense_2[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 5)            645         dense_3[0][0]
# ==================================================================================================
# Total params: 3,088,597
# Trainable params: 3,088,597
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit(
    train_ds,
    epochs=EPOCHS,
    validation_data=valid_ds,
    callbacks=[earlystopping_cb],
    verbose=2
)
print(model.evaluate(valid_ds))
# Out:
# Epoch 1/200
# 14/14 - 40s - loss: 5.4346 - accuracy: 0.3542 - val_loss: 0.8347 - val_accuracy: 0.6853
# Epoch 2/200
# 14/14 - 38s - loss: 0.7981 - accuracy: 0.7069 - val_loss: 0.5684 - val_accuracy: 0.7853
# Epoch 3/200
# 14/14 - 38s - loss: 0.4717 - accuracy: 0.8261 - val_loss: 0.2831 - val_accuracy: 0.9093
# Epoch 4/200
# 14/14 - 38s - loss: 0.3613 - accuracy: 0.8659 - val_loss: 0.3361 - val_accuracy: 0.8680
# Epoch 5/200
# 14/14 - 38s - loss: 0.2598 - accuracy: 0.8973 - val_loss: 0.1972 - val_accuracy: 0.9293
# Epoch 6/200
# 14/14 - 38s - loss: 0.2217 - accuracy: 0.9169 - val_loss: 0.1862 - val_accuracy: 0.9120
# Epoch 7/200
# 14/14 - 38s - loss: 0.2203 - accuracy: 0.9139 - val_loss: 0.1517 - val_accuracy: 0.9453
# Epoch 8/200
# 14/14 - 38s - loss: 0.1656 - accuracy: 0.9372 - val_loss: 0.0885 - val_accuracy: 0.9800
# Epoch 9/200
# 14/14 - 38s - loss: 0.1388 - accuracy: 0.9470 - val_loss: 0.1019 - val_accuracy: 0.9587
# Epoch 10/200
# 14/14 - 38s - loss: 0.1451 - accuracy: 0.9413 - val_loss: 0.0930 - val_accuracy: 0.9667
# Epoch 11/200
# 14/14 - 38s - loss: 0.1189 - accuracy: 0.9567 - val_loss: 0.1326 - val_accuracy: 0.9507
# Epoch 12/200
# 14/14 - 38s - loss: 0.1437 - accuracy: 0.9464 - val_loss: 0.0750 - val_accuracy: 0.9747
# Epoch 13/200
# 14/14 - 38s - loss: 0.1180 - accuracy: 0.9532 - val_loss: 0.0730 - val_accuracy: 0.9653
# Epoch 14/200
# 14/14 - 38s - loss: 0.1018 - accuracy: 0.9609 - val_loss: 0.0515 - val_accuracy: 0.9813
# Epoch 15/200
# 14/14 - 38s - loss: 0.1098 - accuracy: 0.9600 - val_loss: 0.1279 - val_accuracy: 0.9520
# Epoch 16/200
# 14/14 - 38s - loss: 0.1215 - accuracy: 0.9525 - val_loss: 0.0823 - val_accuracy: 0.9693
# Epoch 17/200
# 14/14 - 39s - loss: 0.0864 - accuracy: 0.9684 - val_loss: 0.0620 - val_accuracy: 0.9813
# Epoch 18/200
# 14/14 - 38s - loss: 0.1049 - accuracy: 0.9612 - val_loss: 0.1350 - val_accuracy: 0.9613
# Epoch 19/200
# 14/14 - 38s - loss: 0.0809 - accuracy: 0.9705 - val_loss: 0.0532 - val_accuracy: 0.9827
# Epoch 20/200
# 14/14 - 38s - loss: 0.0663 - accuracy: 0.9762 - val_loss: 0.0324 - val_accuracy: 0.9853
# Epoch 21/200
# 14/14 - 38s - loss: 0.0663 - accuracy: 0.9769 - val_loss: 0.0419 - val_accuracy: 0.9787
# Epoch 22/200
# 14/14 - 38s - loss: 0.0866 - accuracy: 0.9677 - val_loss: 0.0459 - val_accuracy: 0.9867
# Epoch 23/200
# 14/14 - 38s - loss: 0.0951 - accuracy: 0.9647 - val_loss: 0.0594 - val_accuracy: 0.9787
# Epoch 24/200
# 14/14 - 38s - loss: 0.0669 - accuracy: 0.9772 - val_loss: 0.0388 - val_accuracy: 0.9827
# Epoch 25/200
# 14/14 - 38s - loss: 0.0515 - accuracy: 0.9839 - val_loss: 0.0221 - val_accuracy: 0.9933
# Epoch 26/200
# 14/14 - 38s - loss: 0.0572 - accuracy: 0.9788 - val_loss: 0.0231 - val_accuracy: 0.9933
# Epoch 27/200
# 14/14 - 38s - loss: 0.0556 - accuracy: 0.9779 - val_loss: 0.0314 - val_accuracy: 0.9907
# Epoch 28/200
# 14/14 - 39s - loss: 0.0560 - accuracy: 0.9800 - val_loss: 0.0265 - val_accuracy: 0.9907
# Epoch 29/200
# 14/14 - 38s - loss: 0.0482 - accuracy: 0.9821 - val_loss: 0.0229 - val_accuracy: 0.9867
# Epoch 30/200
# 14/14 - 38s - loss: 0.0400 - accuracy: 0.9852 - val_loss: 0.0188 - val_accuracy: 0.9920
# Epoch 31/200
# 14/14 - 38s - loss: 0.0492 - accuracy: 0.9824 - val_loss: 0.0190 - val_accuracy: 0.9960
# Epoch 32/200
# 14/14 - 38s - loss: 0.0429 - accuracy: 0.9858 - val_loss: 0.0267 - val_accuracy: 0.9907
# Epoch 33/200
# 14/14 - 38s - loss: 0.0480 - accuracy: 0.9821 - val_loss: 0.0227 - val_accuracy: 0.9920
# Epoch 34/200
# 14/14 - 38s - loss: 0.1105 - accuracy: 0.9615 - val_loss: 0.0401 - val_accuracy: 0.9893
# Epoch 35/200
# 14/14 - 38s - loss: 0.0776 - accuracy: 0.9708 - val_loss: 0.0506 - val_accuracy: 0.9840
# Epoch 36/200
# 14/14 - 38s - loss: 0.0698 - accuracy: 0.9751 - val_loss: 0.0257 - val_accuracy: 0.9960
# Epoch 37/200
# 14/14 - 38s - loss: 0.0417 - accuracy: 0.9870 - val_loss: 0.0158 - val_accuracy: 0.9960
# Epoch 38/200
# 14/14 - 38s - loss: 0.0368 - accuracy: 0.9862 - val_loss: 0.0320 - val_accuracy: 0.9880
# Epoch 39/200
# 14/14 - 38s - loss: 0.0385 - accuracy: 0.9855 - val_loss: 0.0403 - val_accuracy: 0.9827
# Epoch 40/200
# 14/14 - 38s - loss: 0.0475 - accuracy: 0.9827 - val_loss: 0.0203 - val_accuracy: 0.9933
# Epoch 41/200
# 14/14 - 38s - loss: 0.0316 - accuracy: 0.9904 - val_loss: 0.0127 - val_accuracy: 0.9973
# Epoch 42/200
# 14/14 - 38s - loss: 0.0316 - accuracy: 0.9899 - val_loss: 0.0146 - val_accuracy: 0.9960
# Epoch 43/200
# 14/14 - 38s - loss: 0.0249 - accuracy: 0.9907 - val_loss: 0.0171 - val_accuracy: 0.9920
# Epoch 44/200
# 14/14 - 38s - loss: 0.0299 - accuracy: 0.9907 - val_loss: 0.0237 - val_accuracy: 0.9880
# Epoch 45/200
# 14/14 - 38s - loss: 0.0277 - accuracy: 0.9910 - val_loss: 0.0208 - val_accuracy: 0.9920
# Epoch 46/200
# 14/14 - 38s - loss: 0.0348 - accuracy: 0.9879 - val_loss: 0.0211 - val_accuracy: 0.9920
# Epoch 47/200
# 14/14 - 38s - loss: 0.0325 - accuracy: 0.9880 - val_loss: 0.0127 - val_accuracy: 0.9960
# Epoch 48/200
# 14/14 - 38s - loss: 0.0282 - accuracy: 0.9898 - val_loss: 0.0169 - val_accuracy: 0.9933
# Epoch 49/200
# 14/14 - 38s - loss: 0.0159 - accuracy: 0.9935 - val_loss: 0.0127 - val_accuracy: 0.9947
# Epoch 50/200
# 14/14 - 38s - loss: 0.0167 - accuracy: 0.9941 - val_loss: 0.0133 - val_accuracy: 0.9947
# Epoch 51/200
# 14/14 - 38s - loss: 0.0232 - accuracy: 0.9933 - val_loss: 0.0330 - val_accuracy: 0.9893
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0127 - accuracy: 0.9973
# [0.012711082585155964, 0.9973333477973938]
